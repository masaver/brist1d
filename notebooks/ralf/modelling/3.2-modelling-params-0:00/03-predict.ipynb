# %% [markdown]
# # Univariate Modelling

# %%
import os
import joblib
import pandas as pd

stored_models = [file for file in os.listdir() if file.endswith('.model.pkl')]
stored_models
# Out:
# ['ridge.model.pkl', 'xgb.model.pkl', 'hgb.model.pkl']

# %%
from sklearn.ensemble import VotingRegressor

estimators = []
for model_file in stored_models:
    print(f'Loading {model_file}')
    model = joblib.load(model_file)
    estimators.append((
        model_file.replace('.model.pkl', ''),
        model
    ))

estimators
# Out:
# Loading ridge.model.pkl
# Loading xgb.model.pkl
# Loading hgb.model.pkl
# [('ridge', RidgeCV(alpha_per_target=True, alphas=[0.1, 1.0, 10.0])),
#  ('xgb',
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=0.5, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.1, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=7, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=200, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...)),
#  ('hgb',
#   HistGradientBoostingRegressor(l2_regularization=0.5, max_depth=7, max_iter=300,
#                                 max_leaf_nodes=63))]

# %%
train_data = pd.read_csv('train_data.csv')
X_train = train_data.drop(columns=['bg+1:00'])
y_train = train_data['bg+1:00']

ensemble = VotingRegressor(estimators=estimators, verbose=True)
ensemble.fit(X=X_train, y=y_train)
ensemble.score(X=X_train, y=y_train)
# Out:
# [Voting] .................... (1 of 3) Processing ridge, total=   0.0s
# [Voting] ...................... (2 of 3) Processing xgb, total=   0.8s
# [Voting] ...................... (3 of 3) Processing hgb, total=   4.8s
# 0.5817991078188063

# %%
X_train
# Out:
#          bg-0:00  insulin-0:00   hr-0:00  cals-0:00  day_phase_evening  \
# 0       2.275154     -0.152482  0.929993  -0.458394              False
# 1       2.041687     -0.152482  0.929993  -0.458394              False
# 2       1.874925     -0.152482  0.929993  -0.458394              False
# 3       1.841572     -0.152482  0.929993  -0.458394              False
# 4       1.708162     -0.152482  0.929993  -0.458394              False
# ...          ...           ...       ...        ...                ...
# 177019  0.507474      0.082239  1.175840  -0.202605              False
# 177020  0.674236      0.872021  1.175840  -0.202605              False
# 177021  0.807646      0.368976  1.175840  -0.202605              False
# 177022  0.907704     -0.144131  1.175840  -0.202605              False
# 177023  1.107818     -0.118979  1.175840  -0.202605              False
#
#         day_phase_morning  day_phase_night  day_phase_noon
# 0                    True            False           False
# 1                    True            False           False
# 2                    True            False           False
# 3                    True            False           False
# 4                    True            False           False
# ...                   ...              ...             ...
# 177019              False             True           False
# 177020              False             True           False
# 177021              False             True           False
# 177022              False             True           False
# 177023              False             True           False
#
# [177024 rows x 8 columns]

# %% [markdown]
# # Prepare test results

# %%
test_file = os.path.join('..', '..', '..', '..', 'data', 'raw', 'test.csv')

# %%
## Load the test data
test_data = pd.read_csv(test_file, index_col=0)
test_data.head()
# Out:
#          p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# id
# p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#           bg-5:30  bg-5:25  bg-5:20  ...  activity-0:45  activity-0:40  \
# id                                   ...
# p01_8459      NaN      NaN     10.3  ...            NaN            NaN
# p01_8460      9.4      NaN      NaN  ...            NaN            NaN
# p01_8461      NaN      NaN      5.2  ...            NaN            NaN
# p01_8462      NaN      NaN      4.7  ...            NaN            NaN
# p01_8463     10.0      NaN      NaN  ...            NaN            NaN
#
#           activity-0:35  activity-0:30  activity-0:25  activity-0:20  \
# id
# p01_8459            NaN            NaN            NaN            NaN
# p01_8460            NaN            NaN            NaN            NaN
# p01_8461            NaN            NaN            NaN            NaN
# p01_8462            NaN            NaN            NaN            NaN
# p01_8463            NaN            NaN            NaN            NaN
#
#           activity-0:15  activity-0:10  activity-0:05  activity-0:00
# id
# p01_8459            NaN            NaN            NaN            NaN
# p01_8460            NaN           Walk           Walk           Walk
# p01_8461            NaN            NaN            NaN            NaN
# p01_8462            NaN            NaN            NaN            NaN
# p01_8463            NaN            NaN            NaN            NaN
#
# [5 rows x 506 columns]

# %%
from pipelines import pipeline

test_data = pipeline.fit_transform(test_data)
test_data.head()
# Out:
#            bg-0:00  insulin-0:00   hr-0:00  cals-0:00  day_phase_evening  \
# id
# p01_8459  0.297295     -0.164395 -1.429320  -0.166561              False
# p01_8460 -1.256018     -0.147000  1.989071   3.490763              False
# p01_8461 -0.199765     -0.155698 -0.264931   0.402079              False
# p01_8462  0.390494     -0.147000 -1.151576  -0.341314              False
# p01_8463 -1.038554     -0.208093 -1.092822  -0.341314              False
#
#           day_phase_morning  day_phase_night  day_phase_noon
# id
# p01_8459               True            False           False
# p01_8460              False            False            True
# p01_8461              False            False           False
# p01_8462              False             True           False
# p01_8463              False             True           False

# %%
# Predict the bg+1:00 values
test_data['bg+1:00'] = ensemble.predict(test_data)
test_data.head()
# Out:
#            bg-0:00  insulin-0:00   hr-0:00  cals-0:00  day_phase_evening  \
# id
# p01_8459  0.297295     -0.164395 -1.429320  -0.166561              False
# p01_8460 -1.256018     -0.147000  1.989071   3.490763              False
# p01_8461 -0.199765     -0.155698 -0.264931   0.402079              False
# p01_8462  0.390494     -0.147000 -1.151576  -0.341314              False
# p01_8463 -1.038554     -0.208093 -1.092822  -0.341314              False
#
#           day_phase_morning  day_phase_night  day_phase_noon   bg+1:00
# id
# p01_8459               True            False           False  8.467961
# p01_8460              False            False            True  5.847002
# p01_8461              False            False           False  7.511862
# p01_8462              False             True           False  8.149937
# p01_8463              False             True           False  5.836534

# %% [markdown]
# ## Prepare the submission file

# %%
submission = pd.DataFrame(test_data['bg+1:00'])
submission
# Out:
#            bg+1:00
# id
# p01_8459  8.467961
# p01_8460  5.847002
# p01_8461  7.511862
# p01_8462  8.149937
# p01_8463  5.836534
# ...            ...
# p24_256   6.314424
# p24_257   8.943484
# p24_258   6.724515
# p24_259   7.856204
# p24_260   6.590998
#
# [3644 rows x 1 columns]

# %% [markdown]
# ### Save the submission file

# %%
submission.to_csv(f'submission-{os.path.basename(os.getcwd())}.csv')
