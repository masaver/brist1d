# %% [markdown]
# # Preprocessing
#
# Final model for individual patients
# Based on 3.25

# %%
from data import load_data
import pandas as pd

train_data, additional_train_data, test_data, unique_patients = load_data()
unique_patients
# Out:
# array(['p01', 'p02', 'p04', 'p05', 'p06', 'p10', 'p11', 'p12', 'p15',
#        'p16', 'p18', 'p19', 'p21', 'p22', 'p24'], dtype=object)

# %%
train_data.head()
# Out:
#       p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# id
# p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN      9.7
# p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN      9.2
# p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN      8.7
# p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN      8.4
# p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN      8.1
#
#        bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  activity-0:30  \
# id                       ...
# p01_0      NaN      NaN  ...            NaN            NaN            NaN
# p01_1      NaN      NaN  ...            NaN            NaN            NaN
# p01_2      NaN      NaN  ...            NaN            NaN            NaN
# p01_3      NaN      NaN  ...            NaN            NaN            NaN
# p01_4      NaN      NaN  ...            NaN            NaN            NaN
#
# ...

# %%
additional_train_data.head()
# Out:
#             p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# id
# p01_test_12   p01  01:50:00      NaN      NaN      NaN      NaN      NaN
# p01_test_13   p01  01:55:00      NaN      NaN      NaN      NaN      NaN
# p01_test_14   p01  02:00:00      NaN      NaN      NaN      NaN      NaN
# p01_test_15   p01  02:05:00      NaN      NaN      NaN      NaN      NaN
# p01_test_16   p01  02:10:00      NaN      NaN      NaN      NaN      NaN
#
#              bg-5:30  bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  \
# id                                      ...
# p01_test_12      NaN      NaN      NaN  ...            NaN            NaN
# p01_test_13      NaN      NaN      NaN  ...            NaN            NaN
# p01_test_14      NaN      NaN      NaN  ...            NaN            NaN
# p01_test_15      NaN      NaN      NaN  ...            NaN            NaN
# p01_test_16      NaN      NaN      NaN  ...            NaN            NaN
#
# ...

# %%
test_data.head()
# Out:
#          p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# id
# p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#           bg-5:30  bg-5:25  bg-5:20  ...  activity-0:45  activity-0:40  \
# id                                   ...
# p01_8459      NaN      NaN     10.3  ...            NaN            NaN
# p01_8460      9.4      NaN      NaN  ...            NaN            NaN
# p01_8461      NaN      NaN      5.2  ...            NaN            NaN
# p01_8462      NaN      NaN      4.7  ...            NaN            NaN
# p01_8463     10.0      NaN      NaN  ...            NaN            NaN
#
# ...

# %%
patient_id = unique_patients[0]
patient_id
# Out:
# 'p01'

# %%
patient_train_data = pd.concat([train_data[train_data['p_num'] == patient_id], additional_train_data[additional_train_data['p_num'] == patient_id]])
patient_train_data.shape
# Out:
# (19211, 507)

# %%
patient_test_data = test_data[test_data['p_num'] == patient_id]
patient_test_data.shape
# Out:
# (244, 506)

# %%
from pipelines import preprocessing_pipeline

patient_train_data_preprocessed = preprocessing_pipeline.fit_transform(patient_train_data)
patient_train_data_preprocessed.head()
# Out:
#        hour_sin  hour_cos  bg-1:00  bg-0:55  bg-0:50  bg-0:45  bg-0:40  \
# id
# p01_0  0.999048 -0.043619     17.3     17.4     17.4     17.5     17.4
# p01_1  0.994056 -0.108867     17.5     17.4     17.4     17.3     16.9
# p01_2  0.984808 -0.173648     17.3     16.9     16.6     16.2     15.8
# p01_3  0.971342 -0.237686     16.2     15.8     15.5     15.1     14.9
# p01_4  0.953717 -0.300706     15.1     14.9     14.6     14.4     14.2
#
#        bg-0:35  bg-0:30  bg-0:25  ...  cals-0:40  cals-0:35  cals-0:30  \
# id                                ...
# p01_0     17.4     17.3     16.9  ...       5.68       5.68       5.68
# p01_1     16.6     16.2     15.8  ...       5.68       5.68       5.68
# p01_2     15.5     15.1     14.9  ...       5.68       5.68       5.68
# p01_3     14.6     14.4     14.2  ...       5.68       5.68       5.68
# p01_4     14.1     13.9     13.9  ...       5.68       5.68       5.68
#
# ...

# %%
patient_test_data_preprocessed = preprocessing_pipeline.transform(patient_test_data)
patient_test_data_preprocessed.head()
# Out:
#           hour_sin  hour_cos  bg-1:00  bg-0:55  bg-0:50  bg-0:45  bg-0:40  \
# id
# p01_8459  0.980785 -0.195090     13.5     13.0     12.4     11.8     11.1
# p01_8460  0.152123 -0.988362      3.9      4.1      4.3      4.5      5.1
# p01_8461 -0.659346 -0.751840      4.9      5.5      6.0      6.6      7.1
# p01_8462  0.923880  0.382683      6.4      6.8      7.1      7.5      7.6
# p01_8463  0.906308  0.422618      3.3      3.3      3.4      3.4      3.3
#
#           bg-0:35  bg-0:30  bg-0:25  ...  cals-0:45  cals-0:40  cals-0:35  \
# id                                   ...
# p01_8459     10.5     10.2     10.0  ...        4.9        4.9        4.9
# p01_8460      5.8      6.4      6.4  ...       12.2        5.9        9.7
# p01_8461      7.6      8.1      8.2  ...       19.2       17.6       10.0
# p01_8462      7.7      7.8      8.0  ...        4.8        4.8        4.8
# p01_8463      3.3      3.2      3.4  ...       10.3        4.8        4.8
#
# ...

# %%
from pipelines import pipeline

patient_train_data_transformed = pipeline.fit_transform(patient_train_data)
patient_train_data_transformed.head()
# Out:
#        hour_sin  hour_cos   bg-1:00   bg-0:55   bg-0:50   bg-0:45   bg-0:40  \
# id
# p01_0  1.407712 -0.046143  2.165055  2.194551  2.190038  2.205829  2.183948
# p01_1  1.400722 -0.139375  2.216292  2.194551  2.190038  2.154739  2.055946
# p01_2  1.387772 -0.231940  2.165055  2.066162  1.984914  1.873744  1.774339
# p01_3  1.368918 -0.323443  1.883250  1.783708  1.702869  1.592749  1.543934
# p01_4  1.344239 -0.413492  1.601445  1.552609  1.472106  1.413934  1.364730
#
#         bg-0:35   bg-0:30   bg-0:25  ...  cals-0:40  cals-0:35  cals-0:30  \
# id                                   ...
# p01_0  2.179576  2.144633  2.046924  ...   -0.49896  -0.498023  -0.497886
# p01_1  1.975082  1.864514  1.766162  ...   -0.49896  -0.498023  -0.497886
# p01_2  1.693902  1.584396  1.536447  ...   -0.49896  -0.498023  -0.497886
# p01_3  1.463846  1.406139  1.357780  ...   -0.49896  -0.498023  -0.497886
# p01_4  1.336038  1.278812  1.281208  ...   -0.49896  -0.498023  -0.497886
#
# ...

# %%
patient_test_data_transformed = pipeline.transform(patient_test_data)
patient_test_data_transformed.head()
# Out:
#           hour_sin  hour_cos   bg-1:00   bg-0:55   bg-0:50   bg-0:45  \
# id
# p01_8459  1.382140 -0.262579  1.191546  1.064733  0.908016  0.749764
# p01_8460  0.221840 -1.396078 -1.267843 -1.220581 -1.168859 -1.115020
# p01_8461 -0.914386 -1.058114 -1.011656 -0.861093 -0.732971 -0.578575
# p01_8462  1.302460  0.562997 -0.627377 -0.527283 -0.450927 -0.348670
# p01_8463  1.277856  0.620060 -1.421554 -1.426002 -1.399623 -1.396015
#
#            bg-0:40   bg-0:35   bg-0:30   bg-0:25  ...  cals-0:45  cals-0:40  \
# id                                                ...
# p01_8459  0.571113  0.415814  0.336596  0.285778  ...  -0.626500  -0.628796
# p01_8460 -0.964921 -0.785588 -0.631086 -0.633081  ...   0.592430  -0.462340
# p01_8461 -0.452910 -0.325477 -0.198176 -0.173651  ...   1.761267   1.485199
# p01_8462 -0.324907 -0.299915 -0.274572 -0.224699  ...  -0.643198  -0.645442
# p01_8463 -1.425732 -1.424632 -1.445976 -1.398796  ...   0.275174  -0.645442
#
# ...
