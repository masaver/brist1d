# %% [markdown]
# # Modelling most important features
#
# ## Model Selection

# %%
import os
import pandas as pd

train_data_file = os.path.join('..', '..', '..', '..', 'data', 'raw', 'train.csv')
train_data = pd.read_csv(train_data_file, index_col=0, low_memory=False)

validation_data_file = os.path.join('..', '..', '..', '..', 'data', 'interim', 'all_test_4_55h.csv')
validation_data = pd.read_csv(validation_data_file, index_col=0, low_memory=False)

additional_train_data_file = os.path.join('..', '..', '..', '..', 'data', 'interim', 'all_test_3h.csv')
additional_train_data = pd.read_csv(additional_train_data_file, index_col=0, low_memory=False)
# remove from additional data patients that are not in validation data ids
additional_train_data = additional_train_data[~additional_train_data.index.isin(validation_data.index.unique())]

# merge train and additional data
train_data = pd.concat([train_data, additional_train_data], axis=0)

# do not train with patients that are not have to be predicted
test_data_file = os.path.join('..', '..', '..', '..', 'data', 'raw', 'test.csv')
test_data = pd.read_csv(test_data_file, index_col=0, low_memory=False)

unique_patients = test_data['p_num'].unique()
train_data = train_data[train_data['p_num'].isin(unique_patients)]
validation_data = validation_data[validation_data['p_num'].isin(unique_patients)]
test_data = test_data[test_data['p_num'].isin(unique_patients)]

# %% [markdown]
# ## Loop through unique patients

# %%
from notebooks.helpers.LazyPredict import get_lazy_regressor
from pipelines import pipeline

lazy_predict_results = {}

for patient in unique_patients:
    patient_train_data = train_data[train_data['p_num'] == patient]
    patient_validation_data = validation_data[validation_data['p_num'] == patient]
    
    patient_train_data_transformed = pipeline.fit_transform(patient_train_data)
    patient_validation_data_transformed = pipeline.transform(patient_validation_data)
    
    X_train = patient_train_data_transformed.drop(columns=['bg+1:00'])
    y_train = patient_train_data_transformed['bg+1:00']
    
    X_test = patient_validation_data_transformed.drop(columns=['bg+1:00'])
    y_test = patient_validation_data_transformed['bg+1:00']

    reg = get_lazy_regressor(exclude=['SVR'])
    models = reg.fit(X_train, X_test, y_train, y_test)
    lazy_predict_results[patient] = models
# Out:
#  97%|█████████▋| 37/38 [01:56<00:00,  1.97it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004449 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 43979
# [LightGBM] [Info] Number of data points in the train set: 13600, number of used features: 208
# [LightGBM] [Info] Start training from score 8.854422
# 100%|██████████| 38/38 [01:57<00:00,  3.10s/it]
#  97%|█████████▋| 37/38 [04:21<00:01,  1.00s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 46745
# [LightGBM] [Info] Number of data points in the train set: 31000, number of used features: 208
# [LightGBM] [Info] Start training from score 9.377212
# 100%|██████████| 38/38 [04:22<00:00,  6.91s/it]
#  97%|█████████▋| 37/38 [04:01<00:01,  1.04s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009008 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 46184
# [LightGBM] [Info] Number of data points in the train set: 30505, number of used features: 208
# [LightGBM] [Info] Start training from score 7.783695
# 100%|██████████| 38/38 [04:02<00:00,  6.39s/it]
#  97%|█████████▋| 37/38 [02:03<00:00,  1.43it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006645 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 43485
# [LightGBM] [Info] Number of data points in the train set: 14153, number of used features: 208
# [LightGBM] [Info] Start training from score 8.269870
# 100%|██████████| 38/38 [02:05<00:00,  3.30s/it]
#  97%|█████████▋| 37/38 [01:54<00:00,  1.70it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007661 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42631
# [LightGBM] [Info] Number of data points in the train set: 13315, number of used features: 208
# [LightGBM] [Info] Start training from score 9.094037
# 100%|██████████| 38/38 [01:55<00:00,  3.05s/it]
#  97%|█████████▋| 37/38 [05:07<00:00,  1.01it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006572 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44019
# [LightGBM] [Info] Number of data points in the train set: 29515, number of used features: 208
# [LightGBM] [Info] Start training from score 6.490273
# 100%|██████████| 38/38 [05:08<00:00,  8.13s/it]
#  97%|█████████▋| 37/38 [20:11<00:01,  1.03s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010340 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 45589
# [LightGBM] [Info] Number of data points in the train set: 29531, number of used features: 208
# [LightGBM] [Info] Start training from score 9.256592
# 100%|██████████| 38/38 [20:12<00:00, 31.92s/it]
#  97%|█████████▋| 37/38 [07:42<00:01,  1.67s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011509 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 45668
# [LightGBM] [Info] Number of data points in the train set: 31754, number of used features: 208
# [LightGBM] [Info] Start training from score 7.999423
# 100%|██████████| 38/38 [07:45<00:00, 12.25s/it]
#  97%|█████████▋| 37/38 [00:59<00:00,  2.39it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007726 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 31316
# [LightGBM] [Info] Number of data points in the train set: 6503, number of used features: 208
# [LightGBM] [Info] Start training from score 8.169626
# 100%|██████████| 38/38 [01:00<00:00,  1.58s/it]
#  97%|█████████▋| 37/38 [01:06<00:00,  1.96it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 32586
# [LightGBM] [Info] Number of data points in the train set: 5670, number of used features: 208
# [LightGBM] [Info] Start training from score 8.243407
# 100%|██████████| 38/38 [01:07<00:00,  1.79s/it]
#  97%|█████████▋| 37/38 [01:01<00:00,  2.06it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006492 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 34368
# [LightGBM] [Info] Number of data points in the train set: 5219, number of used features: 208
# [LightGBM] [Info] Start training from score 10.117103
# 100%|██████████| 38/38 [01:02<00:00,  1.65s/it]
#  97%|█████████▋| 37/38 [01:07<00:00,  2.03it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 41924
# [LightGBM] [Info] Number of data points in the train set: 5519, number of used features: 208
# [LightGBM] [Info] Start training from score 8.523470
# 100%|██████████| 38/38 [01:08<00:00,  1.81s/it]
#  97%|█████████▋| 37/38 [00:55<00:00,  2.28it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40659
# [LightGBM] [Info] Number of data points in the train set: 4991, number of used features: 208
# [LightGBM] [Info] Start training from score 10.827031
# 100%|██████████| 38/38 [00:56<00:00,  1.49s/it]
#  97%|█████████▋| 37/38 [00:48<00:00,  2.48it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008044 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 38120
# [LightGBM] [Info] Number of data points in the train set: 4462, number of used features: 208
# [LightGBM] [Info] Start training from score 8.097407
# 100%|██████████| 38/38 [00:49<00:00,  1.31s/it]
#  97%|█████████▋| 37/38 [01:14<00:00,  1.83it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007982 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 43331
# [LightGBM] [Info] Number of data points in the train set: 5957, number of used features: 208
# [LightGBM] [Info] Start training from score 7.978553
# 100%|██████████| 38/38 [01:16<00:00,  2.00s/it]

# %%
lazy_predict_results.keys()
# Out:
# dict_keys(['p01', 'p02', 'p04', 'p05', 'p06', 'p10', 'p11', 'p12', 'p15', 'p16', 'p18', 'p19', 'p21', 'p22', 'p24'])

# %%
lazy_predict_results.values()
# Out:
# dict_values([(                                                              Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.57
# LGBMRegressor                                                               0.44
# OrthogonalMatchingPursuit                                                   0.42
# OrthogonalMatchingPursuitCV                                                 0.42
# XGBRegressor                                                                0.41
# GradientBoostingRegressor                                                   0.41
# HistGradientBoostingRegressor                                               0.39
# LassoCV                                                                     0.34
# LassoLarsCV                                                                 0.34
# LarsCV                                                                      0.31
# PoissonRegressor                                                            0.30
# BaggingRegressor                                                            0.28
# ElasticNetCV                                                                0.23
# HuberRegressor                                                              0.23
# LinearSVR                                                                   0.20
# GammaRegressor                                                              0.12
# LassoLarsIC                                                                 0.10
# TransformedTargetRegressor                                                  0.08
# Ridge                                                                       0.08
# RidgeCV                                                                     0.06
# BayesianRidge                                                               0.05
# LassoLars                                                                   0.04
# ElasticNet                                                                  0.04
# KNeighborsRegressor                                                        -0.03
# AdaBoostRegressor                                                          -0.07
# TweedieRegressor                                                           -0.11
# PassiveAggressiveRegressor                                                 -0.12
# ExtraTreeRegressor                                                         -0.18
# DecisionTreeRegressor                                                      -0.84
# DummyRegressor                                                             -1.11
# QuantileRegressor                                                          -1.25
# MLPRegressor                                                               -4.31
# RANSACRegressor                                                          -641.94
# SGDRegressor                                                        -12323832.57
# Lars                          -4785662047995485589074863244325017315477999505...
#
#                                                                        R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.79
# LGBMRegressor                                                               0.73
# OrthogonalMatchingPursuit                                                   0.73
# OrthogonalMatchingPursuitCV                                                 0.72
# XGBRegressor                                                                0.72
# GradientBoostingRegressor                                                   0.72
# HistGradientBoostingRegressor                                               0.71
# LassoCV                                                                     0.69
# LassoLarsCV                                                                 0.69
# LarsCV                                                                      0.67
# PoissonRegressor                                                            0.67
# BaggingRegressor                                                            0.66
# ElasticNetCV                                                                0.64
# HuberRegressor                                                              0.63
# LinearSVR                                                                   0.62
# GammaRegressor                                                              0.58
# LassoLarsIC                                                                 0.57
# TransformedTargetRegressor                                                  0.56
# Ridge                                                                       0.56
# RidgeCV                                                                     0.55
# BayesianRidge                                                               0.55
# LassoLars                                                                   0.54
# ElasticNet                                                                  0.54
# KNeighborsRegressor                                                         0.51
# AdaBoostRegressor                                                           0.49
# TweedieRegressor                                                            0.47
# PassiveAggressiveRegressor                                                  0.46
# ExtraTreeRegressor                                                          0.44
# DecisionTreeRegressor                                                       0.12
# DummyRegressor                                                             -0.00
# QuantileRegressor                                                          -0.07
# MLPRegressor                                                               -1.53
# RANSACRegressor                                                          -305.09
# SGDRegressor                                                         -5867012.96
# Lars                          -2278312662647724833361466226014972439411621646...
#
#                                                                             RMSE  \
# Model
# ExtraTreesRegressor                                                         1.70
# LGBMRegressor                                                               1.94
# OrthogonalMatchingPursuit                                                   1.97
# OrthogonalMatchingPursuitCV                                                 1.97
# XGBRegressor                                                                1.99
# GradientBoostingRegressor                                                   1.99
# HistGradientBoostingRegressor                                               2.02
# LassoCV                                                                     2.10
# LassoLarsCV                                                                 2.10
# LarsCV                                                                      2.15
# PoissonRegressor                                                            2.17
# BaggingRegressor                                                            2.21
# ElasticNetCV                                                                2.27
# HuberRegressor                                                              2.28
# LinearSVR                                                                   2.31
# GammaRegressor                                                              2.43
# LassoLarsIC                                                                 2.46
# TransformedTargetRegressor                                                  2.49
# Ridge                                                                       2.49
# RidgeCV                                                                     2.52
# BayesianRidge                                                               2.52
# LassoLars                                                                   2.54
# ElasticNet                                                                  2.54
# KNeighborsRegressor                                                         2.64
# AdaBoostRegressor                                                           2.68
# TweedieRegressor                                                            2.73
# PassiveAggressiveRegressor                                                  2.75
# ExtraTreeRegressor                                                          2.81
# DecisionTreeRegressor                                                       3.52
# DummyRegressor                                                              3.77
# QuantileRegressor                                                           3.89
# MLPRegressor                                                                5.97
# RANSACRegressor                                                            65.75
# SGDRegressor                                                             9103.32
# Lars                          17938987885538347096011929628479779217587071314...
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 36.34
# LGBMRegressor                        1.22
# OrthogonalMatchingPursuit            0.07
# OrthogonalMatchingPursuitCV          0.20
# XGBRegressor                         0.96
# GradientBoostingRegressor           26.56
# HistGradientBoostingRegressor        2.29
# LassoCV                              2.59
# LassoLarsCV                          0.46
# LarsCV                               0.43
# PoissonRegressor                     0.17
# BaggingRegressor                    11.10
# ElasticNetCV                         1.02
# HuberRegressor                       0.93
# LinearSVR                            5.60
# GammaRegressor                       0.13
# LassoLarsIC                          0.20
# TransformedTargetRegressor           0.14
# Ridge                                0.07
# RidgeCV                              0.22
# BayesianRidge                        0.23
# LassoLars                            0.07
# ElasticNet                           0.09
# KNeighborsRegressor                  0.10
# AdaBoostRegressor                   11.33
# TweedieRegressor                     0.09
# PassiveAggressiveRegressor           0.16
# ExtraTreeRegressor                   0.44
# DecisionTreeRegressor                1.80
# DummyRegressor                       0.07
# QuantileRegressor                    4.42
# MLPRegressor                         7.35
# RANSACRegressor                      0.68
# SGDRegressor                         0.11
# Lars                                 0.13  ,                                                               Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.57
# LGBMRegressor                                                               0.44
# OrthogonalMatchingPursuit                                                   0.42
# OrthogonalMatchingPursuitCV                                                 0.42
# XGBRegressor                                                                0.41
# GradientBoostingRegressor                                                   0.41
# HistGradientBoostingRegressor                                               0.39
# LassoCV                                                                     0.34
# LassoLarsCV                                                                 0.34
# LarsCV                                                                      0.31
# PoissonRegressor                                                            0.30
# BaggingRegressor                                                            0.28
# ElasticNetCV                                                                0.23
# HuberRegressor                                                              0.23
# LinearSVR                                                                   0.20
# GammaRegressor                                                              0.12
# LassoLarsIC                                                                 0.10
# TransformedTargetRegressor                                                  0.08
# Ridge                                                                       0.08
# RidgeCV                                                                     0.06
# BayesianRidge                                                               0.05
# LassoLars                                                                   0.04
# ElasticNet                                                                  0.04
# KNeighborsRegressor                                                        -0.03
# AdaBoostRegressor                                                          -0.07
# TweedieRegressor                                                           -0.11
# PassiveAggressiveRegressor                                                 -0.12
# ExtraTreeRegressor                                                         -0.18
# DecisionTreeRegressor                                                      -0.84
# DummyRegressor                                                             -1.11
# QuantileRegressor                                                          -1.25
# MLPRegressor                                                               -4.31
# RANSACRegressor                                                          -641.94
# SGDRegressor                                                        -12323832.57
# Lars                          -4785662047995485589074863244325017315477999505...
#
#                                                                        R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.79
# LGBMRegressor                                                               0.73
# OrthogonalMatchingPursuit                                                   0.73
# OrthogonalMatchingPursuitCV                                                 0.72
# XGBRegressor                                                                0.72
# GradientBoostingRegressor                                                   0.72
# HistGradientBoostingRegressor                                               0.71
# LassoCV                                                                     0.69
# LassoLarsCV                                                                 0.69
# LarsCV                                                                      0.67
# PoissonRegressor                                                            0.67
# BaggingRegressor                                                            0.66
# ElasticNetCV                                                                0.64
# HuberRegressor                                                              0.63
# LinearSVR                                                                   0.62
# GammaRegressor                                                              0.58
# LassoLarsIC                                                                 0.57
# TransformedTargetRegressor                                                  0.56
# Ridge                                                                       0.56
# RidgeCV                                                                     0.55
# BayesianRidge                                                               0.55
# LassoLars                                                                   0.54
# ElasticNet                                                                  0.54
# KNeighborsRegressor                                                         0.51
# AdaBoostRegressor                                                           0.49
# TweedieRegressor                                                            0.47
# PassiveAggressiveRegressor                                                  0.46
# ExtraTreeRegressor                                                          0.44
# DecisionTreeRegressor                                                       0.12
# DummyRegressor                                                             -0.00
# QuantileRegressor                                                          -0.07
# MLPRegressor                                                               -1.53
# RANSACRegressor                                                          -305.09
# SGDRegressor                                                         -5867012.96
# Lars                          -2278312662647724833361466226014972439411621646...
#
#                                                                             RMSE  \
# Model
# ExtraTreesRegressor                                                         1.70
# LGBMRegressor                                                               1.94
# OrthogonalMatchingPursuit                                                   1.97
# OrthogonalMatchingPursuitCV                                                 1.97
# XGBRegressor                                                                1.99
# GradientBoostingRegressor                                                   1.99
# HistGradientBoostingRegressor                                               2.02
# LassoCV                                                                     2.10
# LassoLarsCV                                                                 2.10
# LarsCV                                                                      2.15
# PoissonRegressor                                                            2.17
# BaggingRegressor                                                            2.21
# ElasticNetCV                                                                2.27
# HuberRegressor                                                              2.28
# LinearSVR                                                                   2.31
# GammaRegressor                                                              2.43
# LassoLarsIC                                                                 2.46
# TransformedTargetRegressor                                                  2.49
# Ridge                                                                       2.49
# RidgeCV                                                                     2.52
# BayesianRidge                                                               2.52
# LassoLars                                                                   2.54
# ElasticNet                                                                  2.54
# KNeighborsRegressor                                                         2.64
# AdaBoostRegressor                                                           2.68
# TweedieRegressor                                                            2.73
# PassiveAggressiveRegressor                                                  2.75
# ExtraTreeRegressor                                                          2.81
# DecisionTreeRegressor                                                       3.52
# DummyRegressor                                                              3.77
# QuantileRegressor                                                           3.89
# MLPRegressor                                                                5.97
# RANSACRegressor                                                            65.75
# SGDRegressor                                                             9103.32
# Lars                          17938987885538347096011929628479779217587071314...
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 36.34
# LGBMRegressor                        1.22
# OrthogonalMatchingPursuit            0.07
# OrthogonalMatchingPursuitCV          0.20
# XGBRegressor                         0.96
# GradientBoostingRegressor           26.56
# HistGradientBoostingRegressor        2.29
# LassoCV                              2.59
# LassoLarsCV                          0.46
# LarsCV                               0.43
# PoissonRegressor                     0.17
# BaggingRegressor                    11.10
# ElasticNetCV                         1.02
# HuberRegressor                       0.93
# LinearSVR                            5.60
# GammaRegressor                       0.13
# LassoLarsIC                          0.20
# TransformedTargetRegressor           0.14
# Ridge                                0.07
# RidgeCV                              0.22
# BayesianRidge                        0.23
# LassoLars                            0.07
# ElasticNet                           0.09
# KNeighborsRegressor                  0.10
# AdaBoostRegressor                   11.33
# TweedieRegressor                     0.09
# PassiveAggressiveRegressor           0.16
# ExtraTreeRegressor                   0.44
# DecisionTreeRegressor                1.80
# DummyRegressor                       0.07
# QuantileRegressor                    4.42
# MLPRegressor                         7.35
# RANSACRegressor                      0.68
# SGDRegressor                         0.11
# Lars                                 0.13  ), (                               Adjusted R-Squared  R-Squared    RMSE  \
# Model
# ExtraTreesRegressor                          0.01       0.69    1.97
# BaggingRegressor                            -0.04       0.67    2.03
# XGBRegressor                                -0.07       0.66    2.05
# HistGradientBoostingRegressor               -0.21       0.62    2.18
# LGBMRegressor                               -0.25       0.60    2.22
# GradientBoostingRegressor                   -0.43       0.55    2.37
# LassoLarsIC                                 -0.50       0.52    2.43
# LassoLarsCV                                 -0.51       0.52    2.43
# LassoCV                                     -0.51       0.52    2.43
# TransformedTargetRegressor                  -0.51       0.52    2.44
# Ridge                                       -0.51       0.52    2.44
# RidgeCV                                     -0.51       0.52    2.44
# BayesianRidge                               -0.52       0.52    2.44
# ElasticNetCV                                -0.52       0.52    2.45
# LinearSVR                                   -0.53       0.52    2.45
# HuberRegressor                              -0.53       0.52    2.45
# SGDRegressor                                -0.55       0.51    2.47
# OrthogonalMatchingPursuit                   -0.61       0.49    2.51
# OrthogonalMatchingPursuitCV                 -0.61       0.49    2.51
# LarsCV                                      -0.66       0.48    2.56
# PoissonRegressor                            -0.67       0.47    2.56
# MLPRegressor                                -0.71       0.46    2.59
# TweedieRegressor                            -0.87       0.41    2.71
# GammaRegressor                              -0.88       0.41    2.72
# ExtraTreeRegressor                          -0.97       0.38    2.78
# ElasticNet                                  -0.97       0.38    2.78
# DecisionTreeRegressor                       -1.04       0.36    2.83
# AdaBoostRegressor                           -1.06       0.35    2.84
# LassoLars                                   -1.08       0.34    2.86
# KNeighborsRegressor                         -1.11       0.33    2.88
# PassiveAggressiveRegressor                  -2.02       0.05    3.45
# DummyRegressor                              -2.17      -0.00    3.53
# QuantileRegressor                           -2.22      -0.02    3.56
# Lars                                       -17.61      -4.88    8.55
# RANSACRegressor                       -1214077.28 -383392.14 2184.78
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 78.54
# BaggingRegressor                    25.45
# XGBRegressor                         1.18
# HistGradientBoostingRegressor        3.19
# LGBMRegressor                        1.49
# GradientBoostingRegressor           54.38
# LassoLarsIC                          0.38
# LassoLarsCV                          0.71
# LassoCV                              4.75
# TransformedTargetRegressor           0.30
# Ridge                                0.13
# RidgeCV                              0.51
# BayesianRidge                        0.49
# ElasticNetCV                         4.52
# LinearSVR                           15.14
# HuberRegressor                       2.00
# SGDRegressor                         0.83
# OrthogonalMatchingPursuit            0.12
# OrthogonalMatchingPursuitCV          0.40
# LarsCV                               0.71
# PoissonRegressor                     0.32
# MLPRegressor                        18.00
# TweedieRegressor                     0.18
# GammaRegressor                       0.25
# ExtraTreeRegressor                   0.89
# ElasticNet                           0.17
# DecisionTreeRegressor                4.29
# AdaBoostRegressor                   23.28
# LassoLars                            0.13
# KNeighborsRegressor                  0.15
# PassiveAggressiveRegressor           0.39
# DummyRegressor                       0.11
# QuantileRegressor                   17.88
# Lars                                 0.19
# RANSACRegressor                      0.99  ,                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# ExtraTreesRegressor                          0.01       0.69    1.97
# BaggingRegressor                            -0.04       0.67    2.03
# XGBRegressor                                -0.07       0.66    2.05
# HistGradientBoostingRegressor               -0.21       0.62    2.18
# LGBMRegressor                               -0.25       0.60    2.22
# GradientBoostingRegressor                   -0.43       0.55    2.37
# LassoLarsIC                                 -0.50       0.52    2.43
# LassoLarsCV                                 -0.51       0.52    2.43
# LassoCV                                     -0.51       0.52    2.43
# TransformedTargetRegressor                  -0.51       0.52    2.44
# Ridge                                       -0.51       0.52    2.44
# RidgeCV                                     -0.51       0.52    2.44
# BayesianRidge                               -0.52       0.52    2.44
# ElasticNetCV                                -0.52       0.52    2.45
# LinearSVR                                   -0.53       0.52    2.45
# HuberRegressor                              -0.53       0.52    2.45
# SGDRegressor                                -0.55       0.51    2.47
# OrthogonalMatchingPursuit                   -0.61       0.49    2.51
# OrthogonalMatchingPursuitCV                 -0.61       0.49    2.51
# LarsCV                                      -0.66       0.48    2.56
# PoissonRegressor                            -0.67       0.47    2.56
# MLPRegressor                                -0.71       0.46    2.59
# TweedieRegressor                            -0.87       0.41    2.71
# GammaRegressor                              -0.88       0.41    2.72
# ExtraTreeRegressor                          -0.97       0.38    2.78
# ElasticNet                                  -0.97       0.38    2.78
# DecisionTreeRegressor                       -1.04       0.36    2.83
# AdaBoostRegressor                           -1.06       0.35    2.84
# LassoLars                                   -1.08       0.34    2.86
# KNeighborsRegressor                         -1.11       0.33    2.88
# PassiveAggressiveRegressor                  -2.02       0.05    3.45
# DummyRegressor                              -2.17      -0.00    3.53
# QuantileRegressor                           -2.22      -0.02    3.56
# Lars                                       -17.61      -4.88    8.55
# RANSACRegressor                       -1214077.28 -383392.14 2184.78
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 78.54
# BaggingRegressor                    25.45
# XGBRegressor                         1.18
# HistGradientBoostingRegressor        3.19
# LGBMRegressor                        1.49
# GradientBoostingRegressor           54.38
# LassoLarsIC                          0.38
# LassoLarsCV                          0.71
# LassoCV                              4.75
# TransformedTargetRegressor           0.30
# Ridge                                0.13
# RidgeCV                              0.51
# BayesianRidge                        0.49
# ElasticNetCV                         4.52
# LinearSVR                           15.14
# HuberRegressor                       2.00
# SGDRegressor                         0.83
# OrthogonalMatchingPursuit            0.12
# OrthogonalMatchingPursuitCV          0.40
# LarsCV                               0.71
# PoissonRegressor                     0.32
# MLPRegressor                        18.00
# TweedieRegressor                     0.18
# GammaRegressor                       0.25
# ExtraTreeRegressor                   0.89
# ElasticNet                           0.17
# DecisionTreeRegressor                4.29
# AdaBoostRegressor                   23.28
# LassoLars                            0.13
# KNeighborsRegressor                  0.15
# PassiveAggressiveRegressor           0.39
# DummyRegressor                       0.11
# QuantileRegressor                   17.88
# Lars                                 0.19
# RANSACRegressor                      0.99  ), (                               Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.01       0.52  1.48       82.70
# XGBRegressor                                -0.24       0.39  1.66        1.04
# BaggingRegressor                            -0.29       0.37  1.69       26.16
# LGBMRegressor                               -0.29       0.36  1.69        1.53
# HistGradientBoostingRegressor               -0.34       0.34  1.72        2.95
# GradientBoostingRegressor                   -0.46       0.28  1.80       48.57
# HuberRegressor                              -0.46       0.28  1.80        2.00
# LassoLarsIC                                 -0.48       0.27  1.81        0.36
# TransformedTargetRegressor                  -0.48       0.27  1.81        0.37
# Ridge                                       -0.48       0.27  1.81        0.12
# LassoLarsCV                                 -0.48       0.27  1.81        0.65
# RidgeCV                                     -0.49       0.27  1.81        0.47
# LassoCV                                     -0.49       0.27  1.81        4.42
# ElasticNetCV                                -0.49       0.27  1.82        3.53
# BayesianRidge                               -0.49       0.27  1.82        0.48
# LinearSVR                                   -0.51       0.26  1.83       14.63
# SGDRegressor                                -0.51       0.26  1.83        0.54
# PoissonRegressor                            -0.52       0.26  1.83        0.25
# OrthogonalMatchingPursuit                   -0.52       0.25  1.84        0.12
# OrthogonalMatchingPursuitCV                 -0.52       0.25  1.84        0.41
# KNeighborsRegressor                         -0.62       0.21  1.89        0.14
# GammaRegressor                              -0.66       0.18  1.92        0.19
# LarsCV                                      -0.66       0.18  1.92        0.62
# TweedieRegressor                            -0.68       0.18  1.93        0.16
# ElasticNet                                  -0.90       0.07  2.05        0.15
# AdaBoostRegressor                           -0.95       0.04  2.08       10.67
# MLPRegressor                                -1.02       0.01  2.11       15.44
# QuantileRegressor                           -1.04      -0.00  2.12       17.40
# DummyRegressor                              -1.11      -0.04  2.16        0.11
# LassoLars                                   -1.11      -0.04  2.16        0.12
# ExtraTreeRegressor                          -1.49      -0.22  2.35        0.97
# DecisionTreeRegressor                       -1.94      -0.44  2.55        4.02
# PassiveAggressiveRegressor                  -2.17      -0.56  2.65        0.37
# Lars                                        -7.48      -3.17  4.34        0.16
# RANSACRegressor                          -2235.19   -1097.96 70.39        0.94,                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.01       0.52  1.48       82.70
# XGBRegressor                                -0.24       0.39  1.66        1.04
# BaggingRegressor                            -0.29       0.37  1.69       26.16
# LGBMRegressor                               -0.29       0.36  1.69        1.53
# HistGradientBoostingRegressor               -0.34       0.34  1.72        2.95
# GradientBoostingRegressor                   -0.46       0.28  1.80       48.57
# HuberRegressor                              -0.46       0.28  1.80        2.00
# LassoLarsIC                                 -0.48       0.27  1.81        0.36
# TransformedTargetRegressor                  -0.48       0.27  1.81        0.37
# Ridge                                       -0.48       0.27  1.81        0.12
# LassoLarsCV                                 -0.48       0.27  1.81        0.65
# RidgeCV                                     -0.49       0.27  1.81        0.47
# LassoCV                                     -0.49       0.27  1.81        4.42
# ElasticNetCV                                -0.49       0.27  1.82        3.53
# BayesianRidge                               -0.49       0.27  1.82        0.48
# LinearSVR                                   -0.51       0.26  1.83       14.63
# SGDRegressor                                -0.51       0.26  1.83        0.54
# PoissonRegressor                            -0.52       0.26  1.83        0.25
# OrthogonalMatchingPursuit                   -0.52       0.25  1.84        0.12
# OrthogonalMatchingPursuitCV                 -0.52       0.25  1.84        0.41
# KNeighborsRegressor                         -0.62       0.21  1.89        0.14
# GammaRegressor                              -0.66       0.18  1.92        0.19
# LarsCV                                      -0.66       0.18  1.92        0.62
# TweedieRegressor                            -0.68       0.18  1.93        0.16
# ElasticNet                                  -0.90       0.07  2.05        0.15
# AdaBoostRegressor                           -0.95       0.04  2.08       10.67
# MLPRegressor                                -1.02       0.01  2.11       15.44
# QuantileRegressor                           -1.04      -0.00  2.12       17.40
# DummyRegressor                              -1.11      -0.04  2.16        0.11
# LassoLars                                   -1.11      -0.04  2.16        0.12
# ExtraTreeRegressor                          -1.49      -0.22  2.35        0.97
# DecisionTreeRegressor                       -1.94      -0.44  2.55        4.02
# PassiveAggressiveRegressor                  -2.17      -0.56  2.65        0.37
# Lars                                        -7.48      -3.17  4.34        0.16
# RANSACRegressor                          -2235.19   -1097.96 70.39        0.94), (                               Adjusted R-Squared    R-Squared     RMSE  \
# Model
# ExtraTreesRegressor                          0.49         0.81     1.38
# HistGradientBoostingRegressor                0.36         0.76     1.54
# LGBMRegressor                                0.36         0.76     1.54
# XGBRegressor                                 0.26         0.72     1.65
# LassoCV                                      0.21         0.70     1.71
# ElasticNetCV                                 0.21         0.70     1.71
# BayesianRidge                                0.20         0.70     1.72
# HuberRegressor                               0.20         0.70     1.72
# Ridge                                        0.20         0.70     1.73
# LassoLarsIC                                  0.19         0.69     1.73
# LassoLarsCV                                  0.19         0.69     1.73
# RidgeCV                                      0.19         0.69     1.73
# TransformedTargetRegressor                   0.19         0.69     1.74
# BaggingRegressor                             0.18         0.69     1.74
# GradientBoostingRegressor                    0.17         0.69     1.75
# LinearSVR                                    0.17         0.68     1.76
# OrthogonalMatchingPursuit                    0.15         0.68     1.78
# SGDRegressor                                 0.12         0.67     1.80
# OrthogonalMatchingPursuitCV                  0.11         0.66     1.82
# PoissonRegressor                             0.07         0.65     1.86
# LarsCV                                      -0.01         0.62     1.94
# KNeighborsRegressor                         -0.02         0.61     1.94
# TweedieRegressor                            -0.06         0.60     1.99
# GammaRegressor                              -0.07         0.59     2.00
# ExtraTreeRegressor                          -0.20         0.55     2.11
# ElasticNet                                  -0.26         0.52     2.16
# MLPRegressor                                -0.28         0.51     2.18
# LassoLars                                   -0.35         0.49     2.24
# AdaBoostRegressor                           -0.47         0.44     2.34
# DecisionTreeRegressor                       -0.58         0.40     2.42
# PassiveAggressiveRegressor                  -1.19         0.17     2.85
# DummyRegressor                              -1.65        -0.00     3.13
# QuantileRegressor                           -1.65        -0.00     3.13
# RANSACRegressor                           -142.92       -53.56    23.11
# Lars                                -126445908.79 -47936209.58 21658.90
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 35.13
# HistGradientBoostingRegressor        2.97
# LGBMRegressor                        1.49
# XGBRegressor                         1.13
# LassoCV                              3.92
# ElasticNetCV                         2.83
# BayesianRidge                        0.23
# HuberRegressor                       1.02
# Ridge                                0.09
# LassoLarsIC                          0.22
# LassoLarsCV                          0.47
# RidgeCV                              0.29
# TransformedTargetRegressor           0.19
# BaggingRegressor                    11.19
# GradientBoostingRegressor           26.08
# LinearSVR                            5.95
# OrthogonalMatchingPursuit            0.08
# SGDRegressor                         0.42
# OrthogonalMatchingPursuitCV          0.22
# PoissonRegressor                     0.22
# LarsCV                               0.44
# KNeighborsRegressor                  0.08
# TweedieRegressor                     0.10
# GammaRegressor                       0.09
# ExtraTreeRegressor                   0.42
# ElasticNet                           0.09
# MLPRegressor                        10.58
# LassoLars                            0.07
# AdaBoostRegressor                   10.58
# DecisionTreeRegressor                1.81
# PassiveAggressiveRegressor           0.25
# DummyRegressor                       0.06
# QuantileRegressor                    5.70
# RANSACRegressor                      0.76
# Lars                                 0.09  ,                                Adjusted R-Squared    R-Squared     RMSE  \
# Model
# ExtraTreesRegressor                          0.49         0.81     1.38
# HistGradientBoostingRegressor                0.36         0.76     1.54
# LGBMRegressor                                0.36         0.76     1.54
# XGBRegressor                                 0.26         0.72     1.65
# LassoCV                                      0.21         0.70     1.71
# ElasticNetCV                                 0.21         0.70     1.71
# BayesianRidge                                0.20         0.70     1.72
# HuberRegressor                               0.20         0.70     1.72
# Ridge                                        0.20         0.70     1.73
# LassoLarsIC                                  0.19         0.69     1.73
# LassoLarsCV                                  0.19         0.69     1.73
# RidgeCV                                      0.19         0.69     1.73
# TransformedTargetRegressor                   0.19         0.69     1.74
# BaggingRegressor                             0.18         0.69     1.74
# GradientBoostingRegressor                    0.17         0.69     1.75
# LinearSVR                                    0.17         0.68     1.76
# OrthogonalMatchingPursuit                    0.15         0.68     1.78
# SGDRegressor                                 0.12         0.67     1.80
# OrthogonalMatchingPursuitCV                  0.11         0.66     1.82
# PoissonRegressor                             0.07         0.65     1.86
# LarsCV                                      -0.01         0.62     1.94
# KNeighborsRegressor                         -0.02         0.61     1.94
# TweedieRegressor                            -0.06         0.60     1.99
# GammaRegressor                              -0.07         0.59     2.00
# ExtraTreeRegressor                          -0.20         0.55     2.11
# ElasticNet                                  -0.26         0.52     2.16
# MLPRegressor                                -0.28         0.51     2.18
# LassoLars                                   -0.35         0.49     2.24
# AdaBoostRegressor                           -0.47         0.44     2.34
# DecisionTreeRegressor                       -0.58         0.40     2.42
# PassiveAggressiveRegressor                  -1.19         0.17     2.85
# DummyRegressor                              -1.65        -0.00     3.13
# QuantileRegressor                           -1.65        -0.00     3.13
# RANSACRegressor                           -142.92       -53.56    23.11
# Lars                                -126445908.79 -47936209.58 21658.90
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 35.13
# HistGradientBoostingRegressor        2.97
# LGBMRegressor                        1.49
# XGBRegressor                         1.13
# LassoCV                              3.92
# ElasticNetCV                         2.83
# BayesianRidge                        0.23
# HuberRegressor                       1.02
# Ridge                                0.09
# LassoLarsIC                          0.22
# LassoLarsCV                          0.47
# RidgeCV                              0.29
# TransformedTargetRegressor           0.19
# BaggingRegressor                    11.19
# GradientBoostingRegressor           26.08
# LinearSVR                            5.95
# OrthogonalMatchingPursuit            0.08
# SGDRegressor                         0.42
# OrthogonalMatchingPursuitCV          0.22
# PoissonRegressor                     0.22
# LarsCV                               0.44
# KNeighborsRegressor                  0.08
# TweedieRegressor                     0.10
# GammaRegressor                       0.09
# ExtraTreeRegressor                   0.42
# ElasticNet                           0.09
# MLPRegressor                        10.58
# LassoLars                            0.07
# AdaBoostRegressor                   10.58
# DecisionTreeRegressor                1.81
# PassiveAggressiveRegressor           0.25
# DummyRegressor                       0.06
# QuantileRegressor                    5.70
# RANSACRegressor                      0.76
# Lars                                 0.09  ), (                               Adjusted R-Squared  R-Squared   RMSE  \
# Model
# ExtraTreesRegressor                          0.60       0.82   2.23
# BaggingRegressor                             0.58       0.81   2.30
# LGBMRegressor                                0.58       0.81   2.30
# HistGradientBoostingRegressor                0.56       0.80   2.36
# XGBRegressor                                 0.54       0.80   2.40
# HuberRegressor                               0.49       0.77   2.54
# LinearSVR                                    0.48       0.77   2.54
# LassoLarsIC                                  0.48       0.77   2.55
# LassoLarsCV                                  0.48       0.77   2.56
# Ridge                                        0.48       0.77   2.56
# BayesianRidge                                0.48       0.77   2.56
# LassoCV                                      0.48       0.77   2.56
# RidgeCV                                      0.48       0.77   2.57
# TransformedTargetRegressor                   0.48       0.77   2.57
# ElasticNetCV                                 0.47       0.76   2.59
# GradientBoostingRegressor                    0.46       0.76   2.60
# SGDRegressor                                 0.46       0.76   2.61
# OrthogonalMatchingPursuit                    0.45       0.75   2.64
# OrthogonalMatchingPursuitCV                  0.45       0.75   2.64
# PoissonRegressor                             0.42       0.74   2.69
# MLPRegressor                                 0.42       0.74   2.70
# ExtraTreeRegressor                           0.41       0.74   2.72
# DecisionTreeRegressor                        0.40       0.73   2.74
# LarsCV                                       0.36       0.71   2.83
# AdaBoostRegressor                            0.31       0.69   2.95
# GammaRegressor                               0.28       0.68   3.00
# TweedieRegressor                             0.22       0.65   3.14
# KNeighborsRegressor                          0.21       0.65   3.14
# PassiveAggressiveRegressor                   0.14       0.62   3.29
# ElasticNet                                   0.09       0.60   3.37
# LassoLars                                    0.08       0.59   3.41
# DummyRegressor                              -1.54      -0.13   5.65
# QuantileRegressor                           -1.89      -0.29   6.02
# RANSACRegressor                            -18.18      -7.57  15.53
# Lars                                     -3556.06   -1588.32 211.47
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 35.60
# BaggingRegressor                    11.90
# ...
# ExtraTreeRegressor                                   0.29            2.10
# Ridge                                                0.29            2.11
# TransformedTargetRegressor                           0.29            2.11
# LassoCV                                              0.28            2.12
# ElasticNetCV                                         0.28            2.12
# LassoLarsCV                                          0.28            2.12
# GammaRegressor                                       0.26            2.15
# OrthogonalMatchingPursuit                            0.24            2.17
# TweedieRegressor                                     0.23            2.18
# OrthogonalMatchingPursuitCV                          0.22            2.20
# SGDRegressor                                         0.20            2.23
# LarsCV                                               0.13            2.33
# ElasticNet                                           0.11            2.35
# KNeighborsRegressor                                  0.10            2.37
# DecisionTreeRegressor                                0.10            2.37
# LassoLars                                            0.10            2.37
# AdaBoostRegressor                                    0.09            2.38
# QuantileRegressor                                   -0.01            2.50
# DummyRegressor                                      -0.03            2.53
# PassiveAggressiveRegressor                          -0.27            2.82
# Lars                                               -11.99            9.00
# RANSACRegressor               -53029500885354791567360.00 574929110444.98
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 13.48
# XGBRegressor                         0.98
# HistGradientBoostingRegressor        3.46
# LGBMRegressor                        1.28
# MLPRegressor                         2.69
# BaggingRegressor                     3.65
# GradientBoostingRegressor            9.74
# LinearSVR                            2.24
# HuberRegressor                       0.59
# LassoLarsIC                          0.14
# PoissonRegressor                     0.10
# BayesianRidge                        0.11
# RidgeCV                              0.12
# ExtraTreeRegressor                   0.18
# Ridge                                0.05
# TransformedTargetRegressor           0.09
# LassoCV                              1.92
# ElasticNetCV                         1.16
# LassoLarsCV                          0.33
# GammaRegressor                       0.06
# OrthogonalMatchingPursuit            0.05
# TweedieRegressor                     0.06
# OrthogonalMatchingPursuitCV          0.10
# SGDRegressor                         0.17
# LarsCV                               0.33
# ElasticNet                           0.05
# KNeighborsRegressor                  0.06
# DecisionTreeRegressor                0.59
# LassoLars                            0.05
# AdaBoostRegressor                    3.68
# QuantileRegressor                    1.32
# DummyRegressor                       0.04
# PassiveAggressiveRegressor           0.10
# Lars                                 0.10
# RANSACRegressor                      0.78  ,                                         Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                  -3.35
# XGBRegressor                                         -4.93
# HistGradientBoostingRegressor                        -6.03
# LGBMRegressor                                        -6.27
# MLPRegressor                                         -6.45
# BaggingRegressor                                     -6.78
# GradientBoostingRegressor                            -7.14
# LinearSVR                                            -7.19
# HuberRegressor                                       -7.50
# LassoLarsIC                                          -7.69
# PoissonRegressor                                     -7.80
# BayesianRidge                                        -7.82
# RidgeCV                                              -7.84
# ExtraTreeRegressor                                   -7.90
# Ridge                                                -7.93
# TransformedTargetRegressor                           -7.94
# LassoCV                                              -8.04
# ElasticNetCV                                         -8.05
# LassoLarsCV                                          -8.06
# GammaRegressor                                       -8.35
# OrthogonalMatchingPursuit                            -8.51
# TweedieRegressor                                     -8.61
# OrthogonalMatchingPursuitCV                          -8.75
# SGDRegressor                                         -9.05
# LarsCV                                               -9.93
# ElasticNet                                          -10.12
# KNeighborsRegressor                                 -10.30
# DecisionTreeRegressor                               -10.32
# LassoLars                                           -10.35
# AdaBoostRegressor                                   -10.37
# QuantileRegressor                                   -11.62
# DummyRegressor                                      -11.90
# PassiveAggressiveRegressor                          -14.97
# Lars                                               -162.14
# RANSACRegressor               -665814844449454569816064.00
#
#                                                 R-Squared            RMSE  \
# Model
# ExtraTreesRegressor                                  0.65            1.47
# XGBRegressor                                         0.53            1.72
# HistGradientBoostingRegressor                        0.44            1.87
# LGBMRegressor                                        0.42            1.90
# MLPRegressor                                         0.41            1.92
# BaggingRegressor                                     0.38            1.96
# GradientBoostingRegressor                            0.35            2.01
# LinearSVR                                            0.35            2.02
# HuberRegressor                                       0.32            2.05
# LassoLarsIC                                          0.31            2.08
# PoissonRegressor                                     0.30            2.09
# BayesianRidge                                        0.30            2.09
# RidgeCV                                              0.30            2.10
# ExtraTreeRegressor                                   0.29            2.10
# Ridge                                                0.29            2.11
# TransformedTargetRegressor                           0.29            2.11
# LassoCV                                              0.28            2.12
# ElasticNetCV                                         0.28            2.12
# LassoLarsCV                                          0.28            2.12
# GammaRegressor                                       0.26            2.15
# OrthogonalMatchingPursuit                            0.24            2.17
# TweedieRegressor                                     0.23            2.18
# OrthogonalMatchingPursuitCV                          0.22            2.20
# SGDRegressor                                         0.20            2.23
# LarsCV                                               0.13            2.33
# ElasticNet                                           0.11            2.35
# KNeighborsRegressor                                  0.10            2.37
# DecisionTreeRegressor                                0.10            2.37
# LassoLars                                            0.10            2.37
# AdaBoostRegressor                                    0.09            2.38
# QuantileRegressor                                   -0.01            2.50
# DummyRegressor                                      -0.03            2.53
# PassiveAggressiveRegressor                          -0.27            2.82
# Lars                                               -11.99            9.00
# RANSACRegressor               -53029500885354791567360.00 574929110444.98
#
#                                Time Taken
# Model
# ExtraTreesRegressor                 13.48
# XGBRegressor                         0.98
# HistGradientBoostingRegressor        3.46
# LGBMRegressor                        1.28
# MLPRegressor                         2.69
# BaggingRegressor                     3.65
# GradientBoostingRegressor            9.74
# LinearSVR                            2.24
# HuberRegressor                       0.59
# LassoLarsIC                          0.14
# PoissonRegressor                     0.10
# BayesianRidge                        0.11
# RidgeCV                              0.12
# ExtraTreeRegressor                   0.18
# Ridge                                0.05
# TransformedTargetRegressor           0.09
# LassoCV                              1.92
# ElasticNetCV                         1.16
# LassoLarsCV                          0.33
# GammaRegressor                       0.06
# OrthogonalMatchingPursuit            0.05
# TweedieRegressor                     0.06
# OrthogonalMatchingPursuitCV          0.10
# SGDRegressor                         0.17
# LarsCV                               0.33
# ElasticNet                           0.05
# KNeighborsRegressor                  0.06
# DecisionTreeRegressor                0.59
# LassoLars                            0.05
# AdaBoostRegressor                    3.68
# QuantileRegressor                    1.32
# DummyRegressor                       0.04
# PassiveAggressiveRegressor           0.10
# Lars                                 0.10
# RANSACRegressor                      0.78  ), (                               Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -0.37       0.62  1.47       20.97
# BaggingRegressor                            -0.83       0.49  1.70        6.30
# HistGradientBoostingRegressor               -0.84       0.48  1.70        3.07
# LGBMRegressor                               -0.85       0.48  1.71        1.62
# XGBRegressor                                -0.89       0.47  1.72        1.34
# GradientBoostingRegressor                   -1.45       0.31  1.96       17.23
# LassoCV                                     -1.50       0.30  1.98        2.39
# LassoLarsCV                                 -1.50       0.30  1.98        0.36
# ElasticNetCV                                -1.51       0.30  1.98        1.43
# LassoLarsIC                                 -1.54       0.29  1.99        0.16
# PoissonRegressor                            -1.54       0.29  2.00        0.09
# AdaBoostRegressor                           -1.55       0.28  2.00        6.87
# OrthogonalMatchingPursuit                   -1.56       0.28  2.00        0.06
# Ridge                                       -1.56       0.28  2.00        0.06
# TransformedTargetRegressor                  -1.56       0.28  2.00        0.10
# RidgeCV                                     -1.56       0.28  2.00        0.15
# KNeighborsRegressor                         -1.56       0.28  2.00        0.06
# BayesianRidge                               -1.57       0.28  2.01        0.14
# LarsCV                                      -1.59       0.27  2.02        0.37
# OrthogonalMatchingPursuitCV                 -1.61       0.27  2.02        0.12
# GammaRegressor                              -1.66       0.25  2.04        0.06
# TweedieRegressor                            -1.67       0.25  2.05        0.07
# HuberRegressor                              -1.69       0.25  2.06        0.65
# LinearSVR                                   -1.73       0.23  2.07        2.56
# SGDRegressor                                -1.73       0.23  2.07        0.20
# MLPRegressor                                -1.80       0.21  2.10        4.96
# ElasticNet                                  -1.93       0.18  2.14        0.06
# LassoLars                                   -2.18       0.11  2.24        0.06
# DecisionTreeRegressor                       -2.44       0.04  2.32        1.09
# DummyRegressor                              -2.57      -0.00  2.37        0.05
# ExtraTreeRegressor                          -2.63      -0.02  2.39        0.29
# QuantileRegressor                           -2.92      -0.10  2.48        1.97
# PassiveAggressiveRegressor                  -4.62      -0.57  2.97        0.12
# Lars                                       -25.22      -6.35  6.42        0.09
# RANSACRegressor                            -56.92     -15.23  9.54        0.87,                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -0.37       0.62  1.47       20.97
# BaggingRegressor                            -0.83       0.49  1.70        6.30
# HistGradientBoostingRegressor               -0.84       0.48  1.70        3.07
# LGBMRegressor                               -0.85       0.48  1.71        1.62
# XGBRegressor                                -0.89       0.47  1.72        1.34
# GradientBoostingRegressor                   -1.45       0.31  1.96       17.23
# LassoCV                                     -1.50       0.30  1.98        2.39
# LassoLarsCV                                 -1.50       0.30  1.98        0.36
# ElasticNetCV                                -1.51       0.30  1.98        1.43
# LassoLarsIC                                 -1.54       0.29  1.99        0.16
# PoissonRegressor                            -1.54       0.29  2.00        0.09
# AdaBoostRegressor                           -1.55       0.28  2.00        6.87
# OrthogonalMatchingPursuit                   -1.56       0.28  2.00        0.06
# Ridge                                       -1.56       0.28  2.00        0.06
# TransformedTargetRegressor                  -1.56       0.28  2.00        0.10
# RidgeCV                                     -1.56       0.28  2.00        0.15
# KNeighborsRegressor                         -1.56       0.28  2.00        0.06
# BayesianRidge                               -1.57       0.28  2.01        0.14
# LarsCV                                      -1.59       0.27  2.02        0.37
# OrthogonalMatchingPursuitCV                 -1.61       0.27  2.02        0.12
# GammaRegressor                              -1.66       0.25  2.04        0.06
# TweedieRegressor                            -1.67       0.25  2.05        0.07
# HuberRegressor                              -1.69       0.25  2.06        0.65
# LinearSVR                                   -1.73       0.23  2.07        2.56
# SGDRegressor                                -1.73       0.23  2.07        0.20
# MLPRegressor                                -1.80       0.21  2.10        4.96
# ElasticNet                                  -1.93       0.18  2.14        0.06
# LassoLars                                   -2.18       0.11  2.24        0.06
# DecisionTreeRegressor                       -2.44       0.04  2.32        1.09
# DummyRegressor                              -2.57      -0.00  2.37        0.05
# ExtraTreeRegressor                          -2.63      -0.02  2.39        0.29
# QuantileRegressor                           -2.92      -0.10  2.48        1.97
# PassiveAggressiveRegressor                  -4.62      -0.57  2.97        0.12
# Lars                                       -25.22      -6.35  6.42        0.09
# RANSACRegressor                            -56.92     -15.23  9.54        0.87)])

# %%
for p_num in lazy_predict_results.keys():
    print(f'Patient: {p_num}')
    models = lazy_predict_results[p_num]
    display(models[0].head())
# Out:
# Patient: p01
#                              Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                        0.57       0.79  1.70       36.34
# LGBMRegressor                              0.44       0.73  1.94        1.22
# OrthogonalMatchingPursuit                  0.42       0.73  1.97        0.07
# OrthogonalMatchingPursuitCV                0.42       0.72  1.97        0.20
# XGBRegressor                               0.41       0.72  1.99        0.96
# Patient: p02
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.01       0.69  1.97       78.54
# BaggingRegressor                            -0.04       0.67  2.03       25.45
# XGBRegressor                                -0.07       0.66  2.05        1.18
# HistGradientBoostingRegressor               -0.21       0.62  2.18        3.19
# LGBMRegressor                               -0.25       0.60  2.22        1.49
# Patient: p04
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.01       0.52  1.48       82.70
# XGBRegressor                                -0.24       0.39  1.66        1.04
# BaggingRegressor                            -0.29       0.37  1.69       26.16
# LGBMRegressor                               -0.29       0.36  1.69        1.53
# HistGradientBoostingRegressor               -0.34       0.34  1.72        2.95
# Patient: p05
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.49       0.81  1.38       35.13
# HistGradientBoostingRegressor                0.36       0.76  1.54        2.97
# LGBMRegressor                                0.36       0.76  1.54        1.49
# XGBRegressor                                 0.26       0.72  1.65        1.13
# LassoCV                                      0.21       0.70  1.71        3.92
# Patient: p06
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.60       0.82  2.23       35.60
# BaggingRegressor                             0.58       0.81  2.30       11.90
# LGBMRegressor                                0.58       0.81  2.30        1.41
# HistGradientBoostingRegressor                0.56       0.80  2.36        2.04
# XGBRegressor                                 0.54       0.80  2.40        1.15
# Patient: p10
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -2.85       0.43  1.44       97.10
# XGBRegressor                                -3.32       0.36  1.53        1.21
# HistGradientBoostingRegressor               -3.38       0.35  1.54        3.93
# BaggingRegressor                            -3.60       0.32  1.58       34.29
# LGBMRegressor                               -3.67       0.31  1.59        1.63
# Patient: p11
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.11       0.60  1.34       79.25
# BaggingRegressor                            -0.08       0.51  1.47       20.86
# XGBRegressor                                -0.22       0.44  1.57        1.21
# HistGradientBoostingRegressor               -0.23       0.44  1.57        3.58
# LGBMRegressor                               -0.31       0.40  1.62        1.76
# Patient: p12
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.46       0.74  1.53      121.55
# XGBRegressor                                 0.39       0.71  1.62        2.21
# LGBMRegressor                                0.38       0.71  1.63        2.76
# HistGradientBoostingRegressor                0.36       0.70  1.66        5.55
# BaggingRegressor                             0.35       0.69  1.67       95.39
# Patient: p15
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -0.16       0.46  2.17       17.55
# LGBMRegressor                               -0.20       0.44  2.21        1.19
# HistGradientBoostingRegressor               -0.28       0.41  2.27        3.46
# XGBRegressor                                -0.41       0.34  2.39        0.82
# GradientBoostingRegressor                   -0.46       0.32  2.43        8.82
# Patient: p16
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.17       0.58  1.02       18.78
# HistGradientBoostingRegressor               -0.05       0.47  1.15        3.34
# LGBMRegressor                               -0.05       0.47  1.15        1.55
# XGBRegressor                                -0.11       0.44  1.19        1.41
# GradientBoostingRegressor                   -0.18       0.41  1.22       14.26
# Patient: p18
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -0.10       0.70  2.16       16.17
# XGBRegressor                                -0.19       0.67  2.26        1.15
# LGBMRegressor                               -0.23       0.66  2.29        1.31
# HistGradientBoostingRegressor               -0.28       0.65  2.34        3.54
# BaggingRegressor                            -0.35       0.63  2.40        4.04
# Patient: p19
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.22       0.69  1.43       17.15
# HistGradientBoostingRegressor                0.14       0.66  1.51        3.14
# LGBMRegressor                                0.11       0.65  1.53        1.37
# BaggingRegressor                             0.09       0.65  1.54        4.86
# XGBRegressor                                 0.06       0.63  1.57        1.23
# Patient: p21
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.09       0.87  1.49       14.17
# XGBRegressor                                -0.48       0.79  1.91        1.03
# HistGradientBoostingRegressor               -0.53       0.78  1.94        3.10
# LGBMRegressor                               -0.55       0.78  1.96        1.52
# BaggingRegressor                            -0.69       0.76  2.04        3.51
# Patient: p22
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -3.35       0.65  1.47       13.48
# XGBRegressor                                -4.93       0.53  1.72        0.98
# HistGradientBoostingRegressor               -6.03       0.44  1.87        3.46
# LGBMRegressor                               -6.27       0.42  1.90        1.28
# MLPRegressor                                -6.45       0.41  1.92        2.69
# Patient: p24
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                         -0.37       0.62  1.47       20.97
# BaggingRegressor                            -0.83       0.49  1.70        6.30
# HistGradientBoostingRegressor               -0.84       0.48  1.70        3.07
# LGBMRegressor                               -0.85       0.48  1.71        1.62
# XGBRegressor                                -0.89       0.47  1.72        1.34

# %%
lazy_predict_results['p01'][0].head()
# Out:
#                              Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                        0.57       0.79  1.70       36.34
# LGBMRegressor                              0.44       0.73  1.94        1.22
# OrthogonalMatchingPursuit                  0.42       0.73  1.97        0.07
# OrthogonalMatchingPursuitCV                0.42       0.72  1.97        0.20
# XGBRegressor                               0.41       0.72  1.99        0.96
