# %% [markdown]
# # Hyperparameter Tuning

# %%
from data import load_data

train_data, test_data = load_data()

unique_patients = test_data['p_num'].unique()
train_data = train_data[train_data['p_num'].isin(unique_patients)]
test_data = test_data[test_data['p_num'].isin(unique_patients)]

train_data.head()
# Out:
#       p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# id
# p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN      9.7
# p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN      9.2
# p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN      8.7
# p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN      8.4
# p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN      8.1
#
#        bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  activity-0:30  \
# id                       ...
# p01_0      NaN      NaN  ...            NaN            NaN            NaN
# p01_1      NaN      NaN  ...            NaN            NaN            NaN
# p01_2      NaN      NaN  ...            NaN            NaN            NaN
# p01_3      NaN      NaN  ...            NaN            NaN            NaN
# p01_4      NaN      NaN  ...            NaN            NaN            NaN
#
#        activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# id
# p01_0            NaN            NaN            NaN            NaN
# p01_1            NaN            NaN            NaN            NaN
# p01_2            NaN            NaN            NaN            NaN
# p01_3            NaN            NaN            NaN            NaN
# p01_4            NaN            NaN            NaN            NaN
#
#        activity-0:05  activity-0:00  bg+1:00
# id
# p01_0            NaN            NaN     13.4
# p01_1            NaN            NaN     12.8
# p01_2            NaN            NaN     15.5
# p01_3            NaN            NaN     14.8
# p01_4            NaN            NaN     12.7
#
# [5 rows x 507 columns]

# %% [markdown]
# ### Define a tuning function

# %%
import joblib
import os


def tune(p_num, tuner, X, y):
    model_file_name = f'{p_num}.{tuner.__name__}.model.pkl'
    if os.path.exists(model_file_name):
        print(f'Model {model_file_name} already exists. Skipping...')
        return

    print(f'-----------{tuner.__name__}-----------')
    print('Calculating best hyperparameters...')
    tuner.fit(X, y)
    print('Best hyperparameters found.')
    display(tuner.get_params())
    print(f'RMSE: {tuner.get_rmse()}')
    tuner.show_chart()
    joblib.dump(tuner.get_best_model(), model_file_name)

# %%
from pipelines import pipeline
from src.features.tuners import HistGradientBoostingHyperparameterTuner

for patient in unique_patients:
    patient_train_data = train_data[train_data['p_num'] == patient]
    patient_train_data_transformed = pipeline.fit_transform(patient_train_data)

    X_train = patient_train_data_transformed.drop(columns=['bg+1:00'])
    y_train = patient_train_data_transformed['bg+1:00']

    tune(patient, HistGradientBoostingHyperparameterTuner(search_space='deep'), X_train, y_train)
# Out:
# Model p01.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p02.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p04.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p05.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p06.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p10.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p11.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p12.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p15.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p16.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p18.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p19.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# Model p21.HistGradientBoostingRegressor.model.pkl already exists. Skipping...
# -----------HistGradientBoostingRegressor-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('early_stopping', False),
#              ('l2_regularization', 1.0),
#              ('learning_rate', 0.12291836313589895),
#              ('max_bins', 128),
#              ('max_depth', 14),
#              ('max_iter', 500),
#              ('max_leaf_nodes', 31),
#              ('min_samples_leaf', 10),
#              ('scoring', 'neg_mean_squared_error')])
# RMSE: 0.24919626197043185
# -----------HistGradientBoostingRegressor-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('early_stopping', False),
#              ('l2_regularization', 1.0),
#              ('learning_rate', 0.1118857169807318),
#              ('max_bins', 128),
#              ('max_depth', 12),
#              ('max_iter', 500),
#              ('max_leaf_nodes', 31),
#              ('min_samples_leaf', 10),
#              ('scoring', 'neg_mean_squared_error')])
# RMSE: 0.3185210291362736
