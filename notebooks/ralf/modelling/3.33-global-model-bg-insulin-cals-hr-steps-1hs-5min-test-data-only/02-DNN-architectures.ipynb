# %% [markdown]
# # DNN estimator architectures and their performance evaluation

# %%
from data import load_data
from pipelines import pipeline

_, augmented_data, test_data = load_data()
train_data = pipeline.fit_transform(augmented_data)

# cut the data into train, additional train and test
X_train = train_data.drop(columns=['bg+1:00'])
y_train = train_data['bg+1:00']

# %%
import dnns
from model_performance_calculations import calculate_dnn_performance, get_history_line_chart

# %%
# MA01 (used in 3.30-v4.0)

_, histories = calculate_dnn_performance(dnns.create_model_MA01, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()
# Out:
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 890us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 455us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 946us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
# MA01I (used on 3.30-v5.1)
# Reduce complexity of the model by removing the lowest layer
# Try to get a stable RMSE around 2

_, histories = calculate_dnn_performance(dnns.create_model_MA01I, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()
# Out:
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 499us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 911us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 628us/step
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step

# %%
# MA01I2 - Add BatchNormalization
_, histories = calculate_dnn_performance(dnns.create_model_MA01I2, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # MA01I2 - Add BatchNormalization
# ----> 2 _, histories = calculate_dnn_performance(dnns.create_model_MA01I2, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
#       3 get_history_line_chart(histories).show()
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/notebooks/ralf/modelling/3.33-global-model-bg-insulin-cals-hr-steps-1hs-5min-test-data-only/model_performance_calculations.py:155, in calculate_dnn_performance(create_model_fn, X_train, y_train, verbose, n_splits, epochs, groups, callbacks, early_stopping)
#     152 if early_stopping:
#     153     callbacks.append(EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True))
# --> 155 model.fit(
#     156     X_train_split,
#     157     y_train_split,
#     158     validation_data=(X_test_split, y_test_split),
#     159     epochs=epochs,
#     160     callbacks=callbacks,
#     161     verbose=2 if verbose else 0,
#     162 )
#     164 histories.append(model.history.history)
#     165 y_pred = model.predict(X_test_split)
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# MA02

_, histories = calculate_dnn_performance(dnns.create_model_MA02, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA03

_, histories = calculate_dnn_performance(dnns.create_model_MA03, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA04

_, histories = calculate_dnn_performance(dnns.create_model_MA04, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA05

_, histories = calculate_dnn_performance(dnns.create_model_MA05, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA06

_, histories = calculate_dnn_performance(dnns.create_model_MA06, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA07

_, histories = calculate_dnn_performance(dnns.create_model_MA07, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA08

_, histories = calculate_dnn_performance(dnns.create_model_MA08, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA09

_, histories = calculate_dnn_performance(dnns.create_model_MA09, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA10

_, histories = calculate_dnn_performance(dnns.create_model_MA10, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA11

_, histories = calculate_dnn_performance(dnns.create_model_MA11, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA12

_, histories = calculate_dnn_performance(dnns.create_model_MA12, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
# MA13

_, histories = calculate_dnn_performance(dnns.create_model_MA13, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()

# %%
import dnns
from model_performance_calculations import calculate_dnn_performance, get_history_line_chart

_, histories = calculate_dnn_performance(dnns.create_model_MA02, X_train, y_train, n_splits=5, epochs=100, verbose=False, early_stopping=True)
get_history_line_chart(histories).show()
