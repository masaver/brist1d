# %% [markdown]
# # Description

# %% [markdown]
# Changes made (from the 3.20.0):
#
# * Convert bg features with log1p transformation

# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd

train_data_file = os.path.join('..', '..', '..', '..', 'data', 'raw', 'train.csv')
train_data = pd.read_csv(train_data_file, index_col=0, low_memory=False)
validation_data_file = os.path.join('..', '..', '..', '..', 'data', 'interim', 'all_test_3h.csv')
validation_data = pd.read_csv(validation_data_file, low_memory=False)

# %%
from pipelines import preprocessing_pipeline, standardization_pipeline

train_data = preprocessing_pipeline.fit_transform(train_data)
validation_data = preprocessing_pipeline.transform(validation_data)

# %%
train_data.head()
# Out:
#        bg-3:00    bg-2:55    bg-2:50  bg-2:45    bg-2:40    bg-2:35  bg-2:30  \
# id
# p01_0     13.9  14.000000  14.100000     14.2  14.200000  14.200000     14.2
# p01_1     14.2  14.200000  14.200000     14.2  14.600000  15.000000     15.4
# p01_2     14.2  14.600000  15.000000     15.4  16.000000  16.600000     17.2
# p01_3     15.4  16.000000  16.600000     17.2  17.533333  17.866667     18.2
# p01_4     17.2  17.533333  17.866667     18.2  18.266667  18.333333     18.4
#
#          bg-2:25    bg-2:20  bg-2:15  ...  cals-0:35  cals-0:30  cals-0:25  \
# id                                    ...
# p01_0  14.600000  15.000000     15.4  ...       6.18       6.18       6.18
# p01_1  16.000000  16.600000     17.2  ...       6.18       6.18       6.18
# p01_2  17.533333  17.866667     18.2  ...       6.18       6.18       6.18
# p01_3  18.266667  18.333333     18.4  ...       6.18       6.18       6.18
# p01_4  18.266667  18.133333     18.0  ...       6.18       6.18       6.18
#
#        cals-0:20  cals-0:15  cals-0:10  cals-0:05  cals-0:00  bg+1:00  hour
# id
# p01_0       6.18       6.18       6.18       6.18       6.18     13.4    06
# p01_1       6.18       6.18       6.18       6.18       6.18     12.8    06
# p01_2       6.18       6.18       6.18       6.18       6.18     15.5    06
# p01_3       6.18       6.18       6.18       6.18       6.18     14.8    06
# p01_4       6.18       6.18       6.18       6.18       6.18     12.7    07
#
# [5 rows x 187 columns]

# %%
train_data = standardization_pipeline.fit_transform(train_data)
train_data.head()
# Out:
#         bg-3:00   bg-2:55   bg-2:50   bg-2:45   bg-2:40   bg-2:35   bg-2:30  \
# id
# p01_0  1.700061  1.723739  1.744600  1.764666  1.766660  1.765906  1.764329
# p01_1  1.764983  1.766935  1.766115  1.764666  1.851364  1.933090  2.011742
# p01_2  1.764983  1.851646  1.933306  2.012109  2.131616  2.243742  2.350828
# p01_3  2.012455  2.131921  2.243970  2.351236  2.413222  2.470261  2.524990
# p01_4  2.351620  2.413549  2.470499  2.525419  2.539764  2.549901  2.558732
#
#         bg-2:25   bg-2:20   bg-2:15  ...  hour_14  hour_15  hour_16  hour_17  \
# id                                   ...
# p01_0  1.851076  1.932814  2.011406  ...        0        0        0        0
# p01_1  2.131308  2.243455  2.350470  ...        0        0        0        0
# p01_2  2.412894  2.469966  2.524621  ...        0        0        0        0
# p01_3  2.539427  2.549602  2.558361  ...        0        0        0        0
# p01_4  2.539427  2.515710  2.490528  ...        0        0        0        0
#
#        hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# id
# p01_0        0        0        0        0        0        0
# p01_1        0        0        0        0        0        0
# p01_2        0        0        0        0        0        0
# p01_3        0        0        0        0        0        0
# p01_4        0        0        0        0        0        0
#
# [5 rows x 209 columns]

# %%
validation_data.head()
# Out:
#    bg-3:00  bg-2:55  bg-2:50  bg-2:45  bg-2:40  bg-2:35  bg-2:30  bg-2:25  \
# 0     9.20     9.20     9.53     9.87    10.20    10.23    10.27    10.30
# 1     9.20     9.53     9.87    10.20    10.23    10.27    10.30    10.27
# 2     9.53     9.87    10.20    10.23    10.27    10.30    10.27    10.23
# 3     9.87    10.20    10.23    10.27    10.30    10.27    10.23    10.20
# 4    10.20    10.23    10.27    10.30    10.27    10.23    10.20    10.70
#
#    bg-2:20  bg-2:15  ...  cals-0:35  cals-0:30  cals-0:25  cals-0:20  \
# 0    10.27    10.23  ...       4.80       7.89       7.98        4.8
# 1    10.23    10.20  ...       7.89       7.98       4.80        4.8
# 2    10.20    10.70  ...       7.98       4.80       4.80        4.8
# 3    10.70    11.20  ...       4.80       4.80       4.80        4.8
# 4    11.20    11.70  ...       4.80       4.80       4.80        4.8
#
#    cals-0:15  cals-0:10  cals-0:05  cals-0:00  bg+1:00  hour
# 0        4.8        4.8        4.8        4.8    13.73    03
# 1        4.8        4.8        4.8        4.9    13.70    03
# 2        4.8        4.8        4.9        4.8    13.77    04
# 3        4.8        4.9        4.8        4.8    13.83    04
# 4        4.9        4.8        4.8        4.8    13.90    04
#
# [5 rows x 187 columns]
