# %% [markdown]
# # Predict for each patient

# %%
from data import load_data

train_data, test_data = load_data()

unique_patients = test_data['p_num'].unique()
train_data = train_data[train_data['p_num'].isin(unique_patients)]
test_data = test_data[test_data['p_num'].isin(unique_patients)]

train_data.head()
# Out:
#       p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# id
# p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN      9.7
# p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN      9.2
# p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN      8.7
# p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN      8.4
# p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN      8.1
#
#        bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  activity-0:30  \
# id                       ...
# p01_0      NaN      NaN  ...            NaN            NaN            NaN
# p01_1      NaN      NaN  ...            NaN            NaN            NaN
# p01_2      NaN      NaN  ...            NaN            NaN            NaN
# p01_3      NaN      NaN  ...            NaN            NaN            NaN
# p01_4      NaN      NaN  ...            NaN            NaN            NaN
#
#        activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# id
# p01_0            NaN            NaN            NaN            NaN
# p01_1            NaN            NaN            NaN            NaN
# p01_2            NaN            NaN            NaN            NaN
# p01_3            NaN            NaN            NaN            NaN
# p01_4            NaN            NaN            NaN            NaN
#
#        activity-0:05  activity-0:00  bg+1:00
# id
# p01_0            NaN            NaN     13.4
# p01_1            NaN            NaN     12.8
# p01_2            NaN            NaN     15.5
# p01_3            NaN            NaN     14.8
# p01_4            NaN            NaN     12.7
#
# [5 rows x 507 columns]

# %%
from sklearn.svm import SVR
import numpy as np
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor, StackingRegressor, RandomForestRegressor
from pipelines import pipeline
import os
import datetime


def get_date_time_now():
    return datetime.datetime.now().strftime('%H:%M:%S')


models = {}
results = test_data[[]].copy()
results.loc[:, 'bg+1:00'] = -1.0
results['bg+1:00'] = results['bg+1:00'].astype(float)
for p_num in unique_patients:
    print(f'{get_date_time_now()} - {p_num} - Predicting for patient {p_num}')
    print(f'{get_date_time_now()} - {p_num} - Transforming the data -')
    train_data_patient = train_data[train_data['p_num'] == p_num]
    train_data_patient = pipeline.fit_transform(train_data_patient)

    X_train = train_data_patient.drop(columns=['bg+1:00'])
    y_train = train_data_patient['bg+1:00']

    print(f'{get_date_time_now()} - {p_num} - Fitting the model -')
    base_models = [
        ('hgb', HistGradientBoostingRegressor(max_iter=1000, max_depth=5, learning_rate=0.01)),
        ('xgb', XGBRegressor(objective='reg:squarederror', random_state=42, n_estimators=5000, max_depth=5, learning_rate=0.01)),
        ('rf', RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)),
        ('svr', SVR(kernel='rbf', C=1.0, gamma='scale')),
        ('knn', KNeighborsRegressor(n_neighbors=10, weights='distance')),
        ('elastic', ElasticNet(alpha=0.1, l1_ratio=0.5, max_iter=10000))
    ]

    meta_model = ElasticNet(alpha=0.1, l1_ratio=0.5, max_iter=10000)
    model = StackingRegressor(estimators=base_models, final_estimator=meta_model)
    model.fit(X=X_train, y=y_train)

    print(f'{get_date_time_now()} - {p_num} - Predicting -')
    test_data_patient = test_data[test_data['p_num'] == p_num]
    X_test = pipeline.transform(test_data_patient)
    y_pred = model.predict(X=X_test)

    # count and replace negative values
    if np.sum(y_pred < 0) > 0:
        print(f'{get_date_time_now()} - {p_num} - Number of negative values: {np.sum(y_pred < 0)}')
        bg_min_train = np.min(y_train)
        print(f'{get_date_time_now()} - {p_num} - Min value: {np.min(y_pred)}')
        y_pred = y_pred.apply(lambda x: bg_min_train if x < 0 else x)

    results.loc[test_data_patient.index, 'bg+1:00'] = y_pred
    print(f'{get_date_time_now()} - {p_num} - Done -')

results.head()
# Out:
# 00:19:22 - p01 - Predicting for patient p01
# 00:19:22 - p01 - Transforming the data -
# 00:19:25 - p01 - Fitting the model -
# 00:46:12 - p01 - Predicting -
# 00:46:13 - p01 - Done -
# 00:46:13 - p02 - Predicting for patient p02
# 00:46:13 - p02 - Transforming the data -
# 00:46:17 - p02 - Fitting the model -
# 01:29:59 - p02 - Predicting -
# 01:30:00 - p02 - Done -
# 01:30:00 - p04 - Predicting for patient p04
# 01:30:00 - p04 - Transforming the data -
# 01:30:03 - p04 - Fitting the model -
# 02:16:32 - p04 - Predicting -
# 02:16:33 - p04 - Done -
# 02:16:33 - p05 - Predicting for patient p05
# 02:16:33 - p05 - Transforming the data -
# 02:16:35 - p05 - Fitting the model -
# 02:42:19 - p05 - Predicting -
# 02:42:20 - p05 - Done -
# 02:42:20 - p06 - Predicting for patient p06
# 02:42:20 - p06 - Transforming the data -
# 02:42:22 - p06 - Fitting the model -
# 03:05:19 - p06 - Predicting -
# 03:05:19 - p06 - Done -
# 03:05:19 - p10 - Predicting for patient p10
# 03:05:19 - p10 - Transforming the data -
# 03:05:22 - p10 - Fitting the model -
# 03:56:33 - p10 - Predicting -
# 03:56:33 - p10 - Done -
# 03:56:33 - p11 - Predicting for patient p11
# 03:56:33 - p11 - Transforming the data -
# 03:56:37 - p11 - Fitting the model -
# 04:37:19 - p11 - Predicting -
# 04:37:20 - p11 - Done -
# 04:37:20 - p12 - Predicting for patient p12
# 04:37:20 - p12 - Transforming the data -
# 04:37:24 - p12 - Fitting the model -
# 05:23:02 - p12 - Predicting -
# 05:23:03 - p12 - Done -
# 05:23:03 - p15 - Predicting for patient p15
# 05:23:03 - p15 - Transforming the data -
# 05:23:05 - p15 - Fitting the model -
# 05:30:35 - p15 - Predicting -
# 05:30:35 - p15 - Done -
# 05:30:35 - p16 - Predicting for patient p16
# 05:30:35 - p16 - Transforming the data -
# 05:30:37 - p16 - Fitting the model -
# 05:42:08 - p16 - Predicting -
# 05:42:08 - p16 - Done -
# 05:42:08 - p18 - Predicting for patient p18
# 05:42:08 - p18 - Transforming the data -
# 05:42:09 - p18 - Fitting the model -
# 05:50:12 - p18 - Predicting -
# 05:50:13 - p18 - Done -
# 05:50:13 - p19 - Predicting for patient p19
# 05:50:13 - p19 - Transforming the data -
# 05:50:14 - p19 - Fitting the model -
# 06:00:42 - p19 - Predicting -
# 06:00:42 - p19 - Done -
# 06:00:42 - p21 - Predicting for patient p21
# 06:00:42 - p21 - Transforming the data -
# 06:00:43 - p21 - Fitting the model -
# 06:08:40 - p21 - Predicting -
# 06:08:41 - p21 - Done -
# 06:08:41 - p22 - Predicting for patient p22
# 06:08:41 - p22 - Transforming the data -
# 06:08:42 - p22 - Fitting the model -
# 06:16:14 - p22 - Predicting -
# 06:16:14 - p22 - Done -
# 06:16:14 - p24 - Predicting for patient p24
# 06:16:14 - p24 - Transforming the data -
# 06:16:15 - p24 - Fitting the model -
# 06:29:00 - p24 - Predicting -
# 06:29:00 - p24 - Done -
#             bg+1:00
# id
# p01_8459   8.578611
# p01_8460   6.248291
# p01_8461   8.578479
# p01_8462  10.606884
# p01_8463   6.587078

# %%
results[results['bg+1:00'] < 0]
# Out:
# Empty DataFrame
# Columns: [bg+1:00]
# Index: []

# %%
# check if all results are greater than 0
assert (results['bg+1:00'] >= 0).all()

# %% [markdown]
# ## Prepare the submission file

# %%
submission = results
submission
# Out:
#             bg+1:00
# id
# p01_8459   8.578611
# p01_8460   6.248291
# p01_8461   8.578479
# p01_8462  10.606884
# p01_8463   6.587078
# ...             ...
# p24_256    6.677037
# p24_257    9.663669
# p24_258    6.543265
# p24_259    8.301728
# p24_260    6.524253
#
# [3644 rows x 1 columns]

# %% [markdown]
# ### Save the submission file

# %%
submission.to_csv(f'submission-{os.path.basename(os.getcwd())}.csv')

# %%
train_data['bg+1:00'].describe()
# Out:
# count    277524.000000
# mean          8.446084
# std           3.108568
# min           2.200000
# 25%           6.200000
# 50%           7.800000
# 75%          10.100000
# max          27.800000
# Name: bg+1:00, dtype: float64

# %%
train_data[train_data['p_num'] == 'p16']['bg+1:00'].describe()
# Out:
# count    8905.000000
# mean        8.331803
# std         1.915485
# min         3.400000
# 25%         6.900000
# 50%         8.000000
# 75%         9.700000
# max        15.400000
# Name: bg+1:00, dtype: float64
