# %% [markdown]
# # Modelling most important features
#
# ## Model Selection

# %%
# Importing the libraries
import os
import pandas as pd

# %%
train_data_file = os.path.join('..', '..', '..', '..', 'data', 'raw', 'train.csv')
train_data = pd.read_csv(train_data_file, index_col=0, low_memory=False)
validation_data_file = os.path.join('..', '..', '..', '..', 'data', 'interim', 'all_test_3h.csv')
validation_data = pd.read_csv(validation_data_file, low_memory=False)

# %%
from pipelines import pipeline

train_data = pipeline.fit_transform(train_data)
validation_data = pipeline.transform(validation_data)

# %% [markdown]
# ## Data Splitting

# %%
X_train = train_data.drop(columns=['bg+1:00'])
y_train = train_data['bg+1:00']

X_test = validation_data.drop(columns=['bg+1:00'])
y_test = validation_data['bg+1:00']

# %% [markdown]
# ## Model Selection with LazyPredict

# %%
from notebooks.helpers.LazyPredict import get_lazy_regressor

reg = get_lazy_regressor(exclude=['SVR'])
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  97%|█████████▋| 37/38 [38:15<00:11, 11.42s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035000 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 47203
# [LightGBM] [Info] Number of data points in the train set: 177024, number of used features: 208
# [LightGBM] [Info] Start training from score 8.277045
# 100%|██████████| 38/38 [38:20<00:00, 60.54s/it]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.54       0.54  2.22      687.70
# HistGradientBoostingRegressor                0.53       0.53  2.24        9.14
# LGBMRegressor                                0.53       0.53  2.25        4.56
# LassoLarsCV                                  0.52       0.52  2.27        4.23
# LassoCV                                      0.52       0.52  2.27       18.48
# LassoLarsIC                                  0.52       0.52  2.27        2.14
# BayesianRidge                                0.52       0.52  2.27        2.85
# Ridge                                        0.52       0.52  2.27        0.84
# RidgeCV                                      0.52       0.52  2.27        3.05
# TransformedTargetRegressor                   0.52       0.52  2.27        1.78
# ElasticNetCV                                 0.51       0.52  2.28       19.40
# GradientBoostingRegressor                    0.51       0.51  2.28      374.07
# HuberRegressor                               0.51       0.51  2.29       11.55
# SGDRegressor                                 0.51       0.51  2.29        4.45
# LinearSVR                                    0.50       0.51  2.30      100.27
# XGBRegressor                                 0.50       0.50  2.31        3.51
# OrthogonalMatchingPursuit                    0.50       0.50  2.31        0.94
# OrthogonalMatchingPursuitCV                  0.50       0.50  2.31        2.95
# BaggingRegressor                             0.48       0.48  2.35      193.50
# PoissonRegressor                             0.48       0.48  2.36        1.57
# LarsCV                                       0.47       0.48  2.37        4.67
# MLPRegressor                                 0.45       0.45  2.43       96.59
# GammaRegressor                               0.41       0.41  2.50        1.90
# TweedieRegressor                             0.41       0.41  2.52        1.02
# ElasticNet                                   0.39       0.39  2.55        1.11
# LassoLars                                    0.36       0.36  2.61        0.80
# AdaBoostRegressor                            0.28       0.28  2.77      178.86
# KNeighborsRegressor                          0.20       0.20  2.93       32.12
# ExtraTreeRegressor                           0.09       0.09  3.12        6.76
# DecisionTreeRegressor                        0.06       0.07  3.16       31.21
# PassiveAggressiveRegressor                  -0.00      -0.00  3.27        1.71
# DummyRegressor                              -0.02      -0.02  3.30        0.79
# QuantileRegressor                           -0.10      -0.10  3.43      491.03
# Lars                                        -7.45      -7.44  9.50        0.92
# RANSACRegressor                            -92.52     -92.31 31.59        3.25

# %% [markdown]
# The best models are:
#
# * ExtraTreesRegressor
# * XGBRegressor
# * BaggingRegressor
#
# For further work I choose:
#
# * ExtraTreesRegressor
# * XGBRegressor
# * BaggingRegressor
