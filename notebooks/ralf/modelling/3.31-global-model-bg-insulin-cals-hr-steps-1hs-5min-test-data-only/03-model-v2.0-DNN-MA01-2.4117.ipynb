# %% [markdown]
# # The final model

# %% [markdown]
# ## Model v2.0

# %%
model_name = f'3.31-v2.0'

# %%
import warnings

from sklearn.metrics import root_mean_squared_error

warnings.filterwarnings("ignore")

# %%
import pandas as pd
from data import load_data

_, augmented_data, test_data = load_data()

# %%
augmented_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168588 entries, p01_test_12 to p24_test_94938
# Columns: 507 entries, p_num to bg+1:00
# dtypes: float64(433), object(74)
# memory usage: 657.4+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3644 entries, p01_8459 to p24_260
# Columns: 506 entries, p_num to activity-0:00
# dtypes: float64(432), object(74)
# memory usage: 14.2+ MB

# %% [markdown]
# # Prepare the data

# %%
from pipelines import pipeline

train_data_transformed = pipeline.fit_transform(augmented_data)

X_train = train_data_transformed.drop(columns=['bg+1:00'])
y_train = train_data_transformed['bg+1:00']

# %% [markdown]
# ## Predict for validation data and check results

# %%
import dnns
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasRegressor

create_dnn_model = dnns.create_model_MA01


def model_with_pretrained_weights():
    dnn = create_dnn_model(X_train.shape[1])
    dnn.load_weights(f'{model_name}.weights.h5')  # Load the pre-trained weights

    # Freeze all layers except the last one (optional)
    for layer in dnn.layers:
        layer.trainable = False
    # Unfreeze the output layer if you want to fine-tune it
    # dnn.layers[-1].trainable = True

    dnn.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mse',
        metrics=[dnns.rmse]
    )
    return dnn

# %%
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import StackingRegressor, HistGradientBoostingRegressor
from sklearn.linear_model import LassoLarsIC, Ridge
from tensorflow.keras.callbacks import EarlyStopping
from model_performance_calculations import get_history_line_chart

# pretrain the DNN and use the weights in the stacking model
pretrained_dnn = create_dnn_model(X_train.shape[1])
pretrained_dnn.fit(
    X_train,
    y_train,
    epochs=100,
    verbose=2,
    validation_split=0.2,
    batch_size=32,
    callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
)

history = pretrained_dnn.history.history
pretrained_dnn.save_weights(f'{model_name}.weights.h5')

keras_regressor = KerasRegressor(
    model=model_with_pretrained_weights,
    epochs=1,
    verbose=2
)

estimators = [
    ('hgb', HistGradientBoostingRegressor(max_iter=1000, max_depth=5, learning_rate=0.01)),
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=42, n_estimators=5000, max_depth=5, learning_rate=0.01)),
    ('knn', KNeighborsRegressor(n_neighbors=5)),
    ('lasso', LassoLarsIC(criterion='bic', max_iter=5000)),
    ('dnn', keras_regressor)
]

model = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=0.1), n_jobs=1, verbose=2)

get_history_line_chart([history]).show()
# Out:
# Epoch 1/100
# 4215/4215 - 7s - 2ms/step - loss: 11.8310 - rmse: 3.1130 - val_loss: 5.7801 - val_rmse: 2.1314
# Epoch 2/100
# 4215/4215 - 5s - 1ms/step - loss: 6.0670 - rmse: 2.4316 - val_loss: 5.2758 - val_rmse: 2.0394
# Epoch 3/100
# 4215/4215 - 6s - 1ms/step - loss: 5.7489 - rmse: 2.3658 - val_loss: 5.2494 - val_rmse: 2.0414
# Epoch 4/100
# 4215/4215 - 6s - 1ms/step - loss: 5.5216 - rmse: 2.3188 - val_loss: 5.1933 - val_rmse: 2.0226
# Epoch 5/100
# 4215/4215 - 6s - 1ms/step - loss: 5.3573 - rmse: 2.2826 - val_loss: 5.2464 - val_rmse: 2.0414
# Epoch 6/100
# 4215/4215 - 6s - 1ms/step - loss: 5.2186 - rmse: 2.2550 - val_loss: 5.2344 - val_rmse: 2.0453
# Epoch 7/100
# 4215/4215 - 6s - 1ms/step - loss: 5.0921 - rmse: 2.2258 - val_loss: 5.0418 - val_rmse: 2.0036
# Epoch 8/100
# 4215/4215 - 6s - 1ms/step - loss: 5.0156 - rmse: 2.2102 - val_loss: 5.0289 - val_rmse: 2.0027
# Epoch 9/100
# 4215/4215 - 6s - 1ms/step - loss: 4.9672 - rmse: 2.1987 - val_loss: 5.0509 - val_rmse: 2.0111
# Epoch 10/100
# 4215/4215 - 19s - 5ms/step - loss: 4.8817 - rmse: 2.1795 - val_loss: 5.0261 - val_rmse: 2.0000
# Epoch 11/100
# 4215/4215 - 6s - 1ms/step - loss: 4.7954 - rmse: 2.1602 - val_loss: 5.1371 - val_rmse: 2.0241
# Epoch 12/100
# 4215/4215 - 5s - 1ms/step - loss: 4.7776 - rmse: 2.1553 - val_loss: 5.0973 - val_rmse: 2.0167
# Epoch 13/100
# 4215/4215 - 5s - 1ms/step - loss: 4.7322 - rmse: 2.1457 - val_loss: 5.0308 - val_rmse: 2.0004
# Epoch 14/100
# 4215/4215 - 5s - 1ms/step - loss: 4.7009 - rmse: 2.1379 - val_loss: 5.1860 - val_rmse: 2.0258
# Epoch 15/100
# 4215/4215 - 5s - 1ms/step - loss: 4.6525 - rmse: 2.1279 - val_loss: 5.0501 - val_rmse: 2.0014
# Epoch 16/100
# 4215/4215 - 5s - 1ms/step - loss: 4.6093 - rmse: 2.1183 - val_loss: 5.0990 - val_rmse: 2.0092
# Epoch 17/100
# 4215/4215 - 6s - 1ms/step - loss: 4.6081 - rmse: 2.1179 - val_loss: 5.1498 - val_rmse: 2.0219
# Epoch 18/100
# 4215/4215 - 6s - 1ms/step - loss: 4.5646 - rmse: 2.1077 - val_loss: 5.0738 - val_rmse: 2.0086
# Epoch 19/100
# 4215/4215 - 4s - 1ms/step - loss: 4.5478 - rmse: 2.1032 - val_loss: 5.0885 - val_rmse: 2.0086
# Epoch 20/100
# 4215/4215 - 4s - 868us/step - loss: 4.5285 - rmse: 2.0984 - val_loss: 5.2031 - val_rmse: 2.0409

# %%
from datetime import datetime
import os
from model_performance_calculations import calculate_stacking_regressor_performance, get_rmse_boxplot_chart, get_rmse_line_chart, save_performances, save_model

date_time = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

save_model(model, os.path.join('models', f'{model_name}.pkl'))

performances = calculate_stacking_regressor_performance(model, X_train, y_train, n_splits=10)
save_performances(performances, os.path.join('models', f'{model_name}-performances.json'))

get_rmse_boxplot_chart(performances).show()
get_rmse_line_chart(performances).show()
# Out:
# 10:43:11 - Start training
# 10:43:11 - Calculate performance for hgb
# 10:43:11 - Split 1 - Model: hgb
# 10:43:11 - Fitting the model
# 10:43:59 - Predicting
# 10:43:59 - Calculating scores
# 10:43:59 - R^2: 0.60974108312874, RMSE: 2.0556912109119305, MAE: 1.533923872428557, MSE: 4.2258663546205595
# 10:43:59 - Split 2 - Model: hgb
# 10:43:59 - Fitting the model
# 10:44:47 - Predicting
# 10:44:47 - Calculating scores
# 10:44:47 - R^2: 0.6128426972641091, RMSE: 2.031249496388782, MAE: 1.5140410416400358, MSE: 4.125974516579681
# 10:44:47 - Split 3 - Model: hgb
# 10:44:47 - Fitting the model
# 10:45:58 - Predicting
# 10:45:58 - Calculating scores
# 10:45:58 - R^2: 0.6089347044471183, RMSE: 2.04137669001892, MAE: 1.537225219094309, MSE: 4.167218790552601
# 10:45:58 - Split 4 - Model: hgb
# 10:45:59 - Fitting the model
# 10:46:37 - Predicting
# 10:46:37 - Calculating scores
# 10:46:37 - R^2: 0.6008495655616604, RMSE: 2.041342187777623, MAE: 1.535947854618842, MSE: 4.167077927600733
# 10:46:37 - Split 5 - Model: hgb
# 10:46:37 - Fitting the model
# 10:47:29 - Predicting
# 10:47:30 - Calculating scores
# 10:47:30 - R^2: 0.6194461363256653, RMSE: 2.0281231856791915, MAE: 1.5128663220371754, MSE: 4.1132836562895125
# 10:47:30 - Split 6 - Model: hgb
# 10:47:30 - Fitting the model
# 10:48:22 - Predicting
# 10:48:22 - Calculating scores
# 10:48:22 - R^2: 0.6051904208254977, RMSE: 2.0529090097205103, MAE: 1.538547658302255, MSE: 4.214435402191647
# 10:48:22 - Split 7 - Model: hgb
# 10:48:22 - Fitting the model
# 10:49:27 - Predicting
# 10:49:27 - Calculating scores
# 10:49:27 - R^2: 0.5993649051472385, RMSE: 2.0727660404184496, MAE: 1.5479386735929932, MSE: 4.296359058311978
# 10:49:27 - Split 8 - Model: hgb
# 10:49:27 - Fitting the model
# 10:50:09 - Predicting
# 10:50:09 - Calculating scores
# 10:50:09 - R^2: 0.6188227669055344, RMSE: 2.0359613724478445, MAE: 1.5196328998408144, MSE: 4.14513871009971
# 10:50:09 - Split 9 - Model: hgb
# 10:50:09 - Fitting the model
# 10:50:54 - Predicting
# 10:50:55 - Calculating scores
# 10:50:55 - R^2: 0.608044460988721, RMSE: 2.02105472037196, MAE: 1.507352336531165, MSE: 4.084662182737782
# 10:50:55 - Split 10 - Model: hgb
# 10:50:55 - Fitting the model
# 10:51:49 - Predicting
# 10:51:50 - Calculating scores
# 10:51:50 - R^2: 0.6025697565919312, RMSE: 2.0374567071037597, MAE: 1.5263594613869347, MSE: 4.1512298333220965
# 10:51:50 - Training finished
# 10:51:50 - Calculate performance for xgb
# 10:51:50 - Split 1 - Model: xgb
# 10:51:50 - Fitting the model
# 10:53:06 - Predicting
# 10:53:07 - Calculating scores
# 10:53:07 - R^2: 0.6539386897163162, RMSE: 1.9357888567178945, MAE: 1.4425905461127213, MSE: 3.7472784977931726
# 10:53:07 - Split 2 - Model: xgb
# 10:53:07 - Fitting the model
# 10:54:05 - Predicting
# 10:54:06 - Calculating scores
# 10:54:06 - R^2: 0.6534674650809321, RMSE: 1.9217263745968503, MAE: 1.4272594946729975, MSE: 3.693032258821154
# 10:54:06 - Split 3 - Model: xgb
# 10:54:06 - Fitting the model
# 10:55:36 - Predicting
# 10:55:37 - Calculating scores
# 10:55:37 - R^2: 0.6526373149281338, RMSE: 1.9239336672078742, MAE: 1.4458174364826593, MSE: 3.7015207558159395
# 10:55:37 - Split 4 - Model: xgb
# 10:55:37 - Fitting the model
# 10:56:52 - Predicting
# 10:56:52 - Calculating scores
# 10:56:52 - R^2: 0.6449986372533603, RMSE: 1.925140887825327, MAE: 1.4441173348754064, MSE: 3.7061674379768887
# 10:56:52 - Split 5 - Model: xgb
# 10:56:52 - Fitting the model
# 10:59:03 - Predicting
# 10:59:04 - Calculating scores
# 10:59:04 - R^2: 0.6631734851694249, RMSE: 1.9080484486363936, MAE: 1.420516999967229, MSE: 3.6406488823437484
# 10:59:04 - Split 6 - Model: xgb
# 10:59:04 - Fitting the model
# 11:00:37 - Predicting
# 11:00:37 - Calculating scores
# 11:00:37 - R^2: 0.6473746096535757, RMSE: 1.9401381254898022, MAE: 1.449226942062378, MSE: 3.764135945979084
# 11:00:37 - Split 7 - Model: xgb
# 11:00:37 - Fitting the model
# 11:02:30 - Predicting
# 11:02:31 - Calculating scores
# 11:02:31 - R^2: 0.6448658147103952, RMSE: 1.9515156099043647, MAE: 1.4528175543516906, MSE: 3.8084131757004047
# 11:02:31 - Split 8 - Model: xgb
# 11:02:31 - Fitting the model
# 11:04:09 - Predicting
# 11:04:10 - Calculating scores
# 11:04:10 - R^2: 0.6597469659828586, RMSE: 1.9235658606813912, MAE: 1.4335838258927585, MSE: 3.7001056203789413
# 11:04:10 - Split 9 - Model: xgb
# 11:04:10 - Fitting the model
# 11:05:40 - Predicting
# 11:05:41 - Calculating scores
# 11:05:41 - R^2: 0.6493022540585454, RMSE: 1.9117282437859175, MAE: 1.4206808809765097, MSE: 3.654704878088789
# 11:05:41 - Split 10 - Model: xgb
# 11:05:41 - Fitting the model
# 11:07:57 - Predicting
# 11:07:57 - Calculating scores
# 11:07:57 - R^2: 0.6454967846806792, RMSE: 1.9242789201415076, MAE: 1.4356941782224646, MSE: 3.7028493625009666
# 11:07:57 - Training finished
# 11:07:57 - Calculate performance for knn
# 11:07:57 - Split 1 - Model: knn
# 11:07:58 - Fitting the model
# 11:07:58 - Predicting
# 11:08:01 - Calculating scores
# 11:08:01 - R^2: 0.5984832009137091, RMSE: 2.0851308886268924, MAE: 1.403625719200427, MSE: 4.347770822705973
# 11:08:01 - Split 2 - Model: knn
# 11:08:01 - Fitting the model
# 11:08:02 - Predicting
# 11:08:05 - Calculating scores
# 11:08:05 - R^2: 0.606420695750594, RMSE: 2.048026961729, MAE: 1.389701643039326, MSE: 4.194414435968919
# 11:08:05 - Split 3 - Model: knn
# 11:08:05 - Fitting the model
# 11:08:05 - Predicting
# 11:08:09 - Calculating scores
# 11:08:09 - R^2: 0.5959439045149562, RMSE: 2.075005940131439, MAE: 1.408520908713447, MSE: 4.305649651580757
# 11:08:09 - Split 4 - Model: knn
# 11:08:09 - Fitting the model
# 11:08:09 - Predicting
# 11:08:12 - Calculating scores
# 11:08:12 - R^2: 0.5999553773131484, RMSE: 2.0436274452701477, MAE: 1.3969569962631234, MSE: 4.176413135061391
# 11:08:12 - Split 5 - Model: knn
# 11:08:13 - Fitting the model
# 11:08:13 - Predicting
# 11:08:16 - Calculating scores
# 11:08:16 - R^2: 0.6079722258900293, RMSE: 2.058470656574077, MAE: 1.3877163532831127, MSE: 4.237301443976512
# 11:08:16 - Split 6 - Model: knn
# 11:08:16 - Fitting the model
# 11:08:16 - Predicting
# 11:08:20 - Calculating scores
# 11:08:20 - R^2: 0.6052622258989202, RMSE: 2.052722317207223, MAE: 1.3900332166795184, MSE: 4.213668911560591
# 11:08:20 - Split 7 - Model: knn
# 11:08:20 - Fitting the model
# 11:08:20 - Predicting
# 11:08:23 - Calculating scores
# 11:08:23 - R^2: 0.6015470795468865, RMSE: 2.067113374162878, MAE: 1.4008179607331395, MSE: 4.272957701643039
# 11:08:23 - Split 8 - Model: knn
# 11:08:23 - Fitting the model
# 11:08:23 - Predicting
# 11:08:26 - Calculating scores
# 11:08:26 - R^2: 0.6084126096786933, RMSE: 2.0635757071673195, MAE: 1.3841434248769204, MSE: 4.258344699211103
# 11:08:26 - Split 9 - Model: knn
# 11:08:26 - Fitting the model
# 11:08:26 - Predicting
# 11:08:29 - Calculating scores
# 11:08:29 - R^2: 0.6017814253448808, RMSE: 2.0371378871800765, MAE: 1.378421876853719, MSE: 4.149930771384507
# 11:08:29 - Split 10 - Model: knn
# 11:08:29 - Fitting the model
# 11:08:29 - Predicting
# 11:08:33 - Calculating scores
# 11:08:33 - R^2: 0.5892910236874502, RMSE: 2.0712142739829553, MAE: 1.4024053861668053, MSE: 4.2899285687507405
# 11:08:33 - Training finished
# 11:08:33 - Calculate performance for lasso
# 11:08:33 - Split 1 - Model: lasso
# 11:08:33 - Fitting the model
# 11:08:35 - Predicting
# 11:08:35 - Calculating scores
# 11:08:35 - R^2: 0.5505719021924766, RMSE: 2.206030801431196, MAE: 1.6513599549082092, MSE: 4.866571896863164
# 11:08:35 - Split 2 - Model: lasso
# 11:08:35 - Fitting the model
# 11:08:38 - Predicting
# 11:08:38 - Calculating scores
# 11:08:38 - R^2: 0.5539073825334302, RMSE: 2.180379353227832, MAE: 1.6330211958312215, MSE: 4.754054123982219
# 11:08:38 - Split 3 - Model: lasso
# 11:08:38 - Fitting the model
# 11:08:39 - Predicting
# 11:08:39 - Calculating scores
# 11:08:39 - R^2: 0.5479204752920459, RMSE: 2.194855491635474, MAE: 1.6621386748560234, MSE: 4.817390629162398
# 11:08:39 - Split 4 - Model: lasso
# 11:08:40 - Fitting the model
# 11:08:41 - Predicting
# 11:08:41 - Calculating scores
# 11:08:41 - R^2: 0.541529799200976, RMSE: 2.1877770613283936, MAE: 1.6552496606703715, MSE: 4.786368470074701
# 11:08:41 - Split 5 - Model: lasso
# 11:08:41 - Fitting the model
# 11:08:42 - Predicting
# 11:08:42 - Calculating scores
# 11:08:42 - R^2: 0.5561666670804668, RMSE: 2.1902627644342023, MAE: 1.6424596445176354, MSE: 4.7972509772669545
# 11:08:42 - Split 6 - Model: lasso
# 11:08:42 - Fitting the model
# 11:08:43 - Predicting
# 11:08:43 - Calculating scores
# 11:08:43 - R^2: 0.5453569487397958, RMSE: 2.2029829652596375, MAE: 1.6560397095437889, MSE: 4.853133945224145
# 11:08:43 - Split 7 - Model: lasso
# 11:08:44 - Fitting the model
# 11:08:45 - Predicting
# 11:08:45 - Calculating scores
# 11:08:45 - R^2: 0.5379277148190571, RMSE: 2.2260286519703105, MAE: 1.670190777766712, MSE: 4.955203559392759
# 11:08:45 - Split 8 - Model: lasso
# 11:08:45 - Fitting the model
# 11:08:46 - Predicting
# 11:08:46 - Calculating scores
# 11:08:46 - R^2: 0.5625284443198879, RMSE: 2.1811270692335425, MAE: 1.6353664908162653, MSE: 4.757315292143303
# 11:08:46 - Split 9 - Model: lasso
# 11:08:46 - Fitting the model
# 11:08:47 - Predicting
# 11:08:47 - Calculating scores
# 11:08:47 - R^2: 0.5497671710508132, RMSE: 2.166098733823453, MAE: 1.6291727155398656, MSE: 4.691983724671566
# 11:08:47 - Split 10 - Model: lasso
# 11:08:47 - Fitting the model
# 11:08:48 - Predicting
# 11:08:48 - Calculating scores
# 11:08:48 - R^2: 0.5437539429128169, RMSE: 2.1830188972539597, MAE: 1.6445978294876242, MSE: 4.765571505767894
# 11:08:48 - Training finished
# 11:08:48 - Calculate performance for dnn
# 11:08:48 - Split 1 - Model: dnn
# 11:08:48 - Fitting the model
# 4742/4742 - 8s - 2ms/step - loss: 4.7240 - rmse: 4.0551
# 11:08:56 - Predicting
# 527/527 - 1s - 2ms/step
# 11:08:57 - Calculating scores
# 11:08:57 - R^2: 0.6098154924218819, RMSE: 2.055495225868142, MAE: 1.5135048853317974, MSE: 4.225060623566724
# 11:08:57 - Split 2 - Model: dnn
# 11:08:57 - Fitting the model
# 4742/4742 - 8s - 2ms/step - loss: 4.7393 - rmse: 4.0573
# 11:09:05 - Predicting
# 527/527 - 1s - 2ms/step
# 11:09:06 - Calculating scores
# 11:09:06 - R^2: 0.611582770093332, RMSE: 2.034551962427202, MAE: 1.505522989590642, MSE: 4.139401687816378
# 11:09:06 - Split 3 - Model: dnn
# 11:09:06 - Fitting the model
# 4742/4742 - 8s - 2ms/step - loss: 4.7689 - rmse: 4.0632
# 11:09:14 - Predicting
# 527/527 - 1s - 2ms/step
# 11:09:15 - Calculating scores
# 11:09:15 - R^2: 0.6126512529586883, RMSE: 2.0316532659398017, MAE: 1.5210725444680793, MSE: 4.127614993003862
# 11:09:15 - Split 4 - Model: dnn
# 11:09:15 - Fitting the model
# 4742/4742 - 7s - 1ms/step - loss: 4.7389 - rmse: 4.0612
# 11:09:23 - Predicting
# 527/527 - 1s - 2ms/step
# 11:09:24 - Calculating scores
# 11:09:24 - R^2: 0.6016622661312998, RMSE: 2.039262965085044, MAE: 1.5199447353477755, MSE: 4.158593440767444
# 11:09:24 - Split 5 - Model: dnn
# 11:09:24 - Fitting the model
# 4742/4742 - 8s - 2ms/step - loss: 4.7794 - rmse: 4.0564
# 11:09:33 - Predicting
# 527/527 - 1s - 2ms/step
# 11:09:34 - Calculating scores
# 11:09:34 - R^2: 0.6183867631837623, RMSE: 2.030944134638049, MAE: 1.499937498315641, MSE: 4.124734078020694
# 11:09:34 - Split 6 - Model: dnn
# 11:09:34 - Fitting the model
# 4742/4742 - 6s - 1ms/step - loss: 4.7672 - rmse: 4.0555
# 11:09:41 - Predicting
# 527/527 - 1s - 1ms/step
# 11:09:41 - Calculating scores
# 11:09:41 - R^2: 0.6072794969787529, RMSE: 2.0474704745693333, MAE: 1.5226897668207775, MSE: 4.192135344233171
# 11:09:41 - Split 7 - Model: dnn
# 11:09:41 - Fitting the model
# 4742/4742 - 7s - 1ms/step - loss: 4.7387 - rmse: 4.0557
# 11:09:49 - Predicting
# 527/527 - 1s - 2ms/step
# 11:09:50 - Calculating scores
# 11:09:50 - R^2: 0.599649819738275, RMSE: 2.0720288779367304, MAE: 1.5315169113458307, MSE: 4.293303671003747
# 11:09:50 - Split 8 - Model: dnn
# 11:09:50 - Fitting the model
# 4742/4742 - 18s - 4ms/step - loss: 4.7199 - rmse: 4.0515
# 11:10:08 - Predicting
# 527/527 - 3s - 6ms/step
# 11:10:12 - Calculating scores
# 11:10:12 - R^2: 0.6212700131280123, RMSE: 2.0294151764537864, MAE: 1.5019482468226548, MSE: 4.118525958420953
# 11:10:12 - Split 9 - Model: dnn
# 11:10:12 - Fitting the model
# 4742/4742 - 16s - 3ms/step - loss: 4.7339 - rmse: 4.0646
# 11:10:28 - Predicting
# 527/527 - 2s - 4ms/step
# 11:10:31 - Calculating scores
# 11:10:31 - R^2: 0.6064107863027265, RMSE: 2.0252622290444484, MAE: 1.4968032533795204, MSE: 4.1016870963940875
# 11:10:31 - Split 10 - Model: dnn
# 11:10:31 - Fitting the model
# 4742/4742 - 14s - 3ms/step - loss: 4.7143 - rmse: 4.0546
# 11:10:46 - Predicting
# 527/527 - 2s - 4ms/step
# 11:10:48 - Calculating scores
# 11:10:48 - R^2: 0.5965885894331223, RMSE: 2.0527309107451397, MAE: 1.515162639486675, MSE: 4.213704191928571
# 11:10:48 - Training finished
# 11:10:48 - Calculate performance for final_estimator
# 11:10:48 - Split 1 - Model: final_estimator
# 11:10:48 - Fitting the model
# 11:10:49 - Predicting
# 11:10:49 - Calculating scores
# 11:10:49 - R^2: 0.5502368293672057, RMSE: 2.2068530055317126, MAE: 1.6516124754607455, MSE: 4.870200188024354
# 11:10:49 - Split 2 - Model: final_estimator
# 11:10:49 - Fitting the model
# 11:10:49 - Predicting
# 11:10:49 - Calculating scores
# 11:10:49 - R^2: 0.55365843950091, RMSE: 2.1809876512827278, MAE: 1.6332096944028978, MSE: 4.756707135047749
# 11:10:49 - Split 3 - Model: final_estimator
# 11:10:49 - Fitting the model
# 11:10:50 - Predicting
# 11:10:50 - Calculating scores
# 11:10:50 - R^2: 0.5480164456262482, RMSE: 2.1946225102861896, MAE: 1.6619751893323649, MSE: 4.816367962654857
# 11:10:50 - Split 4 - Model: final_estimator
# 11:10:50 - Fitting the model
# 11:10:50 - Predicting
# 11:10:50 - Calculating scores
# 11:10:50 - R^2: 0.541351769022917, RMSE: 2.188201791807442, MAE: 1.6552670814124142, MSE: 4.788227081669301
# 11:10:50 - Split 5 - Model: final_estimator
# 11:10:50 - Fitting the model
# 11:10:51 - Predicting
# 11:10:51 - Calculating scores
# 11:10:51 - R^2: 0.5562567352442287, RMSE: 2.190040515517774, MAE: 1.642387373020715, MSE: 4.796277459609357
# 11:10:51 - Split 6 - Model: final_estimator
# 11:10:51 - Fitting the model
# 11:10:51 - Predicting
# 11:10:51 - Calculating scores
# 11:10:51 - R^2: 0.5451277278042646, RMSE: 2.2035382428364674, MAE: 1.6562242691343754, MSE: 4.855580787642827
# 11:10:51 - Split 7 - Model: final_estimator
# 11:10:51 - Fitting the model
# 11:10:52 - Predicting
# 11:10:52 - Calculating scores
# 11:10:52 - R^2: 0.5381475503064833, RMSE: 2.225499061332915, MAE: 1.6702088253490712, MSE: 4.952846071993686
# 11:10:52 - Split 8 - Model: final_estimator
# 11:10:52 - Fitting the model
# 11:10:52 - Predicting
# 11:10:52 - Calculating scores
# 11:10:52 - R^2: 0.5622454695298957, RMSE: 2.181832377030495, MAE: 1.635580866111205, MSE: 4.760392521458539
# 11:10:52 - Split 9 - Model: final_estimator
# 11:10:53 - Fitting the model
# 11:10:53 - Predicting
# 11:10:53 - Calculating scores
# 11:10:53 - R^2: 0.5495685376086459, RMSE: 2.1665765001867157, MAE: 1.6295046943924343, MSE: 4.694053731161317
# 11:10:53 - Split 10 - Model: final_estimator
# 11:10:53 - Fitting the model
# 11:10:53 - Predicting
# 11:10:53 - Calculating scores
# 11:10:53 - R^2: 0.5435369482634727, RMSE: 2.1835379670648356, MAE: 1.6447792493632265, MSE: 4.767838053613635
# 11:10:53 - Training finished
# 11:10:53 - Calculate performance for stacking_regressor
# 11:10:53 - Split 1 - Model: stacking_regressor
# 11:10:54 - Fitting the model
# 4742/4742 - 9s - 2ms/step - loss: 4.7168 - rmse: 4.0517
# 3794/3794 - 1s - 390us/step - loss: 4.4718 - rmse: 4.0362
# 949/949 - 0s - 417us/step
# 3794/3794 - 2s - 593us/step - loss: 4.8721 - rmse: 3.9765
# 949/949 - 0s - 360us/step
# 3794/3794 - 1s - 343us/step - loss: 4.9914 - rmse: 4.1381
# 949/949 - 0s - 354us/step
# 3794/3794 - 1s - 355us/step - loss: 4.8978 - rmse: 4.1361
# 949/949 - 0s - 365us/step
# 3794/3794 - 1s - 342us/step - loss: 4.5030 - rmse: 3.9856
# 949/949 - 0s - 384us/step
# 11:31:47 - Predicting
# 527/527 - 0s - 460us/step
# 11:31:51 - Calculating scores
# 11:31:51 - R^2: 0.6140988020089939, RMSE: 2.0441818363388466, MAE: 1.5098385176217395, MSE: 4.178679380017659
# 11:31:51 - Split 2 - Model: stacking_regressor
# 11:31:51 - Fitting the model
# 4742/4742 - 2s - 380us/step - loss: 4.7253 - rmse: 4.0586
# 3794/3794 - 1s - 336us/step - loss: 4.5189 - rmse: 4.0461
# 949/949 - 0s - 343us/step
# 3794/3794 - 2s - 397us/step - loss: 4.8349 - rmse: 3.9773
# 949/949 - 0s - 408us/step
# 3794/3794 - 2s - 415us/step - loss: 4.9385 - rmse: 4.1437
# 949/949 - 0s - 405us/step
# 3794/3794 - 2s - 400us/step - loss: 4.8331 - rmse: 4.1348
# 949/949 - 0s - 415us/step
# 3794/3794 - 2s - 499us/step - loss: 4.5283 - rmse: 3.9810
# 949/949 - 0s - 413us/step
# 11:38:25 - Predicting
# 527/527 - 0s - 548us/step
# 11:38:29 - Calculating scores
# 11:38:29 - R^2: 0.6163904282166788, RMSE: 2.0219213607717568, MAE: 1.5023299988453858, MSE: 4.0881659891451125
# 11:38:29 - Split 3 - Model: stacking_regressor
# 11:38:29 - Fitting the model
# 4742/4742 - 4s - 850us/step - loss: 4.7440 - rmse: 4.0654
# 3794/3794 - 2s - 638us/step - loss: 4.5098 - rmse: 4.0463
# 949/949 - 1s - 701us/step
# 3794/3794 - 2s - 656us/step - loss: 4.8654 - rmse: 3.9798
# 949/949 - 1s - 662us/step
# 3794/3794 - 3s - 659us/step - loss: 4.9478 - rmse: 4.1442
# 949/949 - 1s - 698us/step
# 3794/3794 - 2s - 598us/step - loss: 4.8387 - rmse: 4.1397
# 949/949 - 1s - 654us/step
# 3794/3794 - 2s - 644us/step - loss: 4.5084 - rmse: 3.9835
# 949/949 - 1s - 681us/step
# 11:47:13 - Predicting
# 527/527 - 0s - 733us/step
# 11:47:17 - Calculating scores
# 11:47:17 - R^2: 0.6192624741738582, RMSE: 2.0142406418456074, MAE: 1.5140228560806395, MSE: 4.057165363262604
# 11:47:17 - Split 4 - Model: stacking_regressor
# 11:47:17 - Fitting the model
# 4742/4742 - 3s - 541us/step - loss: 4.7548 - rmse: 4.0614
# 3794/3794 - 2s - 632us/step - loss: 4.5138 - rmse: 4.0438
# 949/949 - 1s - 716us/step
# 3794/3794 - 2s - 626us/step - loss: 4.8475 - rmse: 3.9783
# 949/949 - 1s - 674us/step
# 3794/3794 - 2s - 598us/step - loss: 4.9952 - rmse: 4.1509
# 949/949 - 1s - 660us/step
# 3794/3794 - 3s - 662us/step - loss: 4.8771 - rmse: 4.1502
# 949/949 - 1s - 635us/step
# 3794/3794 - 2s - 637us/step - loss: 4.4898 - rmse: 3.9837
# 949/949 - 1s - 664us/step
# 11:56:05 - Predicting
# 527/527 - 0s - 770us/step
# 11:56:09 - Calculating scores
# 11:56:09 - R^2: 0.6075337518676744, RMSE: 2.024177833971157, MAE: 1.5143191988164741, MSE: 4.097295903540164
# 11:56:09 - Split 5 - Model: stacking_regressor
# 11:56:09 - Fitting the model
# 4742/4742 - 4s - 832us/step - loss: 4.7690 - rmse: 4.0554
# 3794/3794 - 2s - 461us/step - loss: 4.4996 - rmse: 4.0353
# 949/949 - 0s - 490us/step
# 3794/3794 - 2s - 478us/step - loss: 4.9824 - rmse: 3.9819
# 949/949 - 0s - 468us/step
# 3794/3794 - 2s - 467us/step - loss: 4.9365 - rmse: 4.1464
# 949/949 - 0s - 467us/step
# 3794/3794 - 2s - 471us/step - loss: 4.8735 - rmse: 4.1403
# 949/949 - 0s - 497us/step
# 3794/3794 - 2s - 491us/step - loss: 4.5459 - rmse: 3.9862
# 949/949 - 0s - 465us/step
# 12:06:01 - Predicting
# 527/527 - 0s - 704us/step
# 12:06:05 - Calculating scores
# 12:06:05 - R^2: 0.6254089130702329, RMSE: 2.0121714466181015, MAE: 1.493139725324937, MSE: 4.048833930585183
# 12:06:05 - Split 6 - Model: stacking_regressor
# 12:06:05 - Fitting the model
# 4742/4742 - 2s - 458us/step - loss: 4.7372 - rmse: 4.0545
# 3794/3794 - 2s - 470us/step - loss: 4.4924 - rmse: 4.0460
# 949/949 - 0s - 482us/step
# 3794/3794 - 4s - 943us/step - loss: 4.8780 - rmse: 3.9767
# 949/949 - 1s - 1ms/step
# 3794/3794 - 4s - 1ms/step - loss: 4.9482 - rmse: 4.1360
# 949/949 - 1s - 545us/step
# 3794/3794 - 1s - 382us/step - loss: 4.8447 - rmse: 4.1320
# 949/949 - 0s - 389us/step
# 3794/3794 - 1s - 387us/step - loss: 4.5474 - rmse: 3.9833
# 949/949 - 0s - 377us/step
# 12:13:44 - Predicting
# 527/527 - 0s - 538us/step
# 12:13:47 - Calculating scores
# 12:13:47 - R^2: 0.614383375495829, RMSE: 2.028867729397863, MAE: 1.5132621135464004, MSE: 4.116304263392041
# 12:13:47 - Split 7 - Model: stacking_regressor
# 12:13:47 - Fitting the model
# 4742/4742 - 3s - 621us/step - loss: 4.6926 - rmse: 4.0511
# 3794/3794 - 2s - 539us/step - loss: 4.4734 - rmse: 4.0364
# 949/949 - 1s - 549us/step
# 3794/3794 - 2s - 538us/step - loss: 4.8828 - rmse: 3.9834
# 949/949 - 1s - 535us/step
# 3794/3794 - 2s - 529us/step - loss: 4.9930 - rmse: 4.1421
# 949/949 - 1s - 558us/step
# 3794/3794 - 2s - 532us/step - loss: 4.8272 - rmse: 4.1381
# 949/949 - 1s - 559us/step
# 3794/3794 - 2s - 582us/step - loss: 4.5248 - rmse: 3.9756
# 949/949 - 0s - 523us/step
# 12:21:44 - Predicting
# 527/527 - 0s - 564us/step
# 12:21:47 - Calculating scores
# 12:21:47 - R^2: 0.6071399902526242, RMSE: 2.0525545179012847, MAE: 1.5218032314719776, MSE: 4.212980048956976
# 12:21:47 - Split 8 - Model: stacking_regressor
# 12:21:47 - Fitting the model
# 4742/4742 - 3s - 579us/step - loss: 4.7328 - rmse: 4.0578
# 3794/3794 - 2s - 581us/step - loss: 4.4972 - rmse: 4.0450
# 949/949 - 1s - 555us/step
# 3794/3794 - 2s - 546us/step - loss: 4.8868 - rmse: 3.9785
# 949/949 - 1s - 548us/step
# 3794/3794 - 2s - 555us/step - loss: 4.9460 - rmse: 4.1334
# 949/949 - 1s - 551us/step
# 3794/3794 - 3s - 665us/step - loss: 4.8151 - rmse: 4.1277
# 949/949 - 1s - 569us/step
# 3794/3794 - 2s - 583us/step - loss: 4.5166 - rmse: 3.9728
# 949/949 - 1s - 550us/step
# 12:30:19 - Predicting
# 527/527 - 0s - 577us/step
# 12:30:22 - Calculating scores
# 12:30:22 - R^2: 0.6260045637303793, RMSE: 2.016690296975024, MAE: 1.5000265239154604, MSE: 4.067039753913211
# 12:30:22 - Split 9 - Model: stacking_regressor
# 12:30:22 - Fitting the model
# 4742/4742 - 3s - 547us/step - loss: 4.7716 - rmse: 4.0589
# 3794/3794 - 2s - 646us/step - loss: 4.5168 - rmse: 4.0537
# 949/949 - 1s - 601us/step
# 3794/3794 - 3s - 732us/step - loss: 4.9475 - rmse: 3.9838
# 949/949 - 1s - 594us/step
# 3794/3794 - 2s - 570us/step - loss: 4.9656 - rmse: 4.1462
# 949/949 - 1s - 660us/step
# 3794/3794 - 2s - 574us/step - loss: 4.8785 - rmse: 4.1482
# 949/949 - 2s - 2ms/step
# 3794/3794 - 6s - 1ms/step - loss: 4.5503 - rmse: 3.9849
# 949/949 - 1s - 1ms/step
# 12:40:25 - Predicting
# 527/527 - 0s - 625us/step
# 12:40:30 - Calculating scores
# 12:40:30 - R^2: 0.6131539835180483, RMSE: 2.007838297636669, MAE: 1.4890851431517274, MSE: 4.031414629456517
# 12:40:30 - Split 10 - Model: stacking_regressor
# 12:40:30 - Fitting the model
# 4742/4742 - 3s - 555us/step - loss: 4.7351 - rmse: 4.0587
# 3794/3794 - 3s - 678us/step - loss: 4.5101 - rmse: 4.0545
# 949/949 - 1s - 687us/step
# 3794/3794 - 2s - 642us/step - loss: 4.8707 - rmse: 3.9777
# 949/949 - 0s - 440us/step
# 3794/3794 - 2s - 448us/step - loss: 4.9680 - rmse: 4.1422
# 949/949 - 1s - 750us/step
# 3794/3794 - 3s - 689us/step - loss: 4.8292 - rmse: 4.1382
# 949/949 - 1s - 641us/step
# 3794/3794 - 2s - 655us/step - loss: 4.4996 - rmse: 3.9868
# 949/949 - 1s - 654us/step
# 12:49:48 - Predicting
# 527/527 - 0s - 778us/step
# 12:49:52 - Calculating scores
# 12:49:52 - R^2: 0.602421746071439, RMSE: 2.0378360654450045, MAE: 1.5096583980842229, MSE: 4.152775829628377
# 12:49:52 - Training finished
# Final estimator RMSE: 2.026048002690131
# Final estimator R2: 0.6145798028405757
# Final estimator MSE: 4.105065509189784
# Final estimator MAE: 1.5067485706858965

# %%
import numpy as np
from pipelines import pipeline

train_data_transformed = pipeline.fit_transform(augmented_data)

X_train = train_data_transformed.drop(columns=['bg+1:00'])
y_train = train_data_transformed['bg+1:00']

model.fit(X_train, y_train)

X_test = pipeline.transform(test_data)
y_pred = model.predict(X_test)

if np.sum(y_pred < 0) > 0:
    print(f'Number of negative values: {np.sum(y_pred < 0)}')
    bg_min_train = np.min(y_train)
    print(f'Min value: {np.min(y_pred)}')
    print(f'Filling negative values with {bg_min_train}')
    y_pred = np.where(y_pred < 0, bg_min_train, y_pred)

test_data['bg+1:00'] = y_pred
test_data.head()
# Out:
# 5269/5269 - 2s - 345us/step - loss: 4.7240 - rmse: 4.0548
# 4215/4215 - 1s - 354us/step - loss: 4.4949 - rmse: 4.0449
# 1054/1054 - 0s - 361us/step
# 4215/4215 - 1s - 350us/step - loss: 4.8941 - rmse: 3.9812
# 1054/1054 - 0s - 366us/step
# 4215/4215 - 1s - 347us/step - loss: 4.9452 - rmse: 4.1428
# 1054/1054 - 0s - 356us/step
# 4215/4215 - 1s - 351us/step - loss: 4.8021 - rmse: 4.1380
# 1054/1054 - 0s - 359us/step
# 4215/4215 - 1s - 345us/step - loss: 4.5404 - rmse: 3.9815
# 1054/1054 - 0s - 355us/step
# 114/114 - 0s - 1ms/step
#          p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# id
# p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#           bg-5:30  bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  \
# id                                   ...
# p01_8459      NaN      NaN     10.3  ...            NaN            NaN
# p01_8460      9.4      NaN      NaN  ...            NaN            NaN
# p01_8461      NaN      NaN      5.2  ...            NaN            NaN
# p01_8462      NaN      NaN      4.7  ...            NaN            NaN
# p01_8463     10.0      NaN      NaN  ...            NaN            NaN
#
#           activity-0:30  activity-0:25  activity-0:20  activity-0:15  \
# id
# p01_8459            NaN            NaN            NaN            NaN
# p01_8460            NaN            NaN            NaN            NaN
# p01_8461            NaN            NaN            NaN            NaN
# p01_8462            NaN            NaN            NaN            NaN
# p01_8463            NaN            NaN            NaN            NaN
#
#           activity-0:10  activity-0:05  activity-0:00    bg+1:00
# id
# p01_8459            NaN            NaN            NaN   8.507765
# p01_8460           Walk           Walk           Walk   7.002129
# p01_8461            NaN            NaN            NaN   7.476150
# p01_8462            NaN            NaN            NaN  11.490660
# p01_8463            NaN            NaN            NaN   6.922920
#
# [5 rows x 507 columns]

# %%
submission = pd.DataFrame(test_data['bg+1:00'])
submission
# Out:
#             bg+1:00
# id
# p01_8459   8.507765
# p01_8460   7.002129
# p01_8461   7.476150
# p01_8462  11.490660
# p01_8463   6.922920
# ...             ...
# p24_256    6.412598
# p24_257   12.099834
# p24_258    6.468861
# p24_259    9.149744
# p24_260    6.092334
#
# [3644 rows x 1 columns]

# %%
submission.to_csv(f'submission-model-{model_name}.csv')

# %%
y_pred = model.predict(X_train)

root_mean_squared_error(y_train, y_pred)
# Out:
# 5269/5269 - 2s - 302us/step
# np.float64(1.999845783959753)

# %%
from sklearn.metrics import root_mean_squared_error

root_mean_squared_error(y_train, y_pred)
# Out:
# np.float64(1.999845783959753)
