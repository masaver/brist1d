# %% [markdown]
# # Predict for each patient

# %%
from data import load_data

train_data, test_data = load_data()

unique_patients = test_data['p_num'].unique()
train_data = train_data[train_data['p_num'].isin(unique_patients)]
test_data = test_data[test_data['p_num'].isin(unique_patients)]

train_data.head()
# Out:
#       p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# id
# p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN      9.7
# p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN      9.2
# p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN      8.7
# p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN      8.4
# p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN      8.1
#
#        bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  activity-0:30  \
# id                       ...
# p01_0      NaN      NaN  ...            NaN            NaN            NaN
# p01_1      NaN      NaN  ...            NaN            NaN            NaN
# p01_2      NaN      NaN  ...            NaN            NaN            NaN
# p01_3      NaN      NaN  ...            NaN            NaN            NaN
# p01_4      NaN      NaN  ...            NaN            NaN            NaN
#
#        activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# id
# p01_0            NaN            NaN            NaN            NaN
# p01_1            NaN            NaN            NaN            NaN
# p01_2            NaN            NaN            NaN            NaN
# p01_3            NaN            NaN            NaN            NaN
# p01_4            NaN            NaN            NaN            NaN
#
#        activity-0:05  activity-0:00  bg+1:00
# id
# p01_0            NaN            NaN     13.4
# p01_1            NaN            NaN     12.8
# p01_2            NaN            NaN     15.5
# p01_3            NaN            NaN     14.8
# p01_4            NaN            NaN     12.7
#
# [5 rows x 507 columns]

# %%
from sklearn.ensemble import VotingRegressor
from pipelines import pipeline
import joblib
import re
import os
import datetime


def get_date_time_now():
    return datetime.datetime.now().strftime('%H:%M:%S')


models = {}
results = test_data[[]].copy()
results.loc[:, 'bg+1:00'] = -1.0
results['bg+1:00'] = results['bg+1:00'].astype(float)
for p_num in unique_patients:
    print(f'{get_date_time_now()} - {p_num} - Predicting for patient {p_num}')
    stored_models = [file for file in os.listdir() if file.endswith('.model.pkl') and file.startswith(f'{p_num}')]
    # filter out all models that have extratrees and LGBM in the name
    stored_models = [file for file in stored_models if not re.search(r'ExtraTrees|LGBM', file)]
    estimators = []
    print(f'{get_date_time_now()} - {p_num} - Found {len(stored_models)} models')
    for model_file in stored_models:
        print(f'{get_date_time_now()} - {p_num} - Loading {model_file}')
        model = joblib.load(model_file)
        estimators.append((
            model_file.replace('.model.pkl', ''),
            model
        ))

    print(f'{get_date_time_now()} - {p_num} - Transforming the data -')
    train_data_patient = train_data[train_data['p_num'] == p_num]
    train_data_patient = pipeline.fit_transform(train_data_patient)

    X_train = train_data_patient.drop(columns=['bg+1:00'])
    y_train = train_data_patient['bg+1:00']

    print(f'{get_date_time_now()} - {p_num} - Fitting the model -')
    model = VotingRegressor(estimators=estimators, verbose=True)
    model.fit(X=X_train, y=y_train)

    print(f'{get_date_time_now()} - {p_num} - Predicting -')
    test_data_patient = test_data[test_data['p_num'] == p_num]
    X_test = pipeline.transform(test_data_patient)
    results.loc[test_data_patient.index, 'bg+1:00'] = model.predict(X=X_test)
    print(f'{get_date_time_now()} - {p_num} - Done -')

results.head()
# Out:
# 15:32:26 - p01 - Predicting for patient p01
# 15:32:26 - p01 - Found 3 models
# 15:32:26 - p01 - Loading p01.LassoLarsIC.model.pkl
# 15:32:26 - p01 - Loading p01.XGBRegressor.model.pkl
# 15:32:26 - p01 - Loading p01.HistGradientBoostingRegressor.model.pkl
# 15:32:26 - p01 - Transforming the data -
# 15:32:28 - p01 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p01.LassoLarsIC, total=   0.0s
# [Voting] ......... (2 of 3) Processing p01.XGBRegressor, total=  19.0s
# [Voting]  (3 of 3) Processing p01.HistGradientBoostingRegressor, total=   5.4s
# 15:32:52 - p01 - Predicting -
# 15:32:52 - p01 - Done -
# 15:32:52 - p02 - Predicting for patient p02
# 15:32:52 - p02 - Found 3 models
# 15:32:52 - p02 - Loading p02.XGBRegressor.model.pkl
# 15:32:53 - p02 - Loading p02.LassoLarsIC.model.pkl
# 15:32:53 - p02 - Loading p02.HistGradientBoostingRegressor.model.pkl
# 15:32:53 - p02 - Transforming the data -
# 15:32:56 - p02 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p02.XGBRegressor, total=   9.5s
# [Voting] .......... (2 of 3) Processing p02.LassoLarsIC, total=   0.1s
# [Voting]  (3 of 3) Processing p02.HistGradientBoostingRegressor, total=  11.3s
# 15:33:17 - p02 - Predicting -
# 15:33:17 - p02 - Done -
# 15:33:17 - p04 - Predicting for patient p04
# 15:33:17 - p04 - Found 3 models
# 15:33:17 - p04 - Loading p04.LassoLarsIC.model.pkl
# 15:33:17 - p04 - Loading p04.HistGradientBoostingRegressor.model.pkl
# 15:33:17 - p04 - Loading p04.XGBRegressor.model.pkl
# 15:33:17 - p04 - Transforming the data -
# 15:33:21 - p04 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p04.LassoLarsIC, total=   0.1s
# [Voting]  (2 of 3) Processing p04.HistGradientBoostingRegressor, total=   8.3s
# [Voting] ......... (3 of 3) Processing p04.XGBRegressor, total=  21.6s
# 15:33:51 - p04 - Predicting -
# 15:33:51 - p04 - Done -
# 15:33:51 - p05 - Predicting for patient p05
# 15:33:51 - p05 - Found 3 models
# 15:33:51 - p05 - Loading p05.LassoLarsIC.model.pkl
# 15:33:51 - p05 - Loading p05.XGBRegressor.model.pkl
# 15:33:51 - p05 - Loading p05.HistGradientBoostingRegressor.model.pkl
# 15:33:51 - p05 - Transforming the data -
# 15:33:53 - p05 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p05.LassoLarsIC, total=   0.0s
# [Voting] ......... (2 of 3) Processing p05.XGBRegressor, total=  13.5s
# [Voting]  (3 of 3) Processing p05.HistGradientBoostingRegressor, total=   7.1s
# 15:34:14 - p05 - Predicting -
# 15:34:14 - p05 - Done -
# 15:34:14 - p06 - Predicting for patient p06
# 15:34:14 - p06 - Found 3 models
# 15:34:14 - p06 - Loading p06.HistGradientBoostingRegressor.model.pkl
# 15:34:14 - p06 - Loading p06.LassoLarsIC.model.pkl
# 15:34:14 - p06 - Loading p06.XGBRegressor.model.pkl
# 15:34:14 - p06 - Transforming the data -
# 15:34:16 - p06 - Fitting the model -
# [Voting]  (1 of 3) Processing p06.HistGradientBoostingRegressor, total=   6.7s
# [Voting] .......... (2 of 3) Processing p06.LassoLarsIC, total=   0.1s
# [Voting] ......... (3 of 3) Processing p06.XGBRegressor, total=  16.3s
# 15:34:39 - p06 - Predicting -
# 15:34:39 - p06 - Done -
# 15:34:39 - p10 - Predicting for patient p10
# 15:34:39 - p10 - Found 3 models
# 15:34:39 - p10 - Loading p10.HistGradientBoostingRegressor.model.pkl
# 15:34:39 - p10 - Loading p10.XGBRegressor.model.pkl
# 15:34:40 - p10 - Loading p10.LassoLarsIC.model.pkl
# 15:34:40 - p10 - Transforming the data -
# 15:34:43 - p10 - Fitting the model -
# [Voting]  (1 of 3) Processing p10.HistGradientBoostingRegressor, total=   8.1s
# [Voting] ......... (2 of 3) Processing p10.XGBRegressor, total=   9.9s
# [Voting] .......... (3 of 3) Processing p10.LassoLarsIC, total=   0.1s
# 15:35:01 - p10 - Predicting -
# 15:35:01 - p10 - Done -
# 15:35:01 - p11 - Predicting for patient p11
# 15:35:01 - p11 - Found 3 models
# 15:35:01 - p11 - Loading p11.XGBRegressor.model.pkl
# 15:35:01 - p11 - Loading p11.LassoLarsIC.model.pkl
# 15:35:01 - p11 - Loading p11.HistGradientBoostingRegressor.model.pkl
# 15:35:01 - p11 - Transforming the data -
# 15:35:04 - p11 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p11.XGBRegressor, total=  15.4s
# [Voting] .......... (2 of 3) Processing p11.LassoLarsIC, total=   0.1s
# [Voting]  (3 of 3) Processing p11.HistGradientBoostingRegressor, total=   7.8s
# 15:35:27 - p11 - Predicting -
# 15:35:27 - p11 - Done -
# 15:35:27 - p12 - Predicting for patient p12
# 15:35:27 - p12 - Found 3 models
# 15:35:27 - p12 - Loading p12.XGBRegressor.model.pkl
# 15:35:27 - p12 - Loading p12.HistGradientBoostingRegressor.model.pkl
# 15:35:27 - p12 - Loading p12.LassoLarsIC.model.pkl
# 15:35:27 - p12 - Transforming the data -
# 15:35:31 - p12 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p12.XGBRegressor, total=  17.6s
# [Voting]  (2 of 3) Processing p12.HistGradientBoostingRegressor, total=   7.1s
# [Voting] .......... (3 of 3) Processing p12.LassoLarsIC, total=   0.1s
# 15:35:55 - p12 - Predicting -
# 15:35:55 - p12 - Done -
# 15:35:55 - p15 - Predicting for patient p15
# 15:35:55 - p15 - Found 3 models
# 15:35:55 - p15 - Loading p15.HistGradientBoostingRegressor.model.pkl
# 15:35:55 - p15 - Loading p15.XGBRegressor.model.pkl
# 15:35:55 - p15 - Loading p15.LassoLarsIC.model.pkl
# 15:35:55 - p15 - Transforming the data -
# 15:35:57 - p15 - Fitting the model -
# [Voting]  (1 of 3) Processing p15.HistGradientBoostingRegressor, total=   4.3s
# [Voting] ......... (2 of 3) Processing p15.XGBRegressor, total=   8.3s
# [Voting] .......... (3 of 3) Processing p15.LassoLarsIC, total=   0.0s
# 15:36:09 - p15 - Predicting -
# 15:36:10 - p15 - Done -
# 15:36:10 - p16 - Predicting for patient p16
# 15:36:10 - p16 - Found 3 models
# 15:36:10 - p16 - Loading p16.XGBRegressor.model.pkl
# 15:36:10 - p16 - Loading p16.HistGradientBoostingRegressor.model.pkl
# 15:36:10 - p16 - Loading p16.LassoLarsIC.model.pkl
# 15:36:10 - p16 - Transforming the data -
# 15:36:11 - p16 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p16.XGBRegressor, total=   9.1s
# [Voting]  (2 of 3) Processing p16.HistGradientBoostingRegressor, total=   4.8s
# [Voting] .......... (3 of 3) Processing p16.LassoLarsIC, total=   0.0s
# 15:36:25 - p16 - Predicting -
# 15:36:25 - p16 - Done -
# 15:36:25 - p18 - Predicting for patient p18
# 15:36:25 - p18 - Found 3 models
# 15:36:25 - p18 - Loading p18.HistGradientBoostingRegressor.model.pkl
# 15:36:25 - p18 - Loading p18.XGBRegressor.model.pkl
# 15:36:25 - p18 - Loading p18.LassoLarsIC.model.pkl
# 15:36:25 - p18 - Transforming the data -
# 15:36:26 - p18 - Fitting the model -
# [Voting]  (1 of 3) Processing p18.HistGradientBoostingRegressor, total=   4.2s
# [Voting] ......... (2 of 3) Processing p18.XGBRegressor, total=  12.0s
# [Voting] .......... (3 of 3) Processing p18.LassoLarsIC, total=   0.0s
# 15:36:43 - p18 - Predicting -
# 15:36:43 - p18 - Done -
# 15:36:43 - p19 - Predicting for patient p19
# 15:36:43 - p19 - Found 3 models
# 15:36:43 - p19 - Loading p19.LassoLarsIC.model.pkl
# 15:36:43 - p19 - Loading p19.HistGradientBoostingRegressor.model.pkl
# 15:36:43 - p19 - Loading p19.XGBRegressor.model.pkl
# 15:36:43 - p19 - Transforming the data -
# 15:36:44 - p19 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p19.LassoLarsIC, total=   0.0s
# [Voting]  (2 of 3) Processing p19.HistGradientBoostingRegressor, total=   4.7s
# [Voting] ......... (3 of 3) Processing p19.XGBRegressor, total=  13.4s
# 15:37:02 - p19 - Predicting -
# 15:37:02 - p19 - Done -
# 15:37:02 - p21 - Predicting for patient p21
# 15:37:02 - p21 - Found 3 models
# 15:37:02 - p21 - Loading p21.HistGradientBoostingRegressor.model.pkl
# 15:37:02 - p21 - Loading p21.LassoLarsIC.model.pkl
# 15:37:02 - p21 - Loading p21.XGBRegressor.model.pkl
# 15:37:03 - p21 - Transforming the data -
# 15:37:04 - p21 - Fitting the model -
# [Voting]  (1 of 3) Processing p21.HistGradientBoostingRegressor, total=   4.3s
# [Voting] .......... (2 of 3) Processing p21.LassoLarsIC, total=   0.0s
# [Voting] ......... (3 of 3) Processing p21.XGBRegressor, total=  22.2s
# 15:37:30 - p21 - Predicting -
# 15:37:30 - p21 - Done -
# 15:37:30 - p22 - Predicting for patient p22
# 15:37:30 - p22 - Found 3 models
# 15:37:30 - p22 - Loading p22.HistGradientBoostingRegressor.model.pkl
# 15:37:30 - p22 - Loading p22.XGBRegressor.model.pkl
# 15:37:30 - p22 - Loading p22.LassoLarsIC.model.pkl
# 15:37:30 - p22 - Transforming the data -
# 15:37:32 - p22 - Fitting the model -
# [Voting]  (1 of 3) Processing p22.HistGradientBoostingRegressor, total=   5.7s
# [Voting] ......... (2 of 3) Processing p22.XGBRegressor, total=   5.6s
# [Voting] .......... (3 of 3) Processing p22.LassoLarsIC, total=   0.0s
# 15:37:43 - p22 - Predicting -
# 15:37:43 - p22 - Done -
# 15:37:43 - p24 - Predicting for patient p24
# 15:37:43 - p24 - Found 3 models
# 15:37:43 - p24 - Loading p24.XGBRegressor.model.pkl
# 15:37:43 - p24 - Loading p24.HistGradientBoostingRegressor.model.pkl
# 15:37:43 - p24 - Loading p24.LassoLarsIC.model.pkl
# 15:37:43 - p24 - Transforming the data -
# 15:37:44 - p24 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p24.XGBRegressor, total=  13.1s
# [Voting]  (2 of 3) Processing p24.HistGradientBoostingRegressor, total=   5.2s
# [Voting] .......... (3 of 3) Processing p24.LassoLarsIC, total=   0.0s
# 15:38:03 - p24 - Predicting -
# 15:38:03 - p24 - Done -
#             bg+1:00
# id
# p01_8459   8.999951
# p01_8460   6.072640
# p01_8461   8.654432
# p01_8462  10.230786
# p01_8463   6.663246

# %%
# check if all results are greater than 0
assert (results['bg+1:00'] >= 0).all()

# %% [markdown]
# ## Prepare the submission file

# %%
submission = results
submission
# Out:
#             bg+1:00
# id
# p01_8459   8.999951
# p01_8460   6.072640
# p01_8461   8.654432
# p01_8462  10.230786
# p01_8463   6.663246
# ...             ...
# p24_256    6.550876
# p24_257   10.138702
# p24_258    6.363535
# p24_259    7.973009
# p24_260    6.699743
#
# [3644 rows x 1 columns]

# %% [markdown]
# ### Save the submission file

# %%
submission.to_csv(f'submission-{os.path.basename(os.getcwd())}.csv')
