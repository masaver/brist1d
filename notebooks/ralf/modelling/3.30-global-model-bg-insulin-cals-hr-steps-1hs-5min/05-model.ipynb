# %% [markdown]
# # Create a baseline model

# %%
import pandas as pd

from data import load_data_selected_features

train_data, additional_train_data, test_data = load_data_selected_features()

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150996 entries, p01_0 to p12_25298
# Columns: 507 entries, p_num to bg+1:00
# dtypes: float64(433), object(74)
# memory usage: 585.2+ MB

# %%
additional_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168588 entries, p01_test_12 to p24_test_94938
# Columns: 507 entries, p_num to bg+1:00
# dtypes: float64(433), object(74)
# memory usage: 657.4+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3644 entries, p01_8459 to p24_260
# Columns: 506 entries, p_num to activity-0:00
# dtypes: float64(432), object(74)
# memory usage: 14.2+ MB

# %% [markdown]
# # Prepare the data

# %%
from pipelines_selected_features import pipeline

all_train_data = pd.concat([train_data, additional_train_data], axis=0)
all_train_data_transformed = pipeline.fit_transform(all_train_data)

train_data_transformed = all_train_data_transformed[:len(train_data)]
additional_train_data_transformed = all_train_data_transformed[len(train_data):]

X_train = train_data_transformed.drop(columns=['bg+1:00'])
y_train = train_data_transformed['bg+1:00']

X_additional_train = additional_train_data_transformed.drop(columns=['bg+1:00'])
y_additional_train = additional_train_data_transformed['bg+1:00']

# %% [markdown]
# ## Create the model

# %%
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import StackingRegressor, HistGradientBoostingRegressor
from sklearn.linear_model import LassoLarsIC, Ridge

hgb_estimator = HistGradientBoostingRegressor(
    l2_regularization=0.0001,
    learning_rate=0.1,
    max_depth=11,
    max_iter=1500,
    min_samples_leaf=10,
    n_iter_no_change=22,
    random_state=42,
)

lasso_lars_ic_base_model = LassoLarsIC(
    criterion='aic',
    eps=0.03922948513965659,
    max_iter=1944,
    noise_variance=5.4116687755186035e-05,
    positive=False,
)
knn_base_model = KNeighborsRegressor(n_neighbors=5)
xgb_base_model = XGBRegressor(objective='reg:squarederror', random_state=42, n_estimators=500, max_depth=5, learning_rate=0.1)

estimators = [
    ('hgb', hgb_estimator),
    ('lasso_lars_ic', lasso_lars_ic_base_model),
    ('knn', knn_base_model),
    ('xgb', xgb_base_model),
]

model = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=0.1), n_jobs=-1, verbose=2)

# %%
from datetime import datetime
import os
from model_performance_calculations import calculate_stacking_regressor_performance, get_rmse_boxplot_chart, get_rmse_line_chart, save_performances, save_model

date_time = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
model_name = f'{date_time}-model-stacking-tuned-LLIC-HGB'

save_model(model, os.path.join('models', f'{model_name}.pkl'))

performances = calculate_stacking_regressor_performance(model, X_train, y_train, X_additional_train, y_additional_train)
save_performances(performances, os.path.join('models', f'{model_name}-performances.json'))

get_rmse_boxplot_chart(performances).show()
get_rmse_line_chart(performances).show()
# Out:
# 23:40:16 - 23:40:16 - Start training
# 23:40:16 - 23:40:16 - Calculate performance for hgb
# 23:40:16 - 23:40:16 - Splitting the additional train data with ShuffleSplit
# 23:40:16 - 23:40:16 - Split 1 - Model: hgb
# 23:40:17 - 23:40:17 - Fitting the model
# 23:40:59 - 23:40:59 - Predicting
# 23:40:59 - 23:40:59 - Calculating scores
# 23:41:00 - 23:41:00 - R^2: 0.6802980598686639, RMSE: 1.853234323545247, MAE: 1.3781103796392653, MSE: 3.4344774579662096
# 23:41:00 - 23:41:00 - Split 2 - Model: hgb
# 23:41:00 - 23:41:00 - Fitting the model
# 23:41:41 - 23:41:41 - Predicting
# 23:41:41 - 23:41:41 - Calculating scores
# 23:41:42 - 23:41:42 - R^2: 0.6790084797635141, RMSE: 1.8599546082369873, MAE: 1.389380261014941, MSE: 3.4594311447020054
# 23:41:42 - 23:41:42 - Split 3 - Model: hgb
# 23:41:42 - 23:41:42 - Fitting the model
# 23:42:27 - 23:42:27 - Predicting
# 23:42:28 - 23:42:28 - Calculating scores
# 23:42:28 - 23:42:28 - R^2: 0.6768352388557501, RMSE: 1.8473604416799103, MAE: 1.3794091734729261, MSE: 3.4127406014837933
# 23:42:28 - 23:42:28 - Split 4 - Model: hgb
# 23:42:28 - 23:42:28 - Fitting the model
# 23:43:12 - 23:43:12 - Predicting
# 23:43:13 - 23:43:13 - Calculating scores
# 23:43:13 - 23:43:13 - R^2: 0.6785663328204601, RMSE: 1.863893799320436, MAE: 1.3902225303104778, MSE: 3.47410009514517
# 23:43:13 - 23:43:13 - Split 5 - Model: hgb
# 23:43:13 - 23:43:13 - Fitting the model
# 23:43:55 - 23:43:55 - Predicting
# 23:43:55 - 23:43:55 - Calculating scores
# 23:43:56 - 23:43:56 - R^2: 0.6718372197374366, RMSE: 1.8594547635122383, MAE: 1.3846466077502462, MSE: 3.457572017548354
# 23:43:56 - 23:43:56 - Split 6 - Model: hgb
# 23:43:56 - 23:43:56 - Fitting the model
# 23:44:38 - 23:44:38 - Predicting
# 23:44:38 - 23:44:38 - Calculating scores
# 23:44:38 - 23:44:38 - R^2: 0.6735222799440113, RMSE: 1.8608965858476423, MAE: 1.3861808405611753, MSE: 3.4629361032194117
# 23:44:39 - 23:44:39 - Split 7 - Model: hgb
# 23:44:39 - 23:44:39 - Fitting the model
# 23:45:21 - 23:45:21 - Predicting
# 23:45:21 - 23:45:21 - Calculating scores
# 23:45:22 - 23:45:22 - R^2: 0.6807885824319322, RMSE: 1.8456464950494869, MAE: 1.370365022332402, MSE: 3.4064109846884554
# 23:45:22 - 23:45:22 - Split 8 - Model: hgb
# 23:45:22 - 23:45:22 - Fitting the model
# 23:46:03 - 23:46:03 - Predicting
# 23:46:03 - 23:46:03 - Calculating scores
# 23:46:04 - 23:46:04 - R^2: 0.6767991379024578, RMSE: 1.8453501860280934, MAE: 1.377793212400397, MSE: 3.405317309073919
# 23:46:04 - 23:46:04 - Split 9 - Model: hgb
# 23:46:04 - 23:46:04 - Fitting the model
# 23:46:44 - 23:46:44 - Predicting
# 23:46:45 - 23:46:45 - Calculating scores
# 23:46:45 - 23:46:45 - R^2: 0.6722819255148569, RMSE: 1.868954000781717, MAE: 1.3961042238024475, MSE: 3.492989057037986
# 23:46:45 - 23:46:45 - Split 10 - Model: hgb
# 23:46:45 - 23:46:45 - Fitting the model
# 23:47:27 - 23:47:27 - Predicting
# 23:47:27 - 23:47:27 - Calculating scores
# 23:47:27 - 23:47:27 - R^2: 0.6764572132678928, RMSE: 1.8611543365909093, MAE: 1.3882459154917073, MSE: 3.463895464611148
# 23:47:27 - 23:47:27 - Training finished
# 23:47:27 - 23:47:27 - Calculate performance for lasso_lars_ic
# 23:47:27 - 23:47:27 - Splitting the additional train data with ShuffleSplit
# 23:47:27 - 23:47:27 - Split 1 - Model: lasso_lars_ic
# 23:47:28 - 23:47:28 - Fitting the model
# 23:47:28 - 23:47:28 - Predicting
# 23:47:28 - 23:47:28 - Calculating scores
# 23:47:28 - 23:47:28 - R^2: 0.5504740932335763, RMSE: 2.1975312622084426, MAE: 1.646579945121024, MSE: 4.829143648383432
# 23:47:28 - 23:47:28 - Split 2 - Model: lasso_lars_ic
# 23:47:28 - 23:47:28 - Fitting the model
# 23:47:28 - 23:47:28 - Predicting
# 23:47:28 - 23:47:28 - Calculating scores
# 23:47:28 - 23:47:28 - R^2: 0.5482092252184848, RMSE: 2.206603207032864, MAE: 1.6617097760265074, MSE: 4.8690977132877205
# 23:47:28 - 23:47:28 - Split 3 - Model: lasso_lars_ic
# 23:47:28 - 23:47:28 - Fitting the model
# 23:47:29 - 23:47:29 - Predicting
# 23:47:29 - 23:47:29 - Calculating scores
# 23:47:29 - 23:47:29 - R^2: 0.5506213302018087, RMSE: 2.178441329543595, MAE: 1.6381996302844015, MSE: 4.745606626263665
# 23:47:29 - 23:47:29 - Split 4 - Model: lasso_lars_ic
# 23:47:29 - 23:47:29 - Fitting the model
# 23:47:29 - 23:47:29 - Predicting
# 23:47:29 - 23:47:29 - Calculating scores
# 23:47:29 - 23:47:29 - R^2: 0.5496599326190281, RMSE: 2.2062045515456292, MAE: 1.6608630324760758, MSE: 4.86733852326065
# 23:47:29 - 23:47:29 - Split 5 - Model: lasso_lars_ic
# 23:47:29 - 23:47:29 - Fitting the model
# 23:47:29 - 23:47:29 - Predicting
# 23:47:29 - 23:47:29 - Calculating scores
# 23:47:29 - 23:47:29 - R^2: 0.5406542484253587, RMSE: 2.199939857568177, MAE: 1.6544598716097572, MSE: 4.8397353769170905
# 23:47:29 - 23:47:29 - Split 6 - Model: lasso_lars_ic
# 23:47:29 - 23:47:29 - Fitting the model
# 23:47:30 - 23:47:30 - Predicting
# 23:47:30 - 23:47:30 - Calculating scores
# 23:47:30 - 23:47:30 - R^2: 0.542715885682558, RMSE: 2.20236107147833, MAE: 1.6580373429763904, MSE: 4.850394289163178
# 23:47:30 - 23:47:30 - Split 7 - Model: lasso_lars_ic
# 23:47:30 - 23:47:30 - Fitting the model
# 23:47:30 - 23:47:30 - Predicting
# 23:47:30 - 23:47:30 - Calculating scores
# 23:47:30 - 23:47:30 - R^2: 0.5480265764938147, RMSE: 2.1961690313836457, MAE: 1.6454703289564245, MSE: 4.82315841440858
# 23:47:30 - 23:47:30 - Split 8 - Model: lasso_lars_ic
# 23:47:30 - 23:47:30 - Fitting the model
# 23:47:30 - 23:47:30 - Predicting
# 23:47:30 - 23:47:30 - Calculating scores
# 23:47:30 - 23:47:30 - R^2: 0.5448195162861484, RMSE: 2.189950780889934, MAE: 1.6502519005925091, MSE: 4.795884422720433
# 23:47:30 - 23:47:30 - Split 9 - Model: lasso_lars_ic
# 23:47:30 - 23:47:30 - Fitting the model
# 23:47:31 - 23:47:31 - Predicting
# 23:47:31 - 23:47:31 - Calculating scores
# 23:47:31 - 23:47:31 - R^2: 0.5396066816676406, RMSE: 2.2151998908720736, MAE: 1.6606781112220077, MSE: 4.907110556519646
# 23:47:31 - 23:47:31 - Split 10 - Model: lasso_lars_ic
# 23:47:31 - 23:47:31 - Fitting the model
# 23:47:31 - 23:47:31 - Predicting
# 23:47:31 - 23:47:31 - Calculating scores
# 23:47:31 - 23:47:31 - R^2: 0.5470606605791345, RMSE: 2.202097525245346, MAE: 1.65867349414695, MSE: 4.849233510691678
# 23:47:31 - 23:47:31 - Training finished
# 23:47:31 - 23:47:31 - Calculate performance for knn
# 23:47:31 - 23:47:31 - Splitting the additional train data with ShuffleSplit
# 23:47:31 - 23:47:31 - Split 1 - Model: knn
# 23:47:31 - 23:47:31 - Fitting the model
# 23:47:31 - 23:47:31 - Predicting
# 23:47:40 - 23:47:40 - Calculating scores
# 23:47:49 - 23:47:49 - R^2: 0.5861675872638137, RMSE: 2.1084822569428217, MAE: 1.4492767068034877, MSE: 4.445697427842695
# 23:47:49 - 23:47:49 - Split 2 - Model: knn
# 23:47:49 - 23:47:49 - Fitting the model
# 23:47:49 - 23:47:49 - Predicting
# 23:47:58 - 23:47:58 - Calculating scores
# 23:48:06 - 23:48:06 - R^2: 0.5807738562489106, RMSE: 2.125591206824066, MAE: 1.4628966130849992, MSE: 4.518137978527789
# 23:48:06 - 23:48:06 - Split 3 - Model: knn
# 23:48:06 - 23:48:06 - Fitting the model
# 23:48:06 - 23:48:06 - Predicting
# 23:48:15 - 23:48:15 - Calculating scores
# 23:48:24 - 23:48:24 - R^2: 0.5829654984857177, RMSE: 2.098580502735276, MAE: 1.4412031555845541, MSE: 4.404040126460645
# 23:48:24 - 23:48:24 - Split 4 - Model: knn
# 23:48:24 - 23:48:24 - Fitting the model
# 23:48:24 - 23:48:24 - Predicting
# 23:48:32 - 23:48:32 - Calculating scores
# 23:48:41 - 23:48:41 - R^2: 0.585291028293391, RMSE: 2.1171283973087287, MAE: 1.4563268877157602, MSE: 4.482232650691026
# 23:48:41 - 23:48:41 - Split 5 - Model: knn
# 23:48:41 - 23:48:41 - Fitting the model
# 23:48:41 - 23:48:41 - Predicting
# 23:48:50 - 23:48:50 - Calculating scores
# 23:48:59 - 23:48:59 - R^2: 0.58483230512719, RMSE: 2.0914752639611955, MAE: 1.4414328845127231, MSE: 4.374268779761552
# 23:48:59 - 23:48:59 - Split 6 - Model: knn
# 23:48:59 - 23:48:59 - Fitting the model
# 23:48:59 - 23:48:59 - Predicting
# 23:49:07 - 23:49:07 - Calculating scores
# 23:49:16 - 23:49:16 - R^2: 0.5831717069942541, RMSE: 2.1026842398504755, MAE: 1.4422464558989263, MSE: 4.421281012515571
# 23:49:16 - 23:49:16 - Split 7 - Model: knn
# 23:49:16 - 23:49:16 - Fitting the model
# 23:49:16 - 23:49:16 - Predicting
# 23:49:25 - 23:49:25 - Calculating scores
# 23:49:34 - 23:49:34 - R^2: 0.5878827744112984, RMSE: 2.0971026913256963, MAE: 1.4424325286197284, MSE: 4.397839697965479
# 23:49:34 - 23:49:34 - Split 8 - Model: knn
# 23:49:34 - 23:49:34 - Fitting the model
# 23:49:34 - 23:49:34 - Predicting
# 23:49:43 - 23:49:43 - Calculating scores
# 23:49:51 - 23:49:51 - R^2: 0.5878923773618292, RMSE: 2.0837607891206624, MAE: 1.4385353816952369, MSE: 4.342059026276766
# 23:49:51 - 23:49:51 - Split 9 - Model: knn
# 23:49:51 - 23:49:51 - Fitting the model
# 23:49:52 - 23:49:52 - Predicting
# 23:50:00 - 23:50:00 - Calculating scores
# 23:50:09 - 23:50:09 - R^2: 0.5800103991555412, RMSE: 2.115766243908136, MAE: 1.4581647191411113, MSE: 4.476466798861142
# 23:50:09 - 23:50:09 - Split 10 - Model: knn
# 23:50:09 - 23:50:09 - Fitting the model
# 23:50:09 - 23:50:09 - Predicting
# 23:50:19 - 23:50:19 - Calculating scores
# 23:50:27 - 23:50:27 - R^2: 0.5849658613144313, RMSE: 2.1079409376777254, MAE: 1.4480522569547425, MSE: 4.443414996737648
# 23:50:27 - 23:50:27 - Training finished
# 23:50:27 - 23:50:27 - Calculate performance for xgb
# 23:50:27 - 23:50:27 - Splitting the additional train data with ShuffleSplit
# 23:50:27 - 23:50:27 - Split 1 - Model: xgb
# 23:50:27 - 23:50:27 - Fitting the model
# 23:50:32 - 23:50:32 - Predicting
# 23:50:32 - 23:50:32 - Calculating scores
# 23:50:32 - 23:50:32 - R^2: 0.6425520086531167, RMSE: 1.9595851049694402, MAE: 1.456686917977356, MSE: 3.8399737836180914
# 23:50:32 - 23:50:32 - Split 2 - Model: xgb
# 23:50:32 - 23:50:32 - Fitting the model
# 23:50:37 - 23:50:37 - Predicting
# 23:50:37 - 23:50:37 - Calculating scores
# 23:50:37 - 23:50:37 - R^2: 0.637755378589864, RMSE: 1.9758616800447983, MAE: 1.4715929169617794, MSE: 3.904029378669453
# 23:50:37 - 23:50:37 - Split 3 - Model: xgb
# 23:50:37 - 23:50:37 - Fitting the model
# 23:50:42 - 23:50:42 - Predicting
# 23:50:42 - 23:50:42 - Calculating scores
# 23:50:42 - 23:50:42 - R^2: 0.6391255913665361, RMSE: 1.9521702195409691, MAE: 1.4554794873144217, MSE: 3.8109685660626353
# 23:50:42 - 23:50:42 - Split 4 - Model: xgb
# 23:50:42 - 23:50:42 - Fitting the model
# 23:50:47 - 23:50:47 - Predicting
# 23:50:47 - 23:50:47 - Calculating scores
# 23:50:47 - 23:50:47 - R^2: 0.6374674454182309, RMSE: 1.9794702893787177, MAE: 1.4746803126088226, MSE: 3.9183026265330643
# 23:50:47 - 23:50:47 - Split 5 - Model: xgb
# 23:50:47 - 23:50:47 - Fitting the model
# 23:50:51 - 23:50:51 - Predicting
# 23:50:51 - 23:50:51 - Calculating scores
# 23:50:51 - 23:50:51 - R^2: 0.6332793903855662, RMSE: 1.9656609729957428, MAE: 1.4643834018415953, MSE: 3.8638230607585706
# 23:50:51 - 23:50:51 - Split 6 - Model: xgb
# 23:50:52 - 23:50:52 - Fitting the model
# 23:50:56 - 23:50:56 - Predicting
# 23:50:56 - 23:50:56 - Calculating scores
# 23:50:56 - 23:50:56 - R^2: 0.6357133350198676, RMSE: 1.9656993839382686, MAE: 1.461572440519785, MSE: 3.8639740680152883
# 23:50:56 - 23:50:56 - Split 7 - Model: xgb
# 23:50:56 - 23:50:56 - Fitting the model
# 23:51:01 - 23:51:01 - Predicting
# 23:51:01 - 23:51:01 - Calculating scores
# 23:51:01 - 23:51:01 - R^2: 0.6416488151921351, RMSE: 1.9555266379119314, MAE: 1.4496953942488788, MSE: 3.8240844315831417
# 23:51:01 - 23:51:01 - Split 8 - Model: xgb
# 23:51:01 - 23:51:01 - Fitting the model
# 23:51:06 - 23:51:06 - Predicting
# 23:51:06 - 23:51:06 - Calculating scores
# 23:51:06 - 23:51:06 - R^2: 0.6364211345637285, RMSE: 1.9572299495736663, MAE: 1.4609606657670806, MSE: 3.8307490755081357
# 23:51:06 - 23:51:06 - Split 9 - Model: xgb
# 23:51:06 - 23:51:06 - Fitting the model
# 23:51:11 - 23:51:11 - Predicting
# 23:51:11 - 23:51:11 - Calculating scores
# 23:51:11 - 23:51:11 - R^2: 0.6358145524146447, RMSE: 1.97019725318326, MAE: 1.4708349505468679, MSE: 3.881677216450863
# 23:51:11 - 23:51:11 - Split 10 - Model: xgb
# 23:51:11 - 23:51:11 - Fitting the model
# 23:51:16 - 23:51:16 - Predicting
# 23:51:16 - 23:51:16 - Calculating scores
# 23:51:16 - 23:51:16 - R^2: 0.6359965495438022, RMSE: 1.9741005880470726, MAE: 1.4733491433583885, MSE: 3.8970731317277973
# 23:51:16 - 23:51:16 - Training finished
# 23:51:16 - 23:51:16 - Calculate performance for final_estimator
# 23:51:16 - 23:51:16 - Splitting the additional train data with ShuffleSplit
# 23:51:16 - 23:51:16 - Split 1 - Model: final_estimator
# 23:51:16 - 23:51:16 - Fitting the model
# 23:51:16 - 23:51:16 - Predicting
# 23:51:16 - 23:51:16 - Calculating scores
# 23:51:16 - 23:51:16 - R^2: 0.550473788739431, RMSE: 2.197532006476215, MAE: 1.6465811248386755, MSE: 4.829146919487378
# 23:51:16 - 23:51:16 - Split 2 - Model: final_estimator
# 23:51:16 - 23:51:16 - Fitting the model
# 23:51:17 - 23:51:17 - Predicting
# 23:51:17 - 23:51:17 - Calculating scores
# 23:51:17 - 23:51:17 - R^2: 0.5482085682464537, RMSE: 2.20660481139947, MAE: 1.6617115145586885, MSE: 4.86910479369129
# 23:51:17 - 23:51:17 - Split 3 - Model: final_estimator
# 23:51:17 - 23:51:17 - Fitting the model
# 23:51:17 - 23:51:17 - Predicting
# 23:51:17 - 23:51:17 - Calculating scores
# 23:51:17 - 23:51:17 - R^2: 0.550620721907582, RMSE: 2.1784428039491734, MAE: 1.6382008202753364, MSE: 4.745613050077937
# 23:51:17 - 23:51:17 - Split 4 - Model: final_estimator
# 23:51:17 - 23:51:17 - Fitting the model
# 23:51:17 - 23:51:17 - Predicting
# 23:51:17 - 23:51:17 - Calculating scores
# 23:51:17 - 23:51:17 - R^2: 0.5496595325955267, RMSE: 2.206205531397898, MAE: 1.6608642027911178, MSE: 4.867342846770682
# 23:51:17 - 23:51:17 - Split 5 - Model: final_estimator
# 23:51:17 - 23:51:17 - Fitting the model
# 23:51:17 - 23:51:17 - Predicting
# 23:51:17 - 23:51:17 - Calculating scores
# 23:51:17 - 23:51:17 - R^2: 0.5406535457617223, RMSE: 2.199941540197377, MAE: 1.654461379704588, MSE: 4.839742780286007
# 23:51:17 - 23:51:17 - Split 6 - Model: final_estimator
# 23:51:17 - 23:51:17 - Fitting the model
# 23:51:17 - 23:51:17 - Predicting
# 23:51:17 - 23:51:17 - Calculating scores
# 23:51:17 - 23:51:17 - R^2: 0.542715191626846, RMSE: 2.2023627428251515, MAE: 1.6580385992416826, MSE: 4.850401650984324
# 23:51:17 - 23:51:17 - Split 7 - Model: final_estimator
# 23:51:18 - 23:51:18 - Fitting the model
# 23:51:18 - 23:51:18 - Predicting
# 23:51:18 - 23:51:18 - Calculating scores
# 23:51:18 - 23:51:18 - R^2: 0.548025946828326, RMSE: 2.196170561176431, MAE: 1.6454716186009783, MSE: 4.823165133778001
# 23:51:18 - 23:51:18 - Split 8 - Model: final_estimator
# 23:51:18 - 23:51:18 - Fitting the model
# 23:51:18 - 23:51:18 - Predicting
# 23:51:18 - 23:51:18 - Calculating scores
# 23:51:18 - 23:51:18 - R^2: 0.5448189984123213, RMSE: 2.1899520266791432, MAE: 1.6502532046872724, MSE: 4.795889879156087
# 23:51:18 - 23:51:18 - Split 9 - Model: final_estimator
# 23:51:18 - 23:51:18 - Fitting the model
# 23:51:18 - 23:51:18 - Predicting
# 23:51:18 - 23:51:18 - Calculating scores
# 23:51:18 - 23:51:18 - R^2: 0.5396063516295904, RMSE: 2.2152006848672214, MAE: 1.6606796136157036, MSE: 4.9071140742362065
# 23:51:18 - 23:51:18 - Split 10 - Model: final_estimator
# 23:51:18 - 23:51:18 - Fitting the model
# 23:51:18 - 23:51:18 - Predicting
# 23:51:18 - 23:51:18 - Calculating scores
# 23:51:18 - 23:51:18 - R^2: 0.5470600950349607, RMSE: 2.2020989000244042, MAE: 1.6586747590083335, MSE: 4.84923956548869
# 23:51:18 - 23:51:18 - Training finished
# 23:51:18 - 23:51:18 - Calculate performance for stacking_regressor
# 23:51:18 - 23:51:18 - Splitting the additional train data with ShuffleSplit
# 23:51:18 - 23:51:18 - Split 1 - Model: stacking_regressor
# 23:51:18 - 23:51:18 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.2s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.6s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   44.9s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   45.7s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.3min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.3min finished
# 23:55:10 - 23:55:10 - Predicting
# 23:55:19 - 23:55:19 - Calculating scores
# 23:55:28 - 23:55:28 - R^2: 0.6878664509295023, RMSE: 1.8311668788342954, MAE: 1.3479897332545832, MSE: 3.353172138139735
# 23:55:28 - 23:55:28 - Split 2 - Model: stacking_regressor
# 23:55:28 - 23:55:28 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.8s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   40.2s remaining:  1.0min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   40.6s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.4min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.4min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.3min remaining:  3.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.3min finished
# 23:59:14 - 23:59:14 - Predicting
# 23:59:23 - 23:59:23 - Calculating scores
# 23:59:33 - 23:59:33 - R^2: 0.6841724985028599, RMSE: 1.8449327405068308, MAE: 1.3631689538528335, MSE: 3.4037768169940446
# 23:59:33 - 23:59:33 - Split 3 - Model: stacking_regressor
# 23:59:33 - 23:59:33 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.7s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   41.7s remaining:  1.0min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   42.3s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.4min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.3min remaining:  3.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.3min finished
# 00:03:23 - 00:03:23 - Predicting
# 00:03:32 - 00:03:32 - Calculating scores
# 00:03:41 - 00:03:41 - R^2: 0.6845463726874879, RMSE: 1.8251871541277302, MAE: 1.346548459577044, MSE: 3.3313081475928827
# 00:03:41 - 00:03:41 - Split 4 - Model: stacking_regressor
# 00:03:42 - 00:03:42 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.1s remaining:    7.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.2s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   43.2s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   43.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.4min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.3min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.3min finished
# 00:07:32 - 00:07:32 - Predicting
# 00:07:42 - 00:07:42 - Calculating scores
# 00:07:51 - 00:07:51 - R^2: 0.6850505105957574, RMSE: 1.8449981554382069, MAE: 1.3621533633476977, MSE: 3.4040181935703857
# 00:07:51 - 00:07:51 - Split 5 - Model: stacking_regressor
# 00:07:51 - 00:07:51 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.8s remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.9s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   43.4s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   44.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.4min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.4min finished
# 00:11:41 - 00:11:41 - Predicting
# 00:11:50 - 00:11:50 - Calculating scores
# 00:12:00 - 00:12:00 - R^2: 0.6792016964094838, RMSE: 1.8384718633932284, MAE: 1.3563960149664254, MSE: 3.37997879248857
# 00:12:00 - 00:12:00 - Split 6 - Model: stacking_regressor
# 00:12:00 - 00:12:00 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.9s remaining:    8.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.3s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   46.3s remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   47.0s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.6min remaining:  2.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.6min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.4min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.4min finished
# 00:15:53 - 00:15:53 - Predicting
# 00:16:02 - 00:16:02 - Calculating scores
# 00:16:11 - 00:16:11 - R^2: 0.6806465322704565, RMSE: 1.8404807643860537, MAE: 1.3557523078737257, MSE: 3.3873694440750723
# 00:16:11 - 00:16:11 - Split 7 - Model: stacking_regressor
# 00:16:12 - 00:16:12 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.1s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   47.7s remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   48.7s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.4min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.4min finished
# 00:20:07 - 00:20:07 - Predicting
# 00:20:16 - 00:20:16 - Calculating scores
# 00:20:26 - 00:20:26 - R^2: 0.6868127719191365, RMSE: 1.8281479314357343, MAE: 1.3438623264277623, MSE: 3.3421248592127544
# 00:20:26 - 00:20:26 - Split 8 - Model: stacking_regressor
# 00:20:26 - 00:20:26 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.4s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.9s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   50.4s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   51.2s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.5min remaining:  3.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.6min finished
# 00:24:28 - 00:24:28 - Predicting
# 00:24:37 - 00:24:37 - Calculating scores
# 00:24:47 - 00:24:47 - R^2: 0.6839179341496704, RMSE: 1.8249142619170244, MAE: 1.3495663883822122, MSE: 3.3303120633481584
# 00:24:47 - 00:24:47 - Split 9 - Model: stacking_regressor
# 00:24:47 - 00:24:47 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.5s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.6s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   48.0s remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   48.6s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.5min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.5min finished
# 00:28:44 - 00:28:44 - Predicting
# 00:28:53 - 00:28:53 - Calculating scores
# 00:29:03 - 00:29:03 - R^2: 0.6800261746031466, RMSE: 1.8467395152775223, MAE: 1.3661424713131396, MSE: 3.410446837287458
# 00:29:03 - 00:29:03 - Split 10 - Model: stacking_regressor
# 00:29:03 - 00:29:03 - Fitting the model
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    4.8s remaining:    7.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.0s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   43.0s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   43.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.5min remaining:  2.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.3min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.3min finished
# 00:32:51 - 00:32:51 - Predicting
# 00:33:00 - 00:33:00 - Calculating scores
# 00:33:09 - 00:33:09 - R^2: 0.6842664420496043, RMSE: 1.8385561567653739, MAE: 1.356519624080492, MSE: 3.3802887415798617
# 00:33:09 - 00:33:09 - Training finished

# %% [markdown]
# ## Predict test data

# %%
import numpy as np
from pipelines_selected_features import pipeline

all_train_data = pipeline.fit_transform(pd.concat([train_data, additional_train_data], axis=0))

X_train = all_train_data_transformed.drop(columns=['bg+1:00'])
y_train = all_train_data_transformed['bg+1:00']

model.fit(X_train, y_train)

X_test = pipeline.transform(test_data)

y_pred = model.predict(X_test)

if np.sum(y_pred < 0) > 0:
    print(f'Number of negative values: {np.sum(y_pred < 0)}')
    bg_min_train = np.min(y_train)
    print(f'Min value: {np.min(y_pred)}')
    y_pred = y_pred.apply(lambda x: bg_min_train if x < 0 else x)

test_data['bg+1:00'] = y_pred
test_data.head()
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   45.4s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   45.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.8min remaining:  2.7min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.8min finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.7min remaining:  4.0min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.7min finished
#          p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# id
# p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#           bg-5:30  bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  \
# id                                   ...
# p01_8459      NaN      NaN     10.3  ...            NaN            NaN
# p01_8460      9.4      NaN      NaN  ...            NaN            NaN
# p01_8461      NaN      NaN      5.2  ...            NaN            NaN
# p01_8462      NaN      NaN      4.7  ...            NaN            NaN
# p01_8463     10.0      NaN      NaN  ...            NaN            NaN
#
#           activity-0:30  activity-0:25  activity-0:20  activity-0:15  \
# id
# p01_8459            NaN            NaN            NaN            NaN
# p01_8460            NaN            NaN            NaN            NaN
# p01_8461            NaN            NaN            NaN            NaN
# p01_8462            NaN            NaN            NaN            NaN
# p01_8463            NaN            NaN            NaN            NaN
#
#           activity-0:10  activity-0:05  activity-0:00    bg+1:00
# id
# p01_8459            NaN            NaN            NaN   9.071119
# p01_8460           Walk           Walk           Walk   5.657524
# p01_8461            NaN            NaN            NaN   8.121666
# p01_8462            NaN            NaN            NaN  11.068323
# p01_8463            NaN            NaN            NaN   6.636524
#
# [5 rows x 507 columns]

# %%
submission = pd.DataFrame(test_data['bg+1:00'])
submission
# Out:
#             bg+1:00
# id
# p01_8459   9.071119
# p01_8460   5.657524
# p01_8461   8.121666
# p01_8462  11.068323
# p01_8463   6.636524
# ...             ...
# p24_256    6.109136
# p24_257   10.136925
# p24_258    6.427288
# p24_259    8.216440
# p24_260    6.059377
#
# [3644 rows x 1 columns]

# %%
submission.to_csv(f'submission-{model_name}.csv')
