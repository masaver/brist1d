# %% [markdown]
# # Hyperparameter Tuning

# %%
import numpy as np

from data import load_data

train_data, test_data = load_data()

unique_patients = test_data['p_num'].unique()
train_data = train_data[train_data['p_num'].isin(unique_patients)]
test_data = test_data[test_data['p_num'].isin(unique_patients)]

train_data.head()
# Out:
#       p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# id
# p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN      9.7
# p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN      9.2
# p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN      8.7
# p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN      8.4
# p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN      8.1
#
#        bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  activity-0:30  \
# id                       ...
# p01_0      NaN      NaN  ...            NaN            NaN            NaN
# p01_1      NaN      NaN  ...            NaN            NaN            NaN
# p01_2      NaN      NaN  ...            NaN            NaN            NaN
# p01_3      NaN      NaN  ...            NaN            NaN            NaN
# p01_4      NaN      NaN  ...            NaN            NaN            NaN
#
#        activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# id
# p01_0            NaN            NaN            NaN            NaN
# p01_1            NaN            NaN            NaN            NaN
# p01_2            NaN            NaN            NaN            NaN
# p01_3            NaN            NaN            NaN            NaN
# p01_4            NaN            NaN            NaN            NaN
#
#        activity-0:05  activity-0:00  bg+1:00
# id
# p01_0            NaN            NaN     13.4
# p01_1            NaN            NaN     12.8
# p01_2            NaN            NaN     15.5
# p01_3            NaN            NaN     14.8
# p01_4            NaN            NaN     12.7
#
# [5 rows x 507 columns]

# %% [markdown]
# ### Define a tuning function

# %%
import joblib
import os


def tune(p_num, tuner, X, y):
    model_file_name = f'{p_num}.{tuner.__name__}.model.pkl'
    if os.path.exists(model_file_name):
        print(f'Model {model_file_name} already exists. Skipping...')
        return

    print(f'-----------{tuner.__name__}-----------')
    print('Calculating best hyperparameters...')
    tuner.fit(X, y)
    print('Best hyperparameters found.')
    display(tuner.get_params())
    print(f'RMSE: {tuner.get_rmse()}')
    tuner.show_chart()
    joblib.dump(tuner.get_best_model(), model_file_name)

# %%
from pipelines import pipeline
from src.features.tuners import LassoLarsICHyperparameterTuner

for patient in unique_patients:
    patient_train_data = train_data[train_data['p_num'] == patient]
    patient_train_data_transformed = pipeline.fit_transform(patient_train_data)

    X_train = patient_train_data_transformed.drop(columns=['bg+1:00'])
    y_train = patient_train_data_transformed['bg+1:00']
    y_train_log = np.log1p(y_train)

    tune(patient, LassoLarsICHyperparameterTuner(search_space='wide'), X_train, y_train_log)
# Out:
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.08833269458531243),
#              ('max_iter', 3731),
#              ('noise_variance', 0.009512287842026701),
#              ('positive', True)])
# RMSE: 0.28585336367178305
# RMSE: 0.28585336367178305
# R2 Score: 0.49184020139185436
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.09200172255146727),
#              ('max_iter', 5468),
#              ('noise_variance', 0.008376726714168206),
#              ('positive', False)])
# RMSE: 0.2105256123970837
# RMSE: 0.2105256123970837
# R2 Score: 0.460822642742473
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.1),
#              ('max_iter', 1000),
#              ('noise_variance', 0.01),
#              ('positive', False)])
# RMSE: 0.22103773955207429
# RMSE: 0.22103773955207429
# R2 Score: 0.2613538306374249
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 1.0000000000000023e-05),
#              ('max_iter', 1000),
#              ('noise_variance', 0.01),
#              ('positive', False)])
# RMSE: 0.2195233019666162
# RMSE: 0.2195233019666162
# R2 Score: 0.5830515832930709
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.09200172255146727),
#              ('max_iter', 5468),
#              ('noise_variance', 0.008376726714168206),
#              ('positive', False)])
# RMSE: 0.22172797268470434
# RMSE: 0.22172797268470434
# R2 Score: 0.6376642105516082
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.09960680525659879),
#              ('max_iter', 8669),
#              ('noise_variance', 0.009968637282249978),
#              ('positive', False)])
# RMSE: 0.18182842770846264
# RMSE: 0.18182842770846264
# R2 Score: 0.27185274465982456
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.1),
#              ('max_iter', 10000),
#              ('noise_variance', 0.01),
#              ('positive', False)])
# RMSE: 0.20366958486342532
# RMSE: 0.20366958486342532
# R2 Score: 0.4774100665540426
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.010463004551981469),
#              ('max_iter', 9760),
#              ('noise_variance', 0.007361053611931837),
#              ('positive', False)])
# RMSE: 0.17813600164984209
# RMSE: 0.17813600164984209
# R2 Score: 0.641657604679138
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.09788326379275333),
#              ('max_iter', 9635),
#              ('noise_variance', 0.009435413559407049),
#              ('positive', False)])
# RMSE: 0.23039798666318137
# RMSE: 0.23039798666318137
# R2 Score: 0.41596644756567913
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.004997207228854742),
#              ('max_iter', 9717),
#              ('noise_variance', 0.0064961272538160576),
#              ('positive', False)])
# RMSE: 0.15514624432838017
# RMSE: 0.15514624432838017
# R2 Score: 0.4255471819758132
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 1.0000000000000013e-05),
#              ('max_iter', 1000),
#              ('noise_variance', 0.01),
#              ('positive', False)])
# RMSE: 0.24572241073180065
# RMSE: 0.24572241073180065
# R2 Score: 0.5309871994019312
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.09200172255146727),
#              ('max_iter', 5468),
#              ('noise_variance', 0.008376726714168206),
#              ('positive', False)])
# RMSE: 0.1858448713050566
# RMSE: 0.1858448713050566
# R2 Score: 0.5454418391668583
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 1.0000000000000253e-05),
#              ('max_iter', 1000),
#              ('noise_variance', 0.01),
#              ('positive', False)])
# RMSE: 0.2202386305373423
# RMSE: 0.2202386305373423
# R2 Score: 0.6257010689684628
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 0.1),
#              ('max_iter', 10000),
#              ('noise_variance', 0.008571879014584494),
#              ('positive', False)])
# RMSE: 0.23494870987467514
# RMSE: 0.23494870987467514
# R2 Score: 0.41054019292136423
# -----------LassoLarsIC-----------
# Calculating best hyperparameters...
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/ralf/Projects/learning-projects/datascience-bootcamp/sep24_bds_int_medical/.venv/lib/python3.12/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Best hyperparameters found.
# OrderedDict([('criterion', 'bic'),
#              ('eps', 1e-05),
#              ('max_iter', 1000),
#              ('noise_variance', 0.01),
#              ('positive', False)])
# RMSE: 0.2065769557634254
# RMSE: 0.2065769557634254
# R2 Score: 0.3745285239983006
