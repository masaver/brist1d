# %% [markdown]
# # Predict for each patient

# %%
from data import load_data

train_data, test_data = load_data()

unique_patients = test_data['p_num'].unique()
train_data = train_data[train_data['p_num'].isin(unique_patients)]
test_data = test_data[test_data['p_num'].isin(unique_patients)]

train_data.head()
# Out:
#       p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# id
# p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN      9.7
# p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN      9.2
# p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN      8.7
# p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN      8.4
# p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN      8.1
#
#        bg-5:25  bg-5:20  ...  activity-0:40  activity-0:35  activity-0:30  \
# id                       ...
# p01_0      NaN      NaN  ...            NaN            NaN            NaN
# p01_1      NaN      NaN  ...            NaN            NaN            NaN
# p01_2      NaN      NaN  ...            NaN            NaN            NaN
# p01_3      NaN      NaN  ...            NaN            NaN            NaN
# p01_4      NaN      NaN  ...            NaN            NaN            NaN
#
#        activity-0:25  activity-0:20  activity-0:15  activity-0:10  \
# id
# p01_0            NaN            NaN            NaN            NaN
# p01_1            NaN            NaN            NaN            NaN
# p01_2            NaN            NaN            NaN            NaN
# p01_3            NaN            NaN            NaN            NaN
# p01_4            NaN            NaN            NaN            NaN
#
#        activity-0:05  activity-0:00  bg+1:00
# id
# p01_0            NaN            NaN     13.4
# p01_1            NaN            NaN     12.8
# p01_2            NaN            NaN     15.5
# p01_3            NaN            NaN     14.8
# p01_4            NaN            NaN     12.7
#
# [5 rows x 507 columns]

# %%
from sklearn.ensemble import VotingRegressor
from pipelines import pipeline
import joblib
import os
import datetime
import numpy as np


def get_date_time_now():
    return datetime.datetime.now().strftime('%H:%M:%S')


models = {}
results = test_data[[]].copy()
results.loc[:, 'bg+1:00'] = -1.0
results['bg+1:00'] = results['bg+1:00'].astype(float)
for p_num in unique_patients:
    print(f'{get_date_time_now()} - {p_num} - Predicting for patient {p_num}')
    stored_models = [file for file in os.listdir() if file.endswith('.model.pkl') and file.startswith(f'{p_num}')]
    estimators = []
    print(f'{get_date_time_now()} - {p_num} - Found {len(stored_models)} models')
    for model_file in stored_models:
        print(f'{get_date_time_now()} - {p_num} - Loading {model_file}')
        model = joblib.load(model_file)
        estimators.append((
            model_file.replace('.model.pkl', ''),
            model
        ))

    print(f'{get_date_time_now()} - {p_num} - Transforming the data -')
    train_data_patient = train_data[train_data['p_num'] == p_num]
    train_data_patient = pipeline.fit_transform(train_data_patient)

    X_train = train_data_patient.drop(columns=['bg+1:00'])
    y_train = train_data_patient['bg+1:00']
    y_train_log = np.log1p(y_train)

    print(f'{get_date_time_now()} - {p_num} - Fitting the model -')
    model = VotingRegressor(estimators=estimators, verbose=True)
    model.fit(X=X_train, y=y_train_log)

    print(f'{get_date_time_now()} - {p_num} - Predicting -')
    test_data_patient = test_data[test_data['p_num'] == p_num]
    
    X_test = pipeline.transform(test_data_patient)
    y_pred_log = model.predict(X=X_test)
    y_pred = np.expm1(y_pred_log)
    
    results.loc[test_data_patient.index, 'bg+1:00'] = y_pred
    print(f'{get_date_time_now()} - {p_num} - Done -')

results.head()
# Out:
# 07:27:56 - p01 - Predicting for patient p01
# 07:27:56 - p01 - Found 3 models
# 07:27:56 - p01 - Loading p01.LassoLarsIC.model.pkl
# 07:27:56 - p01 - Loading p01.XGBRegressor.model.pkl
# 07:27:56 - p01 - Loading p01.HistGradientBoostingRegressor.model.pkl
# 07:27:56 - p01 - Transforming the data -
# 07:27:59 - p01 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p01.LassoLarsIC, total=   0.0s
# [Voting] ......... (2 of 3) Processing p01.XGBRegressor, total= 1.1min
# [Voting]  (3 of 3) Processing p01.HistGradientBoostingRegressor, total=   5.1s
# 07:29:07 - p01 - Predicting -
# 07:29:08 - p01 - Done -
# 07:29:08 - p02 - Predicting for patient p02
# 07:29:08 - p02 - Found 3 models
# 07:29:08 - p02 - Loading p02.XGBRegressor.model.pkl
# 07:29:08 - p02 - Loading p02.LassoLarsIC.model.pkl
# 07:29:08 - p02 - Loading p02.HistGradientBoostingRegressor.model.pkl
# 07:29:08 - p02 - Transforming the data -
# 07:29:11 - p02 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p02.XGBRegressor, total=  15.9s
# [Voting] .......... (2 of 3) Processing p02.LassoLarsIC, total=   0.1s
# [Voting]  (3 of 3) Processing p02.HistGradientBoostingRegressor, total=   5.9s
# 07:29:33 - p02 - Predicting -
# 07:29:33 - p02 - Done -
# 07:29:33 - p04 - Predicting for patient p04
# 07:29:33 - p04 - Found 3 models
# 07:29:33 - p04 - Loading p04.LassoLarsIC.model.pkl
# 07:29:33 - p04 - Loading p04.HistGradientBoostingRegressor.model.pkl
# 07:29:33 - p04 - Loading p04.XGBRegressor.model.pkl
# 07:29:33 - p04 - Transforming the data -
# 07:29:36 - p04 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p04.LassoLarsIC, total=   0.1s
# [Voting]  (2 of 3) Processing p04.HistGradientBoostingRegressor, total=   6.4s
# [Voting] ......... (3 of 3) Processing p04.XGBRegressor, total=  39.5s
# 07:30:22 - p04 - Predicting -
# 07:30:22 - p04 - Done -
# 07:30:22 - p05 - Predicting for patient p05
# 07:30:22 - p05 - Found 3 models
# 07:30:22 - p05 - Loading p05.LassoLarsIC.model.pkl
# 07:30:22 - p05 - Loading p05.XGBRegressor.model.pkl
# 07:30:22 - p05 - Loading p05.HistGradientBoostingRegressor.model.pkl
# 07:30:22 - p05 - Transforming the data -
# 07:30:24 - p05 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p05.LassoLarsIC, total=   0.0s
# [Voting] ......... (2 of 3) Processing p05.XGBRegressor, total=  28.3s
# [Voting]  (3 of 3) Processing p05.HistGradientBoostingRegressor, total=   3.2s
# 07:30:56 - p05 - Predicting -
# 07:30:56 - p05 - Done -
# 07:30:56 - p06 - Predicting for patient p06
# 07:30:56 - p06 - Found 3 models
# 07:30:56 - p06 - Loading p06.HistGradientBoostingRegressor.model.pkl
# 07:30:56 - p06 - Loading p06.LassoLarsIC.model.pkl
# 07:30:56 - p06 - Loading p06.XGBRegressor.model.pkl
# 07:30:56 - p06 - Transforming the data -
# 07:30:58 - p06 - Fitting the model -
# [Voting]  (1 of 3) Processing p06.HistGradientBoostingRegressor, total=   5.2s
# [Voting] .......... (2 of 3) Processing p06.LassoLarsIC, total=   0.0s
# [Voting] ......... (3 of 3) Processing p06.XGBRegressor, total=  14.8s
# 07:31:18 - p06 - Predicting -
# 07:31:18 - p06 - Done -
# 07:31:18 - p10 - Predicting for patient p10
# 07:31:18 - p10 - Found 3 models
# 07:31:18 - p10 - Loading p10.HistGradientBoostingRegressor.model.pkl
# 07:31:18 - p10 - Loading p10.XGBRegressor.model.pkl
# 07:31:18 - p10 - Loading p10.LassoLarsIC.model.pkl
# 07:31:18 - p10 - Transforming the data -
# 07:31:21 - p10 - Fitting the model -
# [Voting]  (1 of 3) Processing p10.HistGradientBoostingRegressor, total=   6.7s
# [Voting] ......... (2 of 3) Processing p10.XGBRegressor, total=   5.7s
# [Voting] .......... (3 of 3) Processing p10.LassoLarsIC, total=   0.1s
# 07:31:33 - p10 - Predicting -
# 07:31:33 - p10 - Done -
# 07:31:33 - p11 - Predicting for patient p11
# 07:31:33 - p11 - Found 3 models
# 07:31:33 - p11 - Loading p11.XGBRegressor.model.pkl
# 07:31:33 - p11 - Loading p11.LassoLarsIC.model.pkl
# 07:31:33 - p11 - Loading p11.HistGradientBoostingRegressor.model.pkl
# 07:31:33 - p11 - Transforming the data -
# 07:31:36 - p11 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p11.XGBRegressor, total=  13.8s
# [Voting] .......... (2 of 3) Processing p11.LassoLarsIC, total=   0.1s
# [Voting]  (3 of 3) Processing p11.HistGradientBoostingRegressor, total=   7.9s
# 07:31:58 - p11 - Predicting -
# 07:31:58 - p11 - Done -
# 07:31:58 - p12 - Predicting for patient p12
# 07:31:58 - p12 - Found 3 models
# 07:31:58 - p12 - Loading p12.XGBRegressor.model.pkl
# 07:31:58 - p12 - Loading p12.HistGradientBoostingRegressor.model.pkl
# 07:31:58 - p12 - Loading p12.LassoLarsIC.model.pkl
# 07:31:58 - p12 - Transforming the data -
# 07:32:01 - p12 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p12.XGBRegressor, total= 1.8min
# [Voting]  (2 of 3) Processing p12.HistGradientBoostingRegressor, total=   9.2s
# [Voting] .......... (3 of 3) Processing p12.LassoLarsIC, total=   0.1s
# 07:33:58 - p12 - Predicting -
# 07:33:58 - p12 - Done -
# 07:33:58 - p15 - Predicting for patient p15
# 07:33:58 - p15 - Found 3 models
# 07:33:58 - p15 - Loading p15.HistGradientBoostingRegressor.model.pkl
# 07:33:58 - p15 - Loading p15.XGBRegressor.model.pkl
# 07:33:58 - p15 - Loading p15.LassoLarsIC.model.pkl
# 07:33:58 - p15 - Transforming the data -
# 07:33:59 - p15 - Fitting the model -
# [Voting]  (1 of 3) Processing p15.HistGradientBoostingRegressor, total=   8.6s
# [Voting] ......... (2 of 3) Processing p15.XGBRegressor, total=  10.3s
# [Voting] .......... (3 of 3) Processing p15.LassoLarsIC, total=   0.0s
# 07:34:18 - p15 - Predicting -
# 07:34:19 - p15 - Done -
# 07:34:19 - p16 - Predicting for patient p16
# 07:34:19 - p16 - Found 3 models
# 07:34:19 - p16 - Loading p16.XGBRegressor.model.pkl
# 07:34:19 - p16 - Loading p16.HistGradientBoostingRegressor.model.pkl
# 07:34:19 - p16 - Loading p16.LassoLarsIC.model.pkl
# 07:34:19 - p16 - Transforming the data -
# 07:34:20 - p16 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p16.XGBRegressor, total=  15.2s
# [Voting]  (2 of 3) Processing p16.HistGradientBoostingRegressor, total=   3.7s
# [Voting] .......... (3 of 3) Processing p16.LassoLarsIC, total=   0.0s
# 07:34:39 - p16 - Predicting -
# 07:34:39 - p16 - Done -
# 07:34:39 - p18 - Predicting for patient p18
# 07:34:39 - p18 - Found 3 models
# 07:34:39 - p18 - Loading p18.HistGradientBoostingRegressor.model.pkl
# 07:34:39 - p18 - Loading p18.XGBRegressor.model.pkl
# 07:34:39 - p18 - Loading p18.LassoLarsIC.model.pkl
# 07:34:39 - p18 - Transforming the data -
# 07:34:40 - p18 - Fitting the model -
# [Voting]  (1 of 3) Processing p18.HistGradientBoostingRegressor, total=   4.3s
# [Voting] ......... (2 of 3) Processing p18.XGBRegressor, total=   9.8s
# [Voting] .......... (3 of 3) Processing p18.LassoLarsIC, total=   0.0s
# 07:34:54 - p18 - Predicting -
# 07:34:55 - p18 - Done -
# 07:34:55 - p19 - Predicting for patient p19
# 07:34:55 - p19 - Found 3 models
# 07:34:55 - p19 - Loading p19.LassoLarsIC.model.pkl
# 07:34:55 - p19 - Loading p19.HistGradientBoostingRegressor.model.pkl
# 07:34:55 - p19 - Loading p19.XGBRegressor.model.pkl
# 07:34:55 - p19 - Transforming the data -
# 07:34:56 - p19 - Fitting the model -
# [Voting] .......... (1 of 3) Processing p19.LassoLarsIC, total=   0.0s
# [Voting]  (2 of 3) Processing p19.HistGradientBoostingRegressor, total=   4.0s
# [Voting] ......... (3 of 3) Processing p19.XGBRegressor, total=   8.9s
# 07:35:09 - p19 - Predicting -
# 07:35:09 - p19 - Done -
# 07:35:09 - p21 - Predicting for patient p21
# 07:35:09 - p21 - Found 3 models
# 07:35:09 - p21 - Loading p21.HistGradientBoostingRegressor.model.pkl
# 07:35:09 - p21 - Loading p21.LassoLarsIC.model.pkl
# 07:35:09 - p21 - Loading p21.XGBRegressor.model.pkl
# 07:35:09 - p21 - Transforming the data -
# 07:35:10 - p21 - Fitting the model -
# [Voting]  (1 of 3) Processing p21.HistGradientBoostingRegressor, total=   4.4s
# [Voting] .......... (2 of 3) Processing p21.LassoLarsIC, total=   0.0s
# [Voting] ......... (3 of 3) Processing p21.XGBRegressor, total=   9.7s
# 07:35:24 - p21 - Predicting -
# 07:35:25 - p21 - Done -
# 07:35:25 - p22 - Predicting for patient p22
# 07:35:25 - p22 - Found 3 models
# 07:35:25 - p22 - Loading p22.HistGradientBoostingRegressor.model.pkl
# 07:35:25 - p22 - Loading p22.XGBRegressor.model.pkl
# 07:35:25 - p22 - Loading p22.LassoLarsIC.model.pkl
# 07:35:25 - p22 - Transforming the data -
# 07:35:26 - p22 - Fitting the model -
# [Voting]  (1 of 3) Processing p22.HistGradientBoostingRegressor, total=   4.6s
# [Voting] ......... (2 of 3) Processing p22.XGBRegressor, total=  13.0s
# [Voting] .......... (3 of 3) Processing p22.LassoLarsIC, total=   0.0s
# 07:35:43 - p22 - Predicting -
# 07:35:43 - p22 - Done -
# 07:35:43 - p24 - Predicting for patient p24
# 07:35:43 - p24 - Found 3 models
# 07:35:43 - p24 - Loading p24.XGBRegressor.model.pkl
# 07:35:43 - p24 - Loading p24.HistGradientBoostingRegressor.model.pkl
# 07:35:43 - p24 - Loading p24.LassoLarsIC.model.pkl
# 07:35:43 - p24 - Transforming the data -
# 07:35:45 - p24 - Fitting the model -
# [Voting] ......... (1 of 3) Processing p24.XGBRegressor, total=   7.7s
# [Voting]  (2 of 3) Processing p24.HistGradientBoostingRegressor, total=   4.5s
# [Voting] .......... (3 of 3) Processing p24.LassoLarsIC, total=   0.0s
# 07:35:57 - p24 - Predicting -
# 07:35:57 - p24 - Done -
#             bg+1:00
# id
# p01_8459   8.546884
# p01_8460   6.106847
# p01_8461   8.532473
# p01_8462  10.201737
# p01_8463   6.583655

# %%
# check if all results are greater than 0
assert (results['bg+1:00'] >= 0).all()

# %% [markdown]
# ## Prepare the submission file

# %%
submission = results
submission
# Out:
#             bg+1:00
# id
# p01_8459   8.546884
# p01_8460   6.106847
# p01_8461   8.532473
# p01_8462  10.201737
# p01_8463   6.583655
# ...             ...
# p24_256    6.510667
# p24_257    9.731105
# p24_258    5.976961
# p24_259    7.957295
# p24_260    6.472413
#
# [3644 rows x 1 columns]

# %% [markdown]
# ### Save the submission file

# %%
submission.to_csv(f'submission-{os.path.basename(os.getcwd())}.csv')
