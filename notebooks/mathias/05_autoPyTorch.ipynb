# %%
from autoPyTorch.api.tabular_classification import TabularClassificationTask

# data and metric imports
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
X, y = sklearn.datasets.load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(X, y, random_state=1)

# initialise Auto-PyTorch api
api = TabularClassificationTask()

# Search for an ensemble of machine learning algorithms
api.search(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    optimize_metric='accuracy',
    total_walltime_limit=300,
    func_eval_time_limit_secs=50
)

# Calculate test accuracy
y_pred = api.predict(X_test)
score = api.score(y_pred, y_test)
print("Accuracy score", score)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from autoPyTorch.api.tabular_classification import TabularClassificationTask
#       3 # data and metric imports
#       4 import sklearn.model_selection
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/api/tabular_classification.py:7
#       3 import numpy as np
#       5 import pandas as pd
# ----> 7 from autoPyTorch.api.base_task import BaseTask
#       8 from autoPyTorch.automl_common.common.utils.backend import Backend
#       9 from autoPyTorch.constants import (
#      10     TABULAR_CLASSIFICATION,
#      11     TASK_TYPES_TO_STRING,
#      12 )
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/api/base_task.py:55
#      53 from autoPyTorch.ensemble.ensemble_builder import EnsembleBuilderManager
#      54 from autoPyTorch.ensemble.singlebest_ensemble import SingleBest
# ---> 55 from autoPyTorch.evaluation.tae import ExecuteTaFuncWithQueue, get_cost_of_crash
#      56 from autoPyTorch.evaluation.utils import DisableFileOutputParameters
#      57 from autoPyTorch.optimizer.smbo import AutoMLSMBO
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/evaluation/tae.py:37
#      26 from autoPyTorch.constants import (
#      27     FORECASTING_BUDGET_TYPE,
#      28     ForecastingDependenciesNotInstalledMSG,
#      29     STRING_TO_TASK_TYPES,
#      30     TIMESERIES_FORECASTING,
#      31 )
#      32 from autoPyTorch.datasets.resampling_strategy import (
#      33     CrossValTypes,
#      34     HoldoutValTypes,
#      35     NoResamplingStrategyTypes
#      36 )
# ---> 37 from autoPyTorch.evaluation.test_evaluator import eval_test_function
#      38 try:
#      39     from autoPyTorch.evaluation.time_series_forecasting_train_evaluator import forecasting_eval_train_function
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/evaluation/test_evaluator.py:12
#      10 from autoPyTorch.automl_common.common.utils.backend import Backend
#      11 from autoPyTorch.datasets.resampling_strategy import NoResamplingStrategyTypes
# ---> 12 from autoPyTorch.evaluation.abstract_evaluator import (
#      13     AbstractEvaluator,
#      14     fit_and_suppress_warnings
#      15 )
#      16 from autoPyTorch.evaluation.utils import DisableFileOutputParameters
#      17 from autoPyTorch.pipeline.components.training.metrics.base import autoPyTorchMetric
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/evaluation/abstract_evaluator.py:27
#      25 except ModuleNotFoundError:
#      26     forecasting_dependencies_installed = False
# ---> 27 import autoPyTorch.pipeline.traditional_tabular_classification
#      28 import autoPyTorch.pipeline.traditional_tabular_regression
#      29 from autoPyTorch.automl_common.common.utils.backend import Backend
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/pipeline/traditional_tabular_classification.py:14
#      12 from autoPyTorch.pipeline.components.base_choice import autoPyTorchChoice
#      13 from autoPyTorch.pipeline.components.base_component import autoPyTorchComponent
# ---> 14 from autoPyTorch.pipeline.components.setup.traditional_ml import ModelChoice
#      15 from autoPyTorch.utils.hyperparameter_search_space_update import HyperparameterSearchSpaceUpdates
#      18 class TraditionalTabularClassificationPipeline(ClassifierMixin, BasePipeline):
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/pipeline/components/setup/traditional_ml/__init__.py:21
#      17 from autoPyTorch.pipeline.components.setup.traditional_ml.base_model import BaseModelComponent
#      20 directory = os.path.split(__file__)[0]
# ---> 21 _models = find_components(__package__,
#      22                           directory,
#      23                           BaseModelComponent)
#      24 _addons = ThirdPartyComponents(BaseModelComponent)
#      27 def add_model(model: BaseModelComponent) -> None:
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/pipeline/components/base_component.py:43, in find_components(package, directory, base_class)
#      41 full_module_name = "%s.%s" % (package, module_name)
#      42 if full_module_name not in sys.modules and not ispkg:
# ---> 43     module = importlib.import_module(full_module_name)
#      45     for member_name, obj in inspect.getmembers(module):
#      46         if inspect.isclass(obj) and issubclass(obj, base_class) and obj != base_class:
#      47             # TODO test if the obj implements the interface
#      48             # Keep in mind that this only instantiates the ensemble_wrapper,
#      49             # but not the real target classifier
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/pipeline/components/setup/traditional_ml/tabular_traditional_model.py:12
#      10 from autoPyTorch.pipeline.base_pipeline import BaseDatasetPropertiesType
#      11 from autoPyTorch.pipeline.components.setup.traditional_ml.base_model import BaseModelComponent
# ---> 12 from autoPyTorch.pipeline.components.setup.traditional_ml.traditional_learner import (
#      13     BaseTraditionalLearner, get_available_traditional_learners)
#      16 class TabularTraditionalModel(BaseModelComponent):
#      17     """
#      18     Implementation of a dynamic model, that consists of a learner and a head
#      19     """
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/pipeline/components/setup/traditional_ml/traditional_learner/__init__.py:8
#       3 from autoPyTorch.pipeline.components.base_component import (
#       4     ThirdPartyComponents,
#       5 )
#       6 from autoPyTorch.pipeline.components.setup.traditional_ml.traditional_learner.base_traditional_learner import \
#       7     BaseTraditionalLearner
# ----> 8 from autoPyTorch.pipeline.components.setup.traditional_ml.traditional_learner.learners import (
#       9     CatboostModel,
#      10     ExtraTreesModel,
#      11     KNNModel,
#      12     LGBModel,
#      13     RFModel,
#      14     SVMModel)
#      16 _traditional_learners = {
#      17     # Sort by more robust models
#      18     # Depending on the allocated time budget, only the
#    (...)
#      32     'knn': KNNModel,
#      33 }
#      34 _addons = ThirdPartyComponents(BaseTraditionalLearner)
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/autoPyTorch/pipeline/components/setup/traditional_ml/traditional_learner/learners.py:7
#       3 from typing import Dict, Optional, Union
#       5 from catboost import CatBoostClassifier, CatBoostRegressor, Pool
# ----> 7 from lightgbm import LGBMClassifier, LGBMRegressor
#       9 import numpy as np
#      11 from sklearn.ensemble import (
#      12     ExtraTreesClassifier,
#      13     ExtraTreesRegressor,
#      14     RandomForestClassifier,
#      15     RandomForestRegressor
#      16 )
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/lightgbm/__init__.py:9
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       7 from pathlib import Path
# ----> 9 from .basic import Booster, Dataset, Sequence, register_logger
#      10 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      11 from .engine import CVBooster, cv, train
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/lightgbm/basic.py:281
#     279     _LIB = Mock(ctypes.CDLL)  # type: ignore
#     280 else:
# --> 281     _LIB = _load_lib()
#     284 _NUMERIC_TYPES = (int, float, bool)
#     287 def _safe_call(ret: int) -> None:
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/lightgbm/basic.py:265, in _load_lib()
#     263 """Load LightGBM library."""
#     264 lib_path = find_lib_path()
# --> 265 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     266 lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     267 callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/ctypes/__init__.py:451, in LibraryLoader.LoadLibrary(self, name)
#     450 def LoadLibrary(self, name):
# --> 451     return self._dlltype(name)
#
# File /opt/anaconda3/envs/auto-pytorch/lib/python3.8/ctypes/__init__.py:373, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     370 self._FuncPtr = _FuncPtr
#     372 if handle is None:
# --> 373     self._handle = _dlopen(self._name, mode)
#     374 else:
#     375     self._handle = handle
#
# OSError: dlopen(/opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/lightgbm/lib/lib_lightgbm.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib
#   Referenced from: <231012EE-C624-39BF-9168-0899EB683529> /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages/lightgbm/lib/lib_lightgbm.dylib
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (mach-o file, but is an incompatible architecture (have 'arm64', need 'x86_64')), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/local/lib/libomp/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/local/lib/libomp/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (mach-o file, but is an incompatible architecture (have 'arm64', need 'x86_64')), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/local/lib/libomp/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/local/lib/libomp/libomp.dylib' (no such file), '/opt/anaconda3/envs/auto-pytorch/lib/python3.8/lib-dynload/../../libomp.dylib' (no such file), '/opt/anaconda3/envs/auto-pytorch/bin/../lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)

# %%
brew info

# %%
sudo -l /opt/homebrew/Cellar/libomp/19.1.2/lib/libomp.dylib /usr/local/opt/libomp/lib/libomp.dylib 
# !pip uninstall lightgbm -y && pip install lightgbm
#!pip install lightgbm --no-binary lightgbm
# Out:
# Found existing installation: lightgbm 4.5.0
# Uninstalling lightgbm-4.5.0:
#   Successfully uninstalled lightgbm-4.5.0
# Collecting lightgbm
#   Using cached lightgbm-4.5.0-py3-none-macosx_10_15_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages (from lightgbm) (1.24.4)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/auto-pytorch/lib/python3.8/site-packages (from lightgbm) (1.10.1)
# Using cached lightgbm-4.5.0-py3-none-macosx_10_15_x86_64.whl (1.9 MB)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.5.0
