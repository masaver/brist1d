# %%
import pandas as pd

# %% [markdown]
# ### Overview of the data

# %%
patients = pd.read_csv("../data/raw/train.csv")
#patients.head()
patients.info()
# Out:
# C:\Users\svetl\AppData\Local\Temp\ipykernel_2092\3254964731.py:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   patients = pd.read_csv("../data/raw/train.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177024 entries, 0 to 177023
# Columns: 508 entries, id to bg+1:00
# dtypes: float64(433), object(75)
# memory usage: 686.1+ MB

# %%
patients['p_num'].unique()
# Out:
# array(['p01', 'p02', 'p03', 'p04', 'p05', 'p06', 'p10', 'p11', 'p12'],
#       dtype=object)

# %% [markdown]
# ### Percentage of missing values for bg-cols

# %%
bg_cols = [col for col in patients.columns if col.startswith('bg-')]
# Calculate the percentage of missing values for each 'bg-' column
missing_percentage = patients[bg_cols].isnull().mean() * 100

# Display the results
print(min(missing_percentage), max(missing_percentage))
# Out:
# 1.5229573391178597 15.399606832971802

# %% [markdown]
# ### Percentage of missing values for insulin-cols

# %%
insulin_cols = [col for col in patients.columns if col.startswith('insulin-')]
print(patients[insulin_cols].dtypes)
# Calculate the percentage of missing values for each 'insulin-' column
missing_percentage = patients[insulin_cols].isnull().mean() * 100
print(min(missing_percentage), max(missing_percentage))
# Out:
# insulin-5:55    float64
# insulin-5:50    float64
# insulin-5:45    float64
# insulin-5:40    float64
# insulin-5:35    float64
#                  ...
# insulin-0:20    float64
# insulin-0:15    float64
# insulin-0:10    float64
# insulin-0:05    float64
# insulin-0:00    float64
# Length: 72, dtype: object
# 5.295892082429502 5.335999638467101

# %%
carbs_cols = [col for col in patients.columns if col.startswith('carbs-')]
print(patients[carbs_cols].dtypes)
# Calculate the percentage of missing values for each 'carbs-' column
missing_percentage = patients[carbs_cols].isnull().mean() * 100
print(min(missing_percentage), max(missing_percentage))
# Out:
# carbs-5:55    float64
# carbs-5:50    float64
# carbs-5:45    float64
# carbs-5:40    float64
# carbs-5:35    float64
#                ...
# carbs-0:20    float64
# carbs-0:15    float64
# carbs-0:10    float64
# carbs-0:05    float64
# carbs-0:00    float64
# Length: 72, dtype: object
# 98.53918112798264 98.57194504699928

# %%
hr_cols = [col for col in patients.columns if col.startswith('hr-')]
print(patients[hr_cols].dtypes)
# Calculate the percentage of missing values for each 'hr-' column
missing_percentage = patients[hr_cols].isnull().mean() * 100
print(min(missing_percentage), max(missing_percentage))
# Out:
# hr-5:55    float64
# hr-5:50    float64
# hr-5:45    float64
# hr-5:40    float64
# hr-5:35    float64
#             ...
# hr-0:20    float64
# hr-0:15    float64
# hr-0:10    float64
# hr-0:05    float64
# hr-0:00    float64
# Length: 72, dtype: object
# 28.885348879248014 29.272302060737527

# %%
steps_cols = [col for col in patients.columns if col.startswith('steps-')]
print(patients[steps_cols].dtypes)
# Calculate the percentage of missing values for each 'steps-' column
missing_percentage = patients[steps_cols].isnull().mean() * 100
print(min(missing_percentage), max(missing_percentage))
# Out:
# steps-5:55    float64
# steps-5:50    float64
# steps-5:45    float64
# steps-5:40    float64
# steps-5:35    float64
#                ...
# steps-0:20    float64
# steps-0:15    float64
# steps-0:10    float64
# steps-0:05    float64
# steps-0:00    float64
# Length: 72, dtype: object
# 53.66165039768619 54.055382321041215

# %%
cals_cols = [col for col in patients.columns if col.startswith('cals-')]
print(patients[cals_cols].dtypes)
# Calculate the percentage of missing values for each 'cals-' column
missing_percentage = patients[cals_cols].isnull().mean() * 100
print(min(missing_percentage), max(missing_percentage))
# Out:
# cals-5:55    float64
# cals-5:50    float64
# cals-5:45    float64
# cals-5:40    float64
# cals-5:35    float64
#               ...
# cals-0:20    float64
# cals-0:15    float64
# cals-0:10    float64
# cals-0:05    float64
# cals-0:00    float64
# Length: 72, dtype: object
# 19.916508496023138 20.231155097613883

# %%
activity_cols = [col for col in patients.columns if col.startswith('activity-')]
print(patients[activity_cols].dtypes)
# Calculate the percentage of missing values for each 'activity-' column
missing_percentage = patients[activity_cols].isnull().mean() * 100
print(min(missing_percentage), max(missing_percentage))

# Initialize an empty set to store unique activities (using set to avoid duplicates)
unique_activities = set()
for col in activity_cols:
    unique_activities.update(patients[col].dropna().unique())  # dropna() to ignore NaN values
unique_activities_list = list(unique_activities)
print(unique_activities_list)
# Out:
# activity-5:55    object
# activity-5:50    object
# activity-5:45    object
# activity-5:40    object
# activity-5:35    object
#                   ...
# activity-0:20    object
# activity-0:15    object
# activity-0:10    object
# activity-0:05    object
# activity-0:00    object
# Length: 72, dtype: object
# 98.43411062906723 98.46800433839479
# ['Swim', 'Hike', 'Walk', 'HIIT', 'Outdoor Bike', 'Walking', 'Tennis', 'Zumba', 'Stairclimber', 'Workout', 'Weights', 'Bike', 'Aerobic Workout', 'Sport', 'Yoga', 'Spinning', 'Run', 'Dancing', 'Running', 'Indoor climbing', 'Swimming', 'Strength training']

# %%
# find the "busiest" patient, i.e. the one who reported the most activities across the activity- columns
# Step 1: Count non-missing values in the 'activity-' columns for each patient
activity_counts = patients.groupby('p_num')[activity_cols].apply(lambda x: x.notnull().sum().sum())

# Step 2: Find the patient with the maximum activity reports
busiest_patient = activity_counts.idxmax()
max_activities_reported = activity_counts.max()

# Step 3: Output the result
print(f"The busiest patient is {busiest_patient} with {max_activities_reported} reported activities.")

# Note: this is the highest absolute number of activity entries
# Out:
# The busiest patient is p10 with 65952 reported activities.

# %%
# Step 1: Count non-missing values in the 'activity-' columns for each patient
activity_counts = patients.groupby('p_num')[activity_cols].apply(lambda x: x.notnull().sum().sum())

# Step 2: Calculate the total possible activity entries for each patient
total_possible_activities = len(activity_cols) * patients.groupby('p_num').size()

# Step 3: Calculate the percentage of filled activity data for each patient
activity_percentage_filled = (activity_counts / total_possible_activities) * 100

# Display the percentage for each patient
print(activity_percentage_filled)

# Note: this is the highest percentage of filled activity data, which suggests that a higher proportion of the total data available 
# for this patient is filled in, even if the absolute number of activity records is lower.
# Out:
# p_num
# p01    3.935650
# p02    0.935857
# p03    0.430306
# p04    1.124625
# p05    1.233879
# p06    2.589401
# p10    3.598649
# p11    1.884432
# p12    0.304525
# dtype: float64

# %%
missing_percentage = patients['bg+1:00'].isna().sum() / len(patients) * 100
missing_percentage
# Out:
# np.float64(0.0)

# %%
# Melting the 'bg' columns into a long format
melted_data = pd.melt(patients, id_vars=['id', 'p_num', 'time'], value_vars=bg_cols, 
                      var_name='bg_time_offset', value_name='bg_value')

# Convert 'time' to datetime and adjust for the 'bg_time_offset'
melted_data['time'] = pd.to_datetime(melted_data['time'])
# Here you would adjust the 'time' column based on 'bg_time_offset', assuming it represents minutes before the timestamp
melted_data.tail()
# Out:
# C:\Users\svetl\AppData\Local\Temp\ipykernel_2092\1309164542.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   melted_data['time'] = pd.to_datetime(melted_data['time'])
#                  id p_num                time bg_time_offset  bg_value
# 12745723  p12_25294   p12 2024-10-19 23:35:00        bg-0:00       9.8
# 12745724  p12_25295   p12 2024-10-19 23:40:00        bg-0:00      10.3
# 12745725  p12_25296   p12 2024-10-19 23:45:00        bg-0:00      10.7
# 12745726  p12_25297   p12 2024-10-19 23:50:00        bg-0:00      11.0
# 12745727  p12_25298   p12 2024-10-19 23:55:00        bg-0:00      11.6

# %%
# Filter columns that are of interest: p_num, time, and columns starting with "bg-*" or "bg+1"
bg_columns = [col for col in patients.columns if col.startswith('bg-') or col == 'bg+1:00']
columns_to_display = ['p_num', 'time'] + bg_columns

# Select the relevant columns and output the first 20 rows
filtered_data = patients[columns_to_display].head()

# %%
# Detect outliers using the IQR method
outliers = {}

for col in hr_cols:
    Q1 = patients[col].quantile(0.25)
    Q3 = patients[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(lower_bound, upper_bound)
    # Get outliers
    outliers[col] = patients[(patients[col] < lower_bound) | (patients[col] > upper_bound)][col]
    
# Display outliers for each hr-* column
for col, outlier_values in outliers.items():
    print(f"Outliers in {col}:")
    print("min oulier:", outlier_values.min(), "max outlier:", outlier_values.max())
    print(outlier_values)
# Out:
# 26.750000000000007 127.94999999999999
# 26.750000000000007 127.94999999999999
# 26.750000000000007 127.94999999999999
# 26.750000000000007 127.94999999999999
# 26.750000000000007 127.94999999999999
# 26.750000000000007 127.94999999999999
# 26.750000000000007 127.94999999999999
# 26.999999999999993 127.80000000000001
# 26.750000000000007 127.94999999999999
# 26.937500000000014 127.83749999999999
# 26.999999999999993 127.80000000000001
# 26.750000000000007 127.94999999999999
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# 26.999999999999993 127.80000000000001
# Outliers in hr-5:55:
# min oulier: 128.0 max outlier: 185.3
# 617       148.2
# 618       157.9
# 1171      138.1
# 1172      141.3
# 1266      139.5
#           ...
# 173295    132.1
# 173458    133.7
# 173531    136.6
# 173787    129.5
# 175603    129.7
# Name: hr-5:55, Length: 1181, dtype: float64
# Outliers in hr-5:50:
# min oulier: 128.0 max outlier: 185.3
# 503       138.1
# 616       130.8
# 617       156.8
# 618       137.9
# 969       134.5
#           ...
# 173294    132.1
# 173457    133.7
# 173530    136.6
# 173786    129.5
# 175602    129.7
# Name: hr-5:50, Length: 1189, dtype: float64
# Outliers in hr-5:45:
# min oulier: 128.0 max outlier: 185.3
# 503       133.5
# 616       146.3
# 617       155.8
# 1170      136.7
# 1171      137.2
#           ...
# 173293    132.1
# 173456    133.7
# 173529    136.6
# 173785    129.5
# 175601    129.7
# Name: hr-5:45, Length: 1184, dtype: float64
# Outliers in hr-5:40:
# min oulier: 128.0 max outlier: 185.3
# 616       148.2
# 617       157.9
# 1170      138.1
# 1171      141.3
# 1265      139.5
#           ...
# 173292    132.1
# 173455    133.7
# 173528    136.6
# 173784    129.5
# 175600    129.7
# Name: hr-5:40, Length: 1180, dtype: float64
# Outliers in hr-5:35:
# min oulier: 128.0 max outlier: 185.3
# 502       138.1
# 615       130.8
# 616       156.8
# 617       137.9
# 968       134.5
#           ...
# 173291    132.1
# 173454    133.7
# 173527    136.6
# 173783    129.5
# 175599    129.7
# Name: hr-5:35, Length: 1188, dtype: float64
# Outliers in hr-5:30:
# min oulier: 128.0 max outlier: 185.3
# 502       133.5
# 615       146.3
# 616       155.8
# 1169      136.7
# 1170      137.2
#           ...
# 173290    132.1
# 173453    133.7
# 173526    136.6
# 173782    129.5
# 175598    129.7
# Name: hr-5:30, Length: 1186, dtype: float64
# Outliers in hr-5:25:
# min oulier: 128.0 max outlier: 185.3
# 615       148.2
# 616       157.9
# 1169      138.1
# 1170      141.3
# 1264      139.5
#           ...
# 173289    132.1
# 173452    133.7
# 173525    136.6
# 173781    129.5
# 175597    129.7
# Name: hr-5:25, Length: 1180, dtype: float64
# Outliers in hr-5:20:
# min oulier: 127.9 max outlier: 185.3
# 501       138.1
# 615       156.8
# 616       137.9
# 1169      129.3
# 1263      131.0
#           ...
# 173288    132.1
# 173451    133.7
# 173524    136.6
# 173780    129.5
# 175596    129.7
# Name: hr-5:20, Length: 1200, dtype: float64
# Outliers in hr-5:15:
# min oulier: 128.0 max outlier: 185.3
# 501       133.5
# 614       130.8
# 615       155.8
# 967       134.5
# 1168      130.5
#           ...
# 173287    132.1
# 173450    133.7
# 173523    136.6
# 173779    129.5
# 175595    129.7
# Name: hr-5:15, Length: 1186, dtype: float64
# Outliers in hr-5:10:
# min oulier: 127.9 max outlier: 185.3
# 614       146.3
# 615       157.9
# 1168      136.7
# 1169      141.3
# 1263      139.5
#           ...
# 173286    132.1
# 173449    133.7
# 173522    136.6
# 173778    129.5
# 175594    129.7
# Name: hr-5:10, Length: 1192, dtype: float64
# Outliers in hr-5:05:
# min oulier: 127.9 max outlier: 185.3
# 500       138.1
# 614       148.2
# 615       137.9
# 1168      138.1
# 1262      131.0
#           ...
# 173285    132.1
# 173448    133.7
# 173521    136.6
# 173777    129.5
# 175593    129.7
# Name: hr-5:05, Length: 1198, dtype: float64
# Outliers in hr-5:00:
# min oulier: 128.0 max outlier: 185.3
# 500       133.5
# 613       130.8
# 614       156.8
# 966       134.5
# 1167      130.5
#           ...
# 173284    132.1
# 173447    133.7
# 173520    136.6
# 173776    129.5
# 175592    129.7
# Name: hr-5:00, Length: 1187, dtype: float64
# Outliers in hr-4:55:
# min oulier: 127.9 max outlier: 185.3
# 613       146.3
# 614       155.8
# 1167      136.7
# 1168      137.2
# 1262      139.5
#           ...
# 173283    132.1
# 173446    133.7
# 173519    136.6
# 173775    129.5
# 175591    129.7
# Name: hr-4:55, Length: 1197, dtype: float64
# Outliers in hr-4:50:
# min oulier: 127.9 max outlier: 185.3
# 613       148.2
# 614       157.9
# 1167      138.1
# 1168      141.3
# 1261      131.0
#           ...
# 173282    132.1
# 173445    133.7
# 173518    136.6
# 173774    129.5
# 175590    129.7
# Name: hr-4:50, Length: 1200, dtype: float64
# Outliers in hr-4:45:
# min oulier: 127.9 max outlier: 185.3
# 499       138.1
# 612       130.8
# 613       156.8
# 614       137.9
# 965       134.5
#           ...
# 173281    132.1
# 173444    133.7
# 173517    136.6
# 173773    129.5
# 175589    129.7
# Name: hr-4:45, Length: 1207, dtype: float64
# Outliers in hr-4:40:
# min oulier: 127.9 max outlier: 185.3
# 499       133.5
# 612       146.3
# 613       155.8
# 1166      136.7
# 1167      137.2
#           ...
# 173280    132.1
# 173443    133.7
# 173516    136.6
# 173772    129.5
# 175588    129.7
# Name: hr-4:40, Length: 1202, dtype: float64
# Outliers in hr-4:35:
# min oulier: 127.9 max outlier: 185.3
# 612       148.2
# 613       157.9
# 1166      138.1
# 1167      141.3
# 1260      131.0
#           ...
# 173279    132.1
# 173442    133.7
# 173515    136.6
# 173771    129.5
# 175587    129.7
# Name: hr-4:35, Length: 1203, dtype: float64
# Outliers in hr-4:30:
# min oulier: 127.9 max outlier: 185.3
# 498       138.1
# 611       130.8
# 612       156.8
# 613       137.9
# 964       134.5
#           ...
# 173278    132.1
# 173441    133.7
# 173514    136.6
# 173770    129.5
# 175586    129.7
# Name: hr-4:30, Length: 1211, dtype: float64
# Outliers in hr-4:25:
# min oulier: 127.9 max outlier: 185.3
# 498       133.5
# 611       146.3
# 612       155.8
# 1165      136.7
# 1166      137.2
#           ...
# 173277    132.1
# 173440    133.7
# 173513    136.6
# 173769    129.5
# 175585    129.7
# Name: hr-4:25, Length: 1202, dtype: float64
# Outliers in hr-4:20:
# min oulier: 127.9 max outlier: 185.3
# 611       148.2
# 612       157.9
# 1165      138.1
# 1166      141.3
# 1259      131.0
#           ...
# 173276    132.1
# 173439    133.7
# 173512    136.6
# 173768    129.5
# 175584    129.7
# Name: hr-4:20, Length: 1203, dtype: float64
# Outliers in hr-4:15:
# min oulier: 127.9 max outlier: 185.3
# 497       138.1
# 610       130.8
# 611       156.8
# 612       137.9
# 963       134.5
#           ...
# 173275    132.1
# 173438    133.7
# 173511    136.6
# 173767    129.5
# 175583    129.7
# Name: hr-4:15, Length: 1208, dtype: float64
# Outliers in hr-4:10:
# min oulier: 127.9 max outlier: 185.3
# 497       133.5
# 610       146.3
# 611       155.8
# 1164      136.7
# 1165      137.2
#           ...
# 173274    132.1
# 173437    133.7
# 173510    136.6
# 173766    129.5
# 175582    129.7
# Name: hr-4:10, Length: 1197, dtype: float64
# Outliers in hr-4:05:
# min oulier: 127.9 max outlier: 185.3
# 610       148.2
# 611       157.9
# 1164      138.1
# 1165      141.3
# 1258      131.0
#           ...
# 173273    132.1
# 173436    133.7
# 173509    136.6
# 173765    129.5
# 175581    129.7
# Name: hr-4:05, Length: 1201, dtype: float64
# Outliers in hr-4:00:
# min oulier: 127.9 max outlier: 185.3
# 496       138.1
# 609       130.8
# 610       156.8
# 611       137.9
# 962       134.5
#           ...
# 173272    132.1
# 173435    133.7
# 173508    136.6
# 173764    129.5
# 175580    129.7
# Name: hr-4:00, Length: 1204, dtype: float64
# Outliers in hr-3:55:
# min oulier: 127.9 max outlier: 185.3
# 496       133.5
# 609       146.3
# 610       155.8
# 1163      136.7
# 1164      137.2
#           ...
# 173271    132.1
# 173434    133.7
# 173507    136.6
# 173763    129.5
# 175579    129.7
# Name: hr-3:55, Length: 1199, dtype: float64
# Outliers in hr-3:50:
# min oulier: 127.9 max outlier: 185.3
# 609       148.2
# 610       157.9
# 1163      138.1
# 1164      141.3
# 1257      131.0
#           ...
# 173270    132.1
# 173433    133.7
# 173506    136.6
# 173762    129.5
# 175578    129.7
# Name: hr-3:50, Length: 1200, dtype: float64
# Outliers in hr-3:45:
# min oulier: 127.9 max outlier: 185.3
# 495       138.1
# 608       130.8
# 609       156.8
# 610       137.9
# 961       134.5
#           ...
# 173269    132.1
# 173432    133.7
# 173505    136.6
# 173761    129.5
# 175577    129.7
# Name: hr-3:45, Length: 1203, dtype: float64
# Outliers in hr-3:40:
# min oulier: 127.9 max outlier: 185.3
# 495       133.5
# 608       146.3
# 609       155.8
# 1162      136.7
# 1163      137.2
#           ...
# 173268    132.1
# 173431    133.7
# 173504    136.6
# 173760    129.5
# 175576    129.7
# Name: hr-3:40, Length: 1196, dtype: float64
# Outliers in hr-3:35:
# min oulier: 127.9 max outlier: 185.3
# 608       148.2
# 609       157.9
# 1162      138.1
# 1163      141.3
# 1256      131.0
#           ...
# 173267    132.1
# 173430    133.7
# 173503    136.6
# 173759    129.5
# 175575    129.7
# Name: hr-3:35, Length: 1196, dtype: float64
# Outliers in hr-3:30:
# min oulier: 127.9 max outlier: 185.3
# 494       138.1
# 607       130.8
# 608       156.8
# 609       137.9
# 960       134.5
#           ...
# 173266    132.1
# 173429    133.7
# 173502    136.6
# 173758    129.5
# 175574    129.7
# Name: hr-3:30, Length: 1200, dtype: float64
# Outliers in hr-3:25:
# min oulier: 127.9 max outlier: 185.3
# 494       133.5
# 607       146.3
# 608       155.8
# 1161      136.7
# 1162      137.2
#           ...
# 173265    132.1
# 173428    133.7
# 173501    136.6
# 173757    129.5
# 175573    129.7
# Name: hr-3:25, Length: 1191, dtype: float64
# Outliers in hr-3:20:
# min oulier: 127.9 max outlier: 185.3
# 607       148.2
# 608       157.9
# 1161      138.1
# 1162      141.3
# 1255      131.0
#           ...
# 173264    132.1
# 173427    133.7
# 173500    136.6
# 173756    129.5
# 175572    129.7
# Name: hr-3:20, Length: 1191, dtype: float64
# Outliers in hr-3:15:
# min oulier: 127.9 max outlier: 185.3
# 493       138.1
# 606       130.8
# 607       156.8
# 608       137.9
# 959       134.5
#           ...
# 173263    132.1
# 173426    133.7
# 173499    136.6
# 173755    129.5
# 175571    129.7
# Name: hr-3:15, Length: 1203, dtype: float64
# Outliers in hr-3:10:
# min oulier: 127.9 max outlier: 185.3
# 493       133.5
# 606       146.3
# 607       155.8
# 1160      136.7
# 1161      137.2
#           ...
# 173262    132.1
# 173425    133.7
# 173498    136.6
# 173754    129.5
# 175570    129.7
# Name: hr-3:10, Length: 1195, dtype: float64
# Outliers in hr-3:05:
# min oulier: 127.9 max outlier: 185.3
# 606       148.2
# 607       157.9
# 1160      138.1
# 1161      141.3
# 1254      131.0
#           ...
# 173261    132.1
# 173424    133.7
# 173497    136.6
# 173753    129.5
# 175569    129.7
# Name: hr-3:05, Length: 1193, dtype: float64
# Outliers in hr-3:00:
# min oulier: 127.9 max outlier: 185.3
# 492       138.1
# 605       130.8
# 606       156.8
# 607       137.9
# 958       134.5
#           ...
# 173260    132.1
# 173423    133.7
# 173496    136.6
# 173752    129.5
# 175568    129.7
# Name: hr-3:00, Length: 1204, dtype: float64
# Outliers in hr-2:55:
# min oulier: 127.9 max outlier: 185.3
# 492       133.5
# 605       146.3
# 606       155.8
# 1159      136.7
# 1160      137.2
#           ...
# 173259    132.1
# 173422    133.7
# 173495    136.6
# 173751    129.5
# 175567    129.7
# Name: hr-2:55, Length: 1196, dtype: float64
# Outliers in hr-2:50:
# min oulier: 127.9 max outlier: 185.3
# 605       148.2
# 606       157.9
# 1159      138.1
# 1160      141.3
# 1253      131.0
#           ...
# 173258    132.1
# 173421    133.7
# 173494    136.6
# 173750    129.5
# 175566    129.7
# Name: hr-2:50, Length: 1194, dtype: float64
# Outliers in hr-2:45:
# min oulier: 127.9 max outlier: 185.3
# 491       138.1
# 604       130.8
# 605       156.8
# 606       137.9
# 957       134.5
#           ...
# 173257    132.1
# 173420    133.7
# 173493    136.6
# 173749    129.5
# 175565    129.7
# Name: hr-2:45, Length: 1205, dtype: float64
# Outliers in hr-2:40:
# min oulier: 127.9 max outlier: 185.3
# 491       133.5
# 604       146.3
# 605       155.8
# 1158      136.7
# 1159      137.2
#           ...
# 173256    132.1
# 173419    133.7
# 173492    136.6
# 173748    129.5
# 175564    129.7
# Name: hr-2:40, Length: 1194, dtype: float64
# Outliers in hr-2:35:
# min oulier: 127.9 max outlier: 185.3
# 604       148.2
# 605       157.9
# 1158      138.1
# 1159      141.3
# 1252      131.0
#           ...
# 173255    132.1
# 173418    133.7
# 173491    136.6
# 173747    129.5
# 175563    129.7
# Name: hr-2:35, Length: 1189, dtype: float64
# Outliers in hr-2:30:
# min oulier: 127.9 max outlier: 185.3
# 490       138.1
# 603       130.8
# 604       156.8
# 605       137.9
# 956       134.5
#           ...
# 173254    132.1
# 173417    133.7
# 173490    136.6
# 173746    129.5
# 175562    129.7
# Name: hr-2:30, Length: 1196, dtype: float64
# Outliers in hr-2:25:
# min oulier: 127.9 max outlier: 185.3
# 490       133.5
# 603       146.3
# 604       155.8
# 1157      136.7
# 1158      137.2
#           ...
# 173253    132.1
# 173416    133.7
# 173489    136.6
# 173745    129.5
# 175561    129.7
# Name: hr-2:25, Length: 1186, dtype: float64
# Outliers in hr-2:20:
# min oulier: 127.9 max outlier: 185.3
# 603       148.2
# 604       157.9
# 1157      138.1
# 1158      141.3
# 1251      131.0
#           ...
# 173252    132.1
# 173415    133.7
# 173488    136.6
# 173744    129.5
# 175560    129.7
# Name: hr-2:20, Length: 1182, dtype: float64
# Outliers in hr-2:15:
# min oulier: 127.9 max outlier: 185.3
# 489       138.1
# 602       130.8
# 603       156.8
# 604       137.9
# 955       134.5
#           ...
# 173251    132.1
# 173414    133.7
# 173487    136.6
# 173743    129.5
# 175559    129.7
# Name: hr-2:15, Length: 1193, dtype: float64
# Outliers in hr-2:10:
# min oulier: 127.9 max outlier: 185.3
# 489       133.5
# 602       146.3
# 603       155.8
# 1156      136.7
# 1157      137.2
#           ...
# 173413    133.7
# 173486    136.6
# 173742    129.5
# 174124    129.6
# 175558    129.7
# Name: hr-2:10, Length: 1181, dtype: float64
# Outliers in hr-2:05:
# min oulier: 127.9 max outlier: 185.3
# 602       148.2
# 603       157.9
# 1156      138.1
# 1157      141.3
# 1250      131.0
#           ...
# 173412    133.7
# 173485    136.6
# 173741    129.5
# 174123    129.6
# 175557    129.7
# Name: hr-2:05, Length: 1179, dtype: float64
# Outliers in hr-2:00:
# min oulier: 127.9 max outlier: 185.3
# 488       138.1
# 601       130.8
# 602       156.8
# 603       137.9
# 954       134.5
#           ...
# 173411    133.7
# 173484    136.6
# 173740    129.5
# 174122    129.6
# 175556    129.7
# Name: hr-2:00, Length: 1190, dtype: float64
# Outliers in hr-1:55:
# min oulier: 127.9 max outlier: 185.3
# 488       133.5
# 601       146.3
# 602       155.8
# 1155      136.7
# 1156      137.2
#           ...
# 173410    133.7
# 173483    136.6
# 173739    129.5
# 174121    129.6
# 175555    129.7
# Name: hr-1:55, Length: 1177, dtype: float64
# Outliers in hr-1:50:
# min oulier: 127.9 max outlier: 185.3
# 601       148.2
# 602       157.9
# 1155      138.1
# 1156      141.3
# 1249      131.0
#           ...
# 173409    133.7
# 173482    136.6
# 173738    129.5
# 174120    129.6
# 175554    129.7
# Name: hr-1:50, Length: 1175, dtype: float64
# Outliers in hr-1:45:
# min oulier: 127.9 max outlier: 185.3
# 487       138.1
# 600       130.8
# 601       156.8
# 602       137.9
# 953       134.5
#           ...
# 173408    133.7
# 173481    136.6
# 173737    129.5
# 174119    129.6
# 175553    129.7
# Name: hr-1:45, Length: 1187, dtype: float64
# Outliers in hr-1:40:
# min oulier: 127.9 max outlier: 185.3
# 487       133.5
# 600       146.3
# 601       155.8
# 1154      136.7
# 1155      137.2
#           ...
# 173407    133.7
# 173480    136.6
# 173736    129.5
# 174118    129.6
# 175552    129.7
# Name: hr-1:40, Length: 1176, dtype: float64
# Outliers in hr-1:35:
# min oulier: 127.9 max outlier: 185.3
# 600       148.2
# 601       157.9
# 1154      138.1
# 1155      141.3
# 1248      131.0
#           ...
# 173406    133.7
# 173479    136.6
# 173735    129.5
# 174117    129.6
# 175551    129.7
# Name: hr-1:35, Length: 1171, dtype: float64
# Outliers in hr-1:30:
# min oulier: 127.9 max outlier: 185.3
# 486       138.1
# 599       130.8
# 600       156.8
# 601       137.9
# 952       134.5
#           ...
# 173405    133.7
# 173478    136.6
# 173734    129.5
# 174116    129.6
# 175550    129.7
# Name: hr-1:30, Length: 1184, dtype: float64
# Outliers in hr-1:25:
# min oulier: 127.9 max outlier: 185.3
# 486       133.5
# 599       146.3
# 600       155.8
# 1153      136.7
# 1154      137.2
#           ...
# 173404    133.7
# 173477    136.6
# 173733    129.5
# 174115    129.6
# 175549    129.7
# Name: hr-1:25, Length: 1175, dtype: float64
# Outliers in hr-1:20:
# min oulier: 127.9 max outlier: 185.3
# 599       148.2
# 600       157.9
# 1153      138.1
# 1154      141.3
# 1247      131.0
#           ...
# 173403    133.7
# 173476    136.6
# 173732    129.5
# 174114    129.6
# 175548    129.7
# Name: hr-1:20, Length: 1173, dtype: float64
# Outliers in hr-1:15:
# min oulier: 127.9 max outlier: 185.3
# 485       138.1
# 598       130.8
# 599       156.8
# 600       137.9
# 951       134.5
#           ...
# 173402    133.7
# 173475    136.6
# 173731    129.5
# 174113    129.6
# 175547    129.7
# Name: hr-1:15, Length: 1185, dtype: float64
# Outliers in hr-1:10:
# min oulier: 127.9 max outlier: 185.3
# 485       133.5
# 598       146.3
# 599       155.8
# 1152      136.7
# 1153      137.2
#           ...
# 173401    133.7
# 173474    136.6
# 173730    129.5
# 174112    129.6
# 175546    129.7
# Name: hr-1:10, Length: 1175, dtype: float64
# Outliers in hr-1:05:
# min oulier: 127.9 max outlier: 185.3
# 598       148.2
# 599       157.9
# 1152      138.1
# 1153      141.3
# 1246      131.0
#           ...
# 173400    133.7
# 173473    136.6
# 173729    129.5
# 174111    129.6
# 175545    129.7
# Name: hr-1:05, Length: 1170, dtype: float64
# Outliers in hr-1:00:
# min oulier: 127.9 max outlier: 185.3
# 484       138.1
# 597       130.8
# 598       156.8
# 599       137.9
# 950       134.5
#           ...
# 173399    133.7
# 173472    136.6
# 173728    129.5
# 174110    129.6
# 175544    129.7
# Name: hr-1:00, Length: 1184, dtype: float64
# Outliers in hr-0:55:
# min oulier: 127.9 max outlier: 185.3
# 484       133.5
# 597       146.3
# 598       155.8
# 1151      136.7
# 1152      137.2
#           ...
# 173398    133.7
# 173471    136.6
# 173727    129.5
# 174109    129.6
# 175543    129.7
# Name: hr-0:55, Length: 1176, dtype: float64
# Outliers in hr-0:50:
# min oulier: 127.9 max outlier: 185.3
# 597       148.2
# 598       157.9
# 1151      138.1
# 1152      141.3
# 1245      131.0
#           ...
# 173397    133.7
# 173470    136.6
# 173726    129.5
# 174108    129.6
# 175542    129.7
# Name: hr-0:50, Length: 1172, dtype: float64
# Outliers in hr-0:45:
# min oulier: 127.9 max outlier: 185.3
# 483       138.1
# 596       130.8
# 597       156.8
# 598       137.9
# 949       134.5
#           ...
# 173396    133.7
# 173469    136.6
# 173725    129.5
# 174107    129.6
# 175541    129.7
# Name: hr-0:45, Length: 1188, dtype: float64
# Outliers in hr-0:40:
# min oulier: 127.9 max outlier: 185.3
# 483       133.5
# 596       146.3
# 597       155.8
# 1150      136.7
# 1151      137.2
#           ...
# 173395    133.7
# 173468    136.6
# 173724    129.5
# 174106    129.6
# 175540    129.7
# Name: hr-0:40, Length: 1176, dtype: float64
# Outliers in hr-0:35:
# min oulier: 127.9 max outlier: 185.3
# 596       148.2
# 597       157.9
# 1150      138.1
# 1151      141.3
# 1244      131.0
#           ...
# 173394    133.7
# 173467    136.6
# 173723    129.5
# 174105    129.6
# 175539    129.7
# Name: hr-0:35, Length: 1167, dtype: float64
# Outliers in hr-0:30:
# min oulier: 127.9 max outlier: 185.3
# 482       138.1
# 595       130.8
# 596       156.8
# 597       137.9
# 948       134.5
#           ...
# 173393    133.7
# 173466    136.6
# 173722    129.5
# 174104    129.6
# 175538    129.7
# Name: hr-0:30, Length: 1189, dtype: float64
# Outliers in hr-0:25:
# min oulier: 127.9 max outlier: 185.3
# 482       133.5
# 595       146.3
# 596       155.8
# 1149      136.7
# 1150      137.2
#           ...
# 173392    133.7
# 173465    136.6
# 173721    129.5
# 174103    129.6
# 175537    129.7
# Name: hr-0:25, Length: 1183, dtype: float64
# Outliers in hr-0:20:
# min oulier: 127.9 max outlier: 185.3
# 595       148.2
# 596       157.9
# 1149      138.1
# 1150      141.3
# 1243      131.0
#           ...
# 173391    133.7
# 173464    136.6
# 173720    129.5
# 174102    129.6
# 175536    129.7
# Name: hr-0:20, Length: 1172, dtype: float64
# Outliers in hr-0:15:
# min oulier: 127.9 max outlier: 185.3
# 481       138.1
# 594       130.8
# 595       156.8
# 596       137.9
# 947       134.5
#           ...
# 173390    133.7
# 173463    136.6
# 173719    129.5
# 174101    129.6
# 175535    129.7
# Name: hr-0:15, Length: 1198, dtype: float64
# Outliers in hr-0:10:
# min oulier: 127.9 max outlier: 185.3
# 481       133.5
# 594       146.3
# 595       155.8
# 1148      136.7
# 1149      137.2
#           ...
# 173389    133.7
# 173462    136.6
# 173718    129.5
# 174100    129.6
# 175534    129.7
# Name: hr-0:10, Length: 1188, dtype: float64
# Outliers in hr-0:05:
# min oulier: 127.9 max outlier: 185.3
# 594       148.2
# 595       157.9
# 1148      138.1
# 1149      141.3
# 1242      131.0
#           ...
# 173388    133.7
# 173461    136.6
# 173717    129.5
# 174099    129.6
# 175533    129.7
# Name: hr-0:05, Length: 1179, dtype: float64
# Outliers in hr-0:00:
# min oulier: 127.9 max outlier: 185.3
# 480       138.1
# 593       130.8
# 594       156.8
# 595       137.9
# 946       134.5
#           ...
# 173387    133.7
# 173460    136.6
# 173716    129.5
# 174098    129.6
# 175532    129.7
# Name: hr-0:00, Length: 1199, dtype: float64

# %%
# Detect outliers using the IQR method
outliers = {}

for col in bg_cols:
    Q1 = patients[col].quantile(0.25)
    Q3 = patients[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(lower_bound, upper_bound)
    # Get outliers
    outliers[col] = patients[(patients[col] < lower_bound) | (patients[col] > upper_bound)][col]
    
# Display outliers
for col, outlier_values in outliers.items():
    print(f"Outliers in {col}:")
    print("min oulier:", outlier_values.min(), "max outlier:", outlier_values.max())
    print(outlier_values)
# Out:
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.549999999999998 15.350000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# 0.7999999999999998 15.200000000000001
# 0.549999999999998 15.350000000000001
# 0.3999999999999986 15.600000000000001
# Outliers in bg-5:55:
# min oulier: 15.4 max outlier: 22.2
# 8724      15.4
# 8725      15.4
# 8726      15.4
# 9824      15.6
# 9825      15.7
#           ...
# 175479    16.0
# 175480    15.8
# 175481    15.6
# 175482    15.6
# 175483    15.5
# Name: bg-5:55, Length: 3383, dtype: float64
# Outliers in bg-5:50:
# min oulier: 15.4 max outlier: 25.1
# 29        15.5
# 35        17.1
# 36        17.9
# 37        17.4
# 38        16.1
#           ...
# 175478    16.0
# 175479    15.8
# 175480    15.6
# 175481    15.6
# 175482    15.5
# Name: bg-5:50, Length: 3911, dtype: float64
# Outliers in bg-5:45:
# min oulier: 15.4 max outlier: 27.8
# 14        15.4
# 15        17.2
# 16        18.2
# 17        18.4
# 18        18.0
#           ...
# 175477    16.0
# 175478    15.8
# 175479    15.6
# 175480    15.6
# 175481    15.5
# Name: bg-5:45, Length: 4285, dtype: float64
# Outliers in bg-5:40:
# min oulier: 15.4 max outlier: 22.2
# 8721      15.4
# 8722      15.4
# 8723      15.4
# 9821      15.6
# 9822      15.7
#           ...
# 175476    16.0
# 175477    15.8
# 175478    15.6
# 175479    15.6
# 175480    15.5
# Name: bg-5:40, Length: 3382, dtype: float64
# Outliers in bg-5:35:
# min oulier: 15.4 max outlier: 25.1
# 28        15.5
# 35        17.9
# 36        17.4
# 37        16.1
# 528       15.5
#           ...
# 175475    16.0
# 175476    15.8
# 175477    15.6
# 175478    15.6
# 175479    15.5
# Name: bg-5:35, Length: 3885, dtype: float64
# Outliers in bg-5:30:
# min oulier: 15.4 max outlier: 27.8
# 13        15.4
# 14        17.2
# 15        18.2
# 16        18.4
# 17        18.0
#           ...
# 175474    16.0
# 175475    15.8
# 175476    15.6
# 175477    15.6
# 175478    15.5
# Name: bg-5:30, Length: 4314, dtype: float64
# Outliers in bg-5:25:
# min oulier: 15.4 max outlier: 22.2
# 8718      15.4
# 8719      15.4
# 8720      15.4
# 9818      15.6
# 9819      15.7
#           ...
# 175473    16.0
# 175474    15.8
# 175475    15.6
# 175476    15.6
# 175477    15.5
# Name: bg-5:25, Length: 3382, dtype: float64
# Outliers in bg-5:20:
# min oulier: 15.4 max outlier: 25.1
# 27        15.5
# 33        17.1
# 35        17.4
# 36        16.1
# 527       15.5
#           ...
# 175472    16.0
# 175473    15.8
# 175474    15.6
# 175475    15.6
# 175476    15.5
# Name: bg-5:20, Length: 3864, dtype: float64
# Outliers in bg-5:15:
# min oulier: 15.4 max outlier: 27.8
# 12        15.4
# 13        17.2
# 14        18.2
# 15        18.4
# 16        18.0
#           ...
# 175471    16.0
# 175472    15.8
# 175473    15.6
# 175474    15.6
# 175475    15.5
# Name: bg-5:15, Length: 4338, dtype: float64
# Outliers in bg-5:10:
# min oulier: 15.4 max outlier: 22.2
# 8715      15.4
# 8716      15.4
# 8717      15.4
# 9815      15.6
# 9816      15.7
#           ...
# 175470    16.0
# 175471    15.8
# 175472    15.6
# 175473    15.6
# 175474    15.5
# Name: bg-5:10, Length: 3385, dtype: float64
# Outliers in bg-5:05:
# min oulier: 15.4 max outlier: 25.1
# 26        15.5
# 32        17.1
# 33        17.9
# 35        16.1
# 526       15.5
#           ...
# 175469    16.0
# 175470    15.8
# 175471    15.6
# 175472    15.6
# 175473    15.5
# Name: bg-5:05, Length: 3851, dtype: float64
# Outliers in bg-5:00:
# min oulier: 15.4 max outlier: 27.8
# 11        15.4
# 12        17.2
# 13        18.2
# 14        18.4
# 15        18.0
#           ...
# 175468    16.0
# 175469    15.8
# 175470    15.6
# 175471    15.6
# 175472    15.5
# Name: bg-5:00, Length: 4360, dtype: float64
# Outliers in bg-4:55:
# min oulier: 15.4 max outlier: 22.2
# 8712      15.4
# 8713      15.4
# 8714      15.4
# 9812      15.6
# 9813      15.7
#           ...
# 175467    16.0
# 175468    15.8
# 175469    15.6
# 175470    15.6
# 175471    15.5
# Name: bg-4:55, Length: 3386, dtype: float64
# Outliers in bg-4:50:
# min oulier: 15.4 max outlier: 25.1
# 31        17.1
# 32        17.9
# 33        17.4
# 526       15.8
# 527       16.2
#           ...
# 175466    16.0
# 175467    15.8
# 175468    15.6
# 175469    15.6
# 175470    15.5
# Name: bg-4:50, Length: 3832, dtype: float64
# Outliers in bg-4:45:
# min oulier: 15.4 max outlier: 27.8
# 10        15.4
# 11        17.2
# 12        18.2
# 13        18.4
# 14        18.0
#           ...
# 175465    16.0
# 175466    15.8
# 175467    15.6
# 175468    15.6
# 175469    15.5
# Name: bg-4:45, Length: 4385, dtype: float64
# Outliers in bg-4:40:
# min oulier: 15.4 max outlier: 22.2
# 8709      15.4
# 8710      15.4
# 8711      15.4
# 9809      15.6
# 9810      15.7
#           ...
# 175464    16.0
# 175465    15.8
# 175466    15.6
# 175467    15.6
# 175468    15.5
# Name: bg-4:40, Length: 3388, dtype: float64
# Outliers in bg-4:35:
# min oulier: 15.4 max outlier: 25.1
# 30        17.1
# 31        17.9
# 32        17.4
# 33        16.1
# 526       16.2
#           ...
# 175463    16.0
# 175464    15.8
# 175465    15.6
# 175466    15.6
# 175467    15.5
# Name: bg-4:35, Length: 3818, dtype: float64
# Outliers in bg-4:30:
# min oulier: 15.4 max outlier: 27.8
# 9         15.4
# 10        17.2
# 11        18.2
# 12        18.4
# 13        18.0
#           ...
# 175462    16.0
# 175463    15.8
# 175464    15.6
# 175465    15.6
# 175466    15.5
# Name: bg-4:30, Length: 4410, dtype: float64
# Outliers in bg-4:25:
# min oulier: 15.4 max outlier: 22.2
# 8706      15.4
# 8707      15.4
# 8708      15.4
# 9806      15.6
# 9807      15.7
#           ...
# 175461    16.0
# 175462    15.8
# 175463    15.6
# 175464    15.6
# 175465    15.5
# Name: bg-4:25, Length: 3391, dtype: float64
# Outliers in bg-4:20:
# min oulier: 15.4 max outlier: 25.1
# 29        17.1
# 30        17.9
# 31        17.4
# 32        16.1
# 526       16.7
#           ...
# 175460    16.0
# 175461    15.8
# 175462    15.6
# 175463    15.6
# 175464    15.5
# Name: bg-4:20, Length: 3802, dtype: float64
# Outliers in bg-4:15:
# min oulier: 15.7 max outlier: 27.8
# 9         17.2
# 10        18.2
# 11        18.4
# 12        18.0
# 13        17.3
#           ...
# 175456    15.8
# 175457    16.2
# 175458    16.3
# 175459    16.0
# 175460    15.8
# Name: bg-4:15, Length: 3859, dtype: float64
# Outliers in bg-4:10:
# min oulier: 15.4 max outlier: 22.2
# 8703      15.4
# 8704      15.4
# 8705      15.4
# 9803      15.6
# 9804      15.7
#           ...
# 175458    16.0
# 175459    15.8
# 175460    15.6
# 175461    15.6
# 175462    15.5
# Name: bg-4:10, Length: 3395, dtype: float64
# Outliers in bg-4:05:
# min oulier: 15.4 max outlier: 25.1
# 28        17.1
# 29        17.9
# 30        17.4
# 31        16.1
# 526       17.6
#           ...
# 175457    16.0
# 175458    15.8
# 175459    15.6
# 175460    15.6
# 175461    15.5
# Name: bg-4:05, Length: 3782, dtype: float64
# Outliers in bg-4:00:
# min oulier: 15.7 max outlier: 27.8
# 8         17.2
# 9         18.2
# 10        18.4
# 11        18.0
# 12        17.3
#           ...
# 175453    15.8
# 175454    16.2
# 175455    16.3
# 175456    16.0
# 175457    15.8
# Name: bg-4:00, Length: 3881, dtype: float64
# Outliers in bg-3:55:
# min oulier: 15.4 max outlier: 22.2
# 8700      15.4
# 8701      15.4
# 8702      15.4
# 9800      15.6
# 9801      15.7
#           ...
# 175455    16.0
# 175456    15.8
# 175457    15.6
# 175458    15.6
# 175459    15.5
# Name: bg-3:55, Length: 3398, dtype: float64
# Outliers in bg-3:50:
# min oulier: 15.4 max outlier: 25.1
# 27        17.1
# 28        17.9
# 29        17.4
# 30        16.1
# 526       19.4
#           ...
# 175454    16.0
# 175455    15.8
# 175456    15.6
# 175457    15.6
# 175458    15.5
# Name: bg-3:50, Length: 3763, dtype: float64
# Outliers in bg-3:45:
# min oulier: 15.7 max outlier: 27.8
# 7         17.2
# 8         18.2
# 9         18.4
# 10        18.0
# 11        17.3
#           ...
# 175450    15.8
# 175451    16.2
# 175452    16.3
# 175453    16.0
# 175454    15.8
# Name: bg-3:45, Length: 3898, dtype: float64
# Outliers in bg-3:40:
# min oulier: 15.4 max outlier: 22.2
# 8697      15.4
# 8698      15.4
# 8699      15.4
# 9797      15.6
# 9798      15.7
#           ...
# 175452    16.0
# 175453    15.8
# 175454    15.6
# 175455    15.6
# 175456    15.5
# Name: bg-3:40, Length: 3398, dtype: float64
# Outliers in bg-3:35:
# min oulier: 15.4 max outlier: 25.1
# 26        17.1
# 27        17.9
# 28        17.4
# 29        16.1
# 526       21.4
#           ...
# 175451    16.0
# 175452    15.8
# 175453    15.6
# 175454    15.6
# 175455    15.5
# Name: bg-3:35, Length: 3744, dtype: float64
# Outliers in bg-3:30:
# min oulier: 15.7 max outlier: 27.8
# 6         17.2
# 7         18.2
# 8         18.4
# 9         18.0
# 10        17.3
#           ...
# 175447    15.8
# 175448    16.2
# 175449    16.3
# 175450    16.0
# 175451    15.8
# Name: bg-3:30, Length: 3917, dtype: float64
# Outliers in bg-3:25:
# min oulier: 15.4 max outlier: 22.2
# 8694      15.4
# 8695      15.4
# 8696      15.4
# 9794      15.6
# 9795      15.7
#           ...
# 175449    16.0
# 175450    15.8
# 175451    15.6
# 175452    15.6
# 175453    15.5
# Name: bg-3:25, Length: 3394, dtype: float64
# Outliers in bg-3:20:
# min oulier: 15.4 max outlier: 25.1
# 26        17.9
# 27        17.4
# 28        16.1
# 526       24.1
# 528       24.0
#           ...
# 175448    16.0
# 175449    15.8
# 175450    15.6
# 175451    15.6
# 175452    15.5
# Name: bg-3:20, Length: 3720, dtype: float64
# Outliers in bg-3:15:
# min oulier: 15.7 max outlier: 27.8
# 5         17.2
# 6         18.2
# 7         18.4
# 8         18.0
# 9         17.3
#           ...
# 175444    15.8
# 175445    16.2
# 175446    16.3
# 175447    16.0
# 175448    15.8
# Name: bg-3:15, Length: 3933, dtype: float64
# Outliers in bg-3:10:
# min oulier: 15.4 max outlier: 22.2
# 8691      15.4
# 8692      15.4
# 8693      15.4
# 9791      15.6
# 9792      15.7
#           ...
# 175446    16.0
# 175447    15.8
# 175448    15.6
# 175449    15.6
# 175450    15.5
# Name: bg-3:10, Length: 3390, dtype: float64
# Outliers in bg-3:05:
# min oulier: 15.4 max outlier: 25.1
# 26        17.4
# 27        16.1
# 527       24.0
# 528       19.2
# 529       15.4
#           ...
# 175445    16.0
# 175446    15.8
# 175447    15.6
# 175448    15.6
# 175449    15.5
# Name: bg-3:05, Length: 3694, dtype: float64
# Outliers in bg-3:00:
# min oulier: 15.7 max outlier: 27.8
# 4         17.2
# 5         18.2
# 6         18.4
# 7         18.0
# 8         17.3
#           ...
# 175441    15.8
# 175442    16.2
# 175443    16.3
# 175444    16.0
# 175445    15.8
# Name: bg-3:00, Length: 3952, dtype: float64
# Outliers in bg-2:55:
# min oulier: 15.4 max outlier: 22.2
# 8688      15.4
# 8689      15.4
# 8690      15.4
# 9788      15.6
# 9789      15.7
#           ...
# 175443    16.0
# 175444    15.8
# 175445    15.6
# 175446    15.6
# 175447    15.5
# Name: bg-2:55, Length: 3388, dtype: float64
# Outliers in bg-2:50:
# min oulier: 15.4 max outlier: 25.1
# 26        16.1
# 526       24.0
# 527       19.2
# 528       15.4
# 649       15.9
#           ...
# 175442    16.0
# 175443    15.8
# 175444    15.6
# 175445    15.6
# 175446    15.5
# Name: bg-2:50, Length: 3672, dtype: float64
# Outliers in bg-2:45:
# min oulier: 15.7 max outlier: 27.8
# 3         17.2
# 4         18.2
# 5         18.4
# 6         18.0
# 7         17.3
#           ...
# 175438    15.8
# 175439    16.2
# 175440    16.3
# 175441    16.0
# 175442    15.8
# Name: bg-2:45, Length: 3972, dtype: float64
# Outliers in bg-2:40:
# min oulier: 15.4 max outlier: 22.2
# 8685      15.4
# 8686      15.4
# 8687      15.4
# 9785      15.6
# 9786      15.7
#           ...
# 175440    16.0
# 175441    15.8
# 175442    15.6
# 175443    15.6
# 175444    15.5
# Name: bg-2:40, Length: 3386, dtype: float64
# Outliers in bg-2:35:
# min oulier: 15.4 max outlier: 25.1
# 526       19.2
# 527       15.4
# 649       15.8
# 653       15.5
# 654       15.6
#           ...
# 175439    16.0
# 175440    15.8
# 175441    15.6
# 175442    15.6
# 175443    15.5
# Name: bg-2:35, Length: 3647, dtype: float64
# Outliers in bg-2:30:
# min oulier: 15.7 max outlier: 27.8
# 2         17.2
# 3         18.2
# 4         18.4
# 5         18.0
# 6         17.3
#           ...
# 175435    15.8
# 175436    16.2
# 175437    16.3
# 175438    16.0
# 175439    15.8
# Name: bg-2:30, Length: 3990, dtype: float64
# Outliers in bg-2:25:
# min oulier: 15.4 max outlier: 22.2
# 8682      15.4
# 8683      15.4
# 8684      15.4
# 9782      15.6
# 9783      15.7
#           ...
# 175437    16.0
# 175438    15.8
# 175439    15.6
# 175440    15.6
# 175441    15.5
# Name: bg-2:25, Length: 3383, dtype: float64
# Outliers in bg-2:20:
# min oulier: 15.4 max outlier: 25.1
# 526       15.4
# 652       15.5
# 653       15.6
# 654       15.8
# 655       15.9
#           ...
# 175436    16.0
# 175437    15.8
# 175438    15.6
# 175439    15.6
# 175440    15.5
# Name: bg-2:20, Length: 3623, dtype: float64
# Outliers in bg-2:15:
# min oulier: 15.7 max outlier: 27.8
# 1         17.2
# 2         18.2
# 3         18.4
# 4         18.0
# 5         17.3
#           ...
# 175432    15.8
# 175433    16.2
# 175434    16.3
# 175435    16.0
# 175436    15.8
# Name: bg-2:15, Length: 4006, dtype: float64
# Outliers in bg-2:10:
# min oulier: 15.3 max outlier: 22.2
# 8679      15.4
# 8680      15.4
# 8681      15.4
# 9779      15.6
# 9780      15.7
#           ...
# 175434    16.0
# 175435    15.8
# 175436    15.6
# 175437    15.6
# 175438    15.5
# Name: bg-2:10, Length: 3585, dtype: float64
# Outliers in bg-2:05:
# min oulier: 15.4 max outlier: 25.1
# 651       15.5
# 652       15.6
# 653       15.8
# 654       15.9
# 655       16.2
#           ...
# 175433    16.0
# 175434    15.8
# 175435    15.6
# 175436    15.6
# 175437    15.5
# Name: bg-2:05, Length: 3602, dtype: float64
# Outliers in bg-2:00:
# min oulier: 15.7 max outlier: 27.8
# 0         17.2
# 1         18.2
# 2         18.4
# 3         18.0
# 4         17.3
#           ...
# 175429    15.8
# 175430    16.2
# 175431    16.3
# 175432    16.0
# 175433    15.8
# Name: bg-2:00, Length: 4026, dtype: float64
# Outliers in bg-1:55:
# min oulier: 15.3 max outlier: 22.2
# 5047      15.3
# 8676      15.4
# 8677      15.4
# 8678      15.4
# 9776      15.6
#           ...
# 175431    16.0
# 175432    15.8
# 175433    15.6
# 175434    15.6
# 175435    15.5
# Name: bg-1:55, Length: 3584, dtype: float64
# Outliers in bg-1:50:
# min oulier: 15.4 max outlier: 25.1
# 650       15.5
# 651       15.6
# 652       15.8
# 653       15.9
# 654       16.2
#           ...
# 175430    16.0
# 175431    15.8
# 175432    15.6
# 175433    15.6
# 175434    15.5
# Name: bg-1:50, Length: 3581, dtype: float64
# Outliers in bg-1:45:
# min oulier: 15.7 max outlier: 27.8
# 0         18.2
# 1         18.4
# 2         18.0
# 3         17.3
# 4         17.5
#           ...
# 175426    15.8
# 175427    16.2
# 175428    16.3
# 175429    16.0
# 175430    15.8
# Name: bg-1:45, Length: 4042, dtype: float64
# Outliers in bg-1:40:
# min oulier: 15.3 max outlier: 22.2
# 5046      15.3
# 5047      16.2
# 8673      15.4
# 8674      15.4
# 8675      15.4
#           ...
# 175428    16.0
# 175429    15.8
# 175430    15.6
# 175431    15.6
# 175432    15.5
# Name: bg-1:40, Length: 3583, dtype: float64
# Outliers in bg-1:35:
# min oulier: 15.4 max outlier: 25.1
# 649       15.5
# 650       15.6
# 651       15.8
# 652       15.9
# 653       16.2
#           ...
# 175427    16.0
# 175428    15.8
# 175429    15.6
# 175430    15.6
# 175431    15.5
# Name: bg-1:35, Length: 3561, dtype: float64
# Outliers in bg-1:30:
# min oulier: 15.7 max outlier: 27.8
# 0         18.4
# 1         18.0
# 2         17.3
# 3         17.5
# 4         17.3
#           ...
# 175423    15.8
# 175424    16.2
# 175425    16.3
# 175426    16.0
# 175427    15.8
# Name: bg-1:30, Length: 4061, dtype: float64
# Outliers in bg-1:25:
# min oulier: 15.3 max outlier: 22.2
# 5045      15.3
# 5046      16.2
# 5047      17.2
# 8670      15.4
# 8671      15.4
#           ...
# 175425    16.0
# 175426    15.8
# 175427    15.6
# 175428    15.6
# 175429    15.5
# Name: bg-1:25, Length: 3589, dtype: float64
# Outliers in bg-1:20:
# min oulier: 15.4 max outlier: 23.6
# 649       15.6
# 650       15.8
# 651       15.9
# 652       16.2
# 653       17.1
#           ...
# 175424    16.0
# 175425    15.8
# 175426    15.6
# 175427    15.6
# 175428    15.5
# Name: bg-1:20, Length: 3546, dtype: float64
# Outliers in bg-1:15:
# min oulier: 15.7 max outlier: 27.8
# 0         18.0
# 1         17.3
# 2         17.5
# 3         17.3
# 4         16.2
#           ...
# 175420    15.8
# 175421    16.2
# 175422    16.3
# 175423    16.0
# 175424    15.8
# Name: bg-1:15, Length: 4085, dtype: float64
# Outliers in bg-1:10:
# min oulier: 15.3 max outlier: 22.2
# 5044      15.3
# 5045      16.2
# 5046      17.2
# 5047      17.0
# 8667      15.4
#           ...
# 175422    16.0
# 175423    15.8
# 175424    15.6
# 175425    15.6
# 175426    15.5
# Name: bg-1:10, Length: 3594, dtype: float64
# Outliers in bg-1:05:
# min oulier: 15.4 max outlier: 22.7
# 649       15.8
# 650       15.9
# 651       16.2
# 652       17.1
# 653       17.8
#           ...
# 175421    16.0
# 175422    15.8
# 175423    15.6
# 175424    15.6
# 175425    15.5
# Name: bg-1:05, Length: 3530, dtype: float64
# Outliers in bg-1:00:
# min oulier: 15.7 max outlier: 27.8
# 0         17.3
# 1         17.5
# 2         17.3
# 3         16.2
# 16        17.1
#           ...
# 175417    15.8
# 175418    16.2
# 175419    16.3
# 175420    16.0
# 175421    15.8
# Name: bg-1:00, Length: 4110, dtype: float64
# Outliers in bg-0:55:
# min oulier: 15.3 max outlier: 22.2
# 5043      15.3
# 5044      16.2
# 5045      17.2
# 5046      17.0
# 5047      16.3
#           ...
# 175419    16.0
# 175420    15.8
# 175421    15.6
# 175422    15.6
# 175423    15.5
# Name: bg-0:55, Length: 3605, dtype: float64
# Outliers in bg-0:50:
# min oulier: 15.4 max outlier: 22.7
# 649       15.9
# 650       16.2
# 651       17.1
# 652       17.8
# 653       18.3
#           ...
# 175418    16.0
# 175419    15.8
# 175420    15.6
# 175421    15.6
# 175422    15.5
# Name: bg-0:50, Length: 3521, dtype: float64
# Outliers in bg-0:45:
# min oulier: 15.7 max outlier: 27.8
# 0         17.5
# 1         17.3
# 2         16.2
# 15        17.1
# 16        17.9
#           ...
# 175414    15.8
# 175415    16.2
# 175416    16.3
# 175417    16.0
# 175418    15.8
# Name: bg-0:45, Length: 4137, dtype: float64
# Outliers in bg-0:40:
# min oulier: 15.3 max outlier: 22.2
# 5043      16.2
# 5044      17.2
# 5045      17.0
# 5046      16.3
# 5047      15.8
#           ...
# 175416    16.0
# 175417    15.8
# 175418    15.6
# 175419    15.6
# 175420    15.5
# Name: bg-0:40, Length: 3616, dtype: float64
# Outliers in bg-0:35:
# min oulier: 15.4 max outlier: 22.7
# 649       16.2
# 650       17.1
# 651       17.8
# 652       18.3
# 653       19.6
#           ...
# 175415    16.0
# 175416    15.8
# 175417    15.6
# 175418    15.6
# 175419    15.5
# Name: bg-0:35, Length: 3510, dtype: float64
# Outliers in bg-0:30:
# min oulier: 15.7 max outlier: 27.8
# 0         17.3
# 1         16.2
# 14        17.1
# 15        17.9
# 16        17.4
#           ...
# 175411    15.8
# 175412    16.2
# 175413    16.3
# 175414    16.0
# 175415    15.8
# Name: bg-0:30, Length: 4164, dtype: float64
# Outliers in bg-0:25:
# min oulier: 15.3 max outlier: 22.2
# 5043      17.2
# 5044      17.0
# 5045      16.3
# 5046      15.8
# 5047      15.4
#           ...
# 175413    16.0
# 175414    15.8
# 175415    15.6
# 175416    15.6
# 175417    15.5
# Name: bg-0:25, Length: 3627, dtype: float64
# Outliers in bg-0:20:
# min oulier: 15.4 max outlier: 22.7
# 649       17.1
# 650       17.8
# 651       18.3
# 652       19.6
# 653       20.7
#           ...
# 175412    16.0
# 175413    15.8
# 175414    15.6
# 175415    15.6
# 175416    15.5
# Name: bg-0:20, Length: 3505, dtype: float64
# Outliers in bg-0:15:
# min oulier: 15.7 max outlier: 27.8
# 0         16.2
# 13        17.1
# 14        17.9
# 15        17.4
# 16        16.1
#           ...
# 175408    15.8
# 175409    16.2
# 175410    16.3
# 175411    16.0
# 175412    15.8
# Name: bg-0:15, Length: 4190, dtype: float64
# Outliers in bg-0:10:
# min oulier: 15.3 max outlier: 22.2
# 5043      17.0
# 5044      16.3
# 5045      15.8
# 5046      15.4
# 8655      15.4
#           ...
# 175410    16.0
# 175411    15.8
# 175412    15.6
# 175413    15.6
# 175414    15.5
# Name: bg-0:10, Length: 3634, dtype: float64
# Outliers in bg-0:05:
# min oulier: 15.4 max outlier: 22.7
# 649       17.8
# 650       18.3
# 651       19.6
# 652       20.7
# 904       16.4
#           ...
# 175409    16.0
# 175410    15.8
# 175411    15.6
# 175412    15.6
# 175413    15.5
# Name: bg-0:05, Length: 3495, dtype: float64
# Outliers in bg-0:00:
# min oulier: 15.7 max outlier: 27.8
# 12        17.1
# 13        17.9
# 14        17.4
# 15        16.1
# 71        15.9
#           ...
# 175405    15.8
# 175406    16.2
# 175407    16.3
# 175408    16.0
# 175409    15.8
# Name: bg-0:00, Length: 4213, dtype: float64

# %%
# Detect outliers using the IQR method
outliers = {}

for col in insulin_cols:
    Q1 = patients[col].quantile(0.25)
    Q3 = patients[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(lower_bound, upper_bound)
    # Get outliers
    outliers[col] = patients[(patients[col] < lower_bound) | (patients[col] > upper_bound)][col]
    
# Display outliers
for col, outlier_values in outliers.items():
    print(f"Outliers in {col}:")
    print("min oulier:", outlier_values.min(), "max outlier:", outlier_values.max())
    print(outlier_values)
# Out:
# -0.05644999999999998 0.20714999999999997
# -0.05670000000000001 0.20729999999999998
# -0.05670000000000001 0.20729999999999998
# -0.05670000000000001 0.20729999999999998
# -0.05670000000000001 0.20729999999999998
# -0.05670000000000001 0.20729999999999998
# -0.05670000000000001 0.20729999999999998
# -0.05670000000000001 0.20729999999999998
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.0572 0.2076
# -0.05694999999999999 0.20744999999999997
# -0.0572 0.2076
# -0.0572 0.2076
# -0.0572 0.2076
# -0.0573875 0.2077125
# -0.057449999999999994 0.20775
# -0.0572 0.2076
# -0.057449999999999994 0.20775
# -0.057449999999999994 0.20775
# -0.0572 0.2076
# -0.057449999999999994 0.20775
# -0.057449999999999994 0.20775
# -0.0572 0.2076
# -0.057449999999999994 0.20775
# -0.05769999999999998 0.20789999999999997
# -0.057449999999999994 0.20775
# -0.05769999999999998 0.20789999999999997
# -0.05769999999999998 0.20789999999999997
# -0.057449999999999994 0.20775
# -0.057449999999999994 0.20775
# -0.057449999999999994 0.20775
# -0.0572 0.2076
# -0.0572 0.2076
# -0.057449999999999994 0.20775
# -0.0572 0.2076
# -0.0572 0.2076
# -0.0572 0.2076
# -0.05694999999999999 0.20744999999999997
# -0.0572 0.2076
# -0.0572 0.2076
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.0572 0.2076
# -0.05707499999999998 0.20752499999999996
# -0.0572 0.2076
# -0.0572 0.2076
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.0572 0.2076
# -0.05694999999999999 0.20744999999999997
# -0.05694999999999999 0.20744999999999997
# -0.0572 0.2076
# -0.0572 0.2076
# -0.0572 0.2076
# -0.057449999999999994 0.20775
# -0.057449999999999994 0.20775
# -0.057449999999999994 0.20775
# -0.05769999999999998 0.20789999999999997
# -0.05769999999999998 0.20789999999999997
# -0.05795000000000001 0.20805
# -0.05819999999999999 0.2082
# -0.05819999999999999 0.2082
# -0.05819999999999999 0.2082
# -0.05819999999999999 0.2082
# -0.05819999999999999 0.2082
# -0.05819999999999999 0.2082
# Outliers in insulin-5:55:
# min oulier: -0.3078 max outlier: 46.311
# 35        1.0583
# 68        1.8292
# 73        5.8292
# 83        1.0333
# 92        0.2167
#            ...
# 177016    0.2750
# 177017    0.2500
# 177018    0.2750
# 177019    0.2750
# 177023    1.2900
# Name: insulin-5:55, Length: 17697, dtype: float64
# Outliers in insulin-5:50:
# min oulier: -0.3078 max outlier: 46.311
# 53        3.1500
# 90        0.6333
# 91        0.9167
# 149       8.0500
# 265       2.2083
#            ...
# 177016    0.2500
# 177017    0.2750
# 177018    0.2750
# 177022    1.2900
# 177023    0.5600
# Name: insulin-5:50, Length: 17687, dtype: float64
# Outliers in insulin-5:45:
# min oulier: -0.3078 max outlier: 46.311
# 29        6.5417
# 109       1.7083
# 126       8.0583
# 152       4.0500
# 315       2.5500
#            ...
# 177016    0.2750
# 177017    0.2750
# 177021    1.2900
# 177022    0.5600
# 177023    0.3100
# Name: insulin-5:45, Length: 17679, dtype: float64
# Outliers in insulin-5:40:
# min oulier: -0.3078 max outlier: 46.311
# 34        2.6583
# 67        1.8292
# 72        5.8292
# 82        1.0333
# 91        0.2167
#            ...
# 177016    0.2750
# 177020    1.2900
# 177021    0.5600
# 177022    0.3100
# 177023    0.2750
# Name: insulin-5:40, Length: 17693, dtype: float64
# Outliers in insulin-5:35:
# min oulier: -0.3078 max outlier: 46.311
# 34        1.0583
# 52        3.1500
# 89        0.6333
# 90        0.9167
# 148       8.0500
#            ...
# 177019    1.2900
# 177020    0.5600
# 177021    0.3100
# 177022    0.2750
# 177023    0.2500
# Name: insulin-5:35, Length: 17687, dtype: float64
# Outliers in insulin-5:30:
# min oulier: -0.3078 max outlier: 46.311
# 28        6.5417
# 33        2.6583
# 108       1.7083
# 125       8.0583
# 151       4.0500
#            ...
# 177019    0.5600
# 177020    0.3100
# 177021    0.2750
# 177022    0.2500
# 177023    0.2750
# Name: insulin-5:30, Length: 17690, dtype: float64
# Outliers in insulin-5:25:
# min oulier: -0.3078 max outlier: 46.311
# 33        1.0583
# 66        1.8292
# 71        5.8292
# 81        1.0333
# 90        0.2167
#            ...
# 177018    0.5600
# 177019    0.3100
# 177020    0.2750
# 177021    0.2500
# 177022    0.2750
# Name: insulin-5:25, Length: 17678, dtype: float64
# Outliers in insulin-5:20:
# min oulier: -0.3078 max outlier: 46.311
# 51        3.1500
# 88        0.6333
# 89        0.9167
# 147       8.0500
# 263       2.2083
#            ...
# 177017    0.5600
# 177018    0.3100
# 177019    0.2750
# 177020    0.2500
# 177021    0.2750
# Name: insulin-5:20, Length: 17690, dtype: float64
# Outliers in insulin-5:15:
# min oulier: -0.3078 max outlier: 46.311
# 27        6.5417
# 32        2.6583
# 107       1.7083
# 124       8.0583
# 150       4.0500
#            ...
# 177016    0.5600
# 177017    0.3100
# 177018    0.2750
# 177019    0.2500
# 177020    0.2750
# Name: insulin-5:15, Length: 17667, dtype: float64
# Outliers in insulin-5:10:
# min oulier: -0.3078 max outlier: 46.311
# 32        1.0583
# 65        1.8292
# 70        5.8292
# 80        1.0333
# 89        0.2167
#            ...
# 177015    0.5600
# 177016    0.3100
# 177017    0.2750
# 177018    0.2500
# 177019    0.2750
# Name: insulin-5:10, Length: 17660, dtype: float64
# Outliers in insulin-5:05:
# min oulier: -0.3078 max outlier: 46.311
# 50        3.1500
# 87        0.6333
# 88        0.9167
# 146       8.0500
# 262       2.2083
#            ...
# 177014    0.5600
# 177015    0.3100
# 177016    0.2750
# 177017    0.2500
# 177018    0.2750
# Name: insulin-5:05, Length: 17658, dtype: float64
# Outliers in insulin-5:00:
# min oulier: -0.3078 max outlier: 46.311
# 26        6.5417
# 31        2.6583
# 106       1.7083
# 123       8.0583
# 149       4.0500
#            ...
# 177013    0.5600
# 177014    0.3100
# 177015    0.2750
# 177016    0.2500
# 177017    0.2750
# Name: insulin-5:00, Length: 17651, dtype: float64
# Outliers in insulin-4:55:
# min oulier: -0.3078 max outlier: 46.311
# 31        1.0583
# 64        1.8292
# 69        5.8292
# 79        1.0333
# 88        0.2167
#            ...
# 177012    0.5600
# 177013    0.3100
# 177014    0.2750
# 177015    0.2500
# 177016    0.2750
# Name: insulin-4:55, Length: 17646, dtype: float64
# Outliers in insulin-4:50:
# min oulier: -0.3078 max outlier: 46.311
# 49        3.1500
# 86        0.6333
# 87        0.9167
# 145       8.0500
# 261       2.2083
#            ...
# 177011    0.5600
# 177012    0.3100
# 177013    0.2750
# 177014    0.2500
# 177015    0.2750
# Name: insulin-4:50, Length: 17669, dtype: float64
# Outliers in insulin-4:45:
# min oulier: -0.3078 max outlier: 46.311
# 30        2.6583
# 105       1.7083
# 122       8.0583
# 148       4.0500
# 311       2.5500
#            ...
# 177010    0.5600
# 177011    0.3100
# 177012    0.2750
# 177013    0.2500
# 177014    0.2750
# Name: insulin-4:45, Length: 17640, dtype: float64
# Outliers in insulin-4:40:
# min oulier: -0.3078 max outlier: 46.311
# 25        6.5417
# 30        1.0583
# 68        5.8292
# 78        1.0333
# 87        0.2167
#            ...
# 177009    0.5600
# 177010    0.3100
# 177011    0.2750
# 177012    0.2500
# 177013    0.2750
# Name: insulin-4:40, Length: 17629, dtype: float64
# Outliers in insulin-4:35:
# min oulier: -0.3078 max outlier: 46.311
# 48        3.1500
# 63        1.8292
# 85        0.6333
# 86        0.9167
# 144       8.0500
#            ...
# 177008    0.5600
# 177009    0.3100
# 177010    0.2750
# 177011    0.2500
# 177012    0.2750
# Name: insulin-4:35, Length: 17656, dtype: float64
# Outliers in insulin-4:30:
# min oulier: -0.3078 max outlier: 46.311
# 29        2.6583
# 104       1.7083
# 121       8.0583
# 147       4.0500
# 310       2.5500
#            ...
# 177007    0.5600
# 177008    0.3100
# 177009    0.2750
# 177010    0.2500
# 177011    0.2750
# Name: insulin-4:30, Length: 17616, dtype: float64
# Outliers in insulin-4:25:
# min oulier: -0.3078 max outlier: 46.311
# 24        6.5417
# 29        1.0583
# 67        5.8292
# 77        1.0333
# 86        0.2167
#            ...
# 177006    0.5600
# 177007    0.3100
# 177008    0.2750
# 177009    0.2500
# 177010    0.2750
# Name: insulin-4:25, Length: 17622, dtype: float64
# Outliers in insulin-4:20:
# min oulier: -0.3078 max outlier: 46.311
# 47        3.1500
# 62        1.8292
# 84        0.6333
# 85        0.9167
# 143       8.0500
#            ...
# 177005    0.5600
# 177006    0.3100
# 177007    0.2750
# 177008    0.2500
# 177009    0.2750
# Name: insulin-4:20, Length: 17640, dtype: float64
# Outliers in insulin-4:15:
# min oulier: -0.3078 max outlier: 46.311
# 28        2.6583
# 103       1.7083
# 146       4.0500
# 309       2.5500
# 447       0.6167
#            ...
# 177004    0.5600
# 177005    0.3100
# 177006    0.2750
# 177007    0.2500
# 177008    0.2750
# Name: insulin-4:15, Length: 17600, dtype: float64
# Outliers in insulin-4:10:
# min oulier: -0.3078 max outlier: 46.311
# 23        6.5417
# 28        1.0583
# 66        5.8292
# 76        1.0333
# 85        0.2167
#            ...
# 177004    0.3100
# 177005    0.2750
# 177006    0.2500
# 177007    0.2750
# 177023    0.4600
# Name: insulin-4:10, Length: 17600, dtype: float64
# Outliers in insulin-4:05:
# min oulier: -0.3078 max outlier: 46.311
# 46        3.1500
# 61        1.8292
# 83        0.6333
# 84        0.9167
# 142       8.0500
#            ...
# 177004    0.2750
# 177005    0.2500
# 177006    0.2750
# 177022    0.4600
# 177023    0.2500
# Name: insulin-4:05, Length: 17647, dtype: float64
# Outliers in insulin-4:00:
# min oulier: -0.3078 max outlier: 46.311
# 27        2.6583
# 102       1.7083
# 120       8.0583
# 145       4.0500
# 308       2.5500
#            ...
# 177004    0.2500
# 177005    0.2750
# 177021    0.4600
# 177022    0.2500
# 177023    0.2750
# Name: insulin-4:00, Length: 17599, dtype: float64
# Outliers in insulin-3:55:
# min oulier: -0.3078 max outlier: 46.311
# 22        6.5417
# 27        1.0583
# 65        5.8292
# 75        1.0333
# 84        0.2167
#            ...
# 177004    0.2750
# 177020    0.4600
# 177021    0.2500
# 177022    0.2750
# 177023    0.3600
# Name: insulin-3:55, Length: 17610, dtype: float64
# Outliers in insulin-3:50:
# min oulier: -0.3078 max outlier: 46.311
# 45        3.1500
# 60        1.8292
# 82        0.6333
# 83        0.9167
# 141       8.0500
#            ...
# 177019    0.4600
# 177020    0.2500
# 177021    0.2750
# 177022    0.3600
# 177023    0.2750
# Name: insulin-3:50, Length: 17646, dtype: float64
# Outliers in insulin-3:45:
# min oulier: -0.3078 max outlier: 46.311
# 26        2.6583
# 101       1.7083
# 119       8.0583
# 144       4.0500
# 307       2.5500
#            ...
# 177019    0.2500
# 177020    0.2750
# 177021    0.3600
# 177022    0.2750
# 177023    3.4500
# Name: insulin-3:45, Length: 17613, dtype: float64
# Outliers in insulin-3:40:
# min oulier: -0.3078 max outlier: 46.311
# 21        6.5417
# 26        1.0583
# 64        5.8292
# 74        1.0333
# 83        0.2167
#            ...
# 177019    0.2750
# 177020    0.3600
# 177021    0.2750
# 177022    3.4500
# 177023    0.2500
# Name: insulin-3:40, Length: 17613, dtype: float64
# Outliers in insulin-3:35:
# min oulier: -0.3078 max outlier: 46.311
# 44        3.1500
# 59        1.8292
# 81        0.6333
# 82        0.9167
# 140       8.0500
#            ...
# 177019    0.3600
# 177020    0.2750
# 177021    3.4500
# 177022    0.2500
# 177023    0.2750
# Name: insulin-3:35, Length: 17636, dtype: float64
# Outliers in insulin-3:30:
# min oulier: -0.3078 max outlier: 46.311
# 100       1.7083
# 118       8.0583
# 143       4.0500
# 306       2.5500
# 444       0.6167
#            ...
# 177019    0.2750
# 177020    3.4500
# 177021    0.2500
# 177022    0.2750
# 177023    0.2500
# Name: insulin-3:30, Length: 17611, dtype: float64
# Outliers in insulin-3:25:
# min oulier: -0.3078 max outlier: 46.311
# 20        6.5417
# 25        2.6583
# 73        1.0333
# 82        0.2167
# 113       0.2417
#            ...
# 177019    3.4500
# 177020    0.2500
# 177021    0.2750
# 177022    0.2500
# 177023    0.2250
# Name: insulin-3:25, Length: 17615, dtype: float64
# Outliers in insulin-3:20:
# min oulier: -0.3078 max outlier: 46.311
# 25        1.0583
# 43        3.1500
# 58        1.8292
# 63        5.8292
# 80        0.6333
#            ...
# 177018    3.4500
# 177019    0.2500
# 177020    0.2750
# 177021    0.2500
# 177022    0.2250
# Name: insulin-3:20, Length: 17620, dtype: float64
# Outliers in insulin-3:15:
# min oulier: -0.3078 max outlier: 46.311
# 117       8.0583
# 142       4.0500
# 305       2.5500
# 443       0.6167
# 474       1.3417
#            ...
# 177017    3.4500
# 177018    0.2500
# 177019    0.2750
# 177020    0.2500
# 177021    0.2250
# Name: insulin-3:15, Length: 17607, dtype: float64
# Outliers in insulin-3:10:
# min oulier: -0.3078 max outlier: 46.311
# 19        6.5417
# 24        2.6583
# 72        1.0333
# 81        0.2167
# 99        1.7083
#            ...
# 177016    3.4500
# 177017    0.2500
# 177018    0.2750
# 177019    0.2500
# 177020    0.2250
# Name: insulin-3:10, Length: 17609, dtype: float64
# Outliers in insulin-3:05:
# min oulier: -0.3078 max outlier: 46.311
# 24        1.0583
# 42        3.1500
# 57        1.8292
# 62        5.8292
# 79        0.6333
#            ...
# 177015    3.4500
# 177016    0.2500
# 177017    0.2750
# 177018    0.2500
# 177019    0.2250
# Name: insulin-3:05, Length: 17611, dtype: float64
# Outliers in insulin-3:00:
# min oulier: -0.3078 max outlier: 46.311
# 116       8.0583
# 141       4.0500
# 304       2.5500
# 442       0.6167
# 473       1.3417
#            ...
# 177014    3.4500
# 177015    0.2500
# 177016    0.2750
# 177017    0.2500
# 177018    0.2250
# Name: insulin-3:00, Length: 17616, dtype: float64
# Outliers in insulin-2:55:
# min oulier: -0.3078 max outlier: 46.311
# 18        6.5417
# 23        2.6583
# 71        1.0333
# 80        0.2167
# 98        1.7083
#            ...
# 177013    3.4500
# 177014    0.2500
# 177015    0.2750
# 177016    0.2500
# 177017    0.2250
# Name: insulin-2:55, Length: 17599, dtype: float64
# Outliers in insulin-2:50:
# min oulier: -0.3078 max outlier: 46.311
# 23        1.0583
# 41        3.1500
# 56        1.8292
# 61        5.8292
# 78        0.6333
#            ...
# 177012    3.4500
# 177013    0.2500
# 177014    0.2750
# 177015    0.2500
# 177016    0.2250
# Name: insulin-2:50, Length: 17611, dtype: float64
# Outliers in insulin-2:45:
# min oulier: -0.3078 max outlier: 46.311
# 115       8.0583
# 137       8.0500
# 140       4.0500
# 303       2.5500
# 441       0.6167
#            ...
# 177011    3.4500
# 177012    0.2500
# 177013    0.2750
# 177014    0.2500
# 177015    0.2250
# Name: insulin-2:45, Length: 17626, dtype: float64
# Outliers in insulin-2:40:
# min oulier: -0.3078 max outlier: 46.311
# 17        6.5417
# 22        2.6583
# 70        1.0333
# 79        0.2167
# 97        1.7083
#            ...
# 177010    3.4500
# 177011    0.2500
# 177012    0.2750
# 177013    0.2500
# 177014    0.2250
# Name: insulin-2:40, Length: 17598, dtype: float64
# Outliers in insulin-2:35:
# min oulier: -0.3078 max outlier: 46.311
# 22        1.0583
# 40        3.1500
# 55        1.8292
# 60        5.8292
# 77        0.6333
#            ...
# 177010    0.2500
# 177011    0.2750
# 177012    0.2500
# 177013    0.2250
# 177023    0.2500
# Name: insulin-2:35, Length: 17618, dtype: float64
# Outliers in insulin-2:30:
# min oulier: -0.3078 max outlier: 46.311
# 114       8.0583
# 136       8.0500
# 139       4.0500
# 302       2.5500
# 440       0.6167
#            ...
# 177009    0.2500
# 177010    0.2750
# 177011    0.2500
# 177012    0.2250
# 177022    0.2500
# Name: insulin-2:30, Length: 17645, dtype: float64
# Outliers in insulin-2:25:
# min oulier: -0.3078 max outlier: 46.311
# 16        6.5417
# 21        2.6583
# 69        1.0333
# 78        0.2167
# 96        1.7083
#            ...
# 177008    0.2500
# 177009    0.2750
# 177010    0.2500
# 177011    0.2250
# 177021    0.2500
# Name: insulin-2:25, Length: 17615, dtype: float64
# Outliers in insulin-2:20:
# min oulier: -0.3078 max outlier: 46.311
# 21         1.0583
# 39         3.1500
# 54         1.8292
# 59         5.8292
# 76         0.6333
#            ...
# 177008     0.2750
# 177009     0.2500
# 177010     0.2250
# 177020     0.2500
# 177023    13.0750
# Name: insulin-2:20, Length: 17631, dtype: float64
# Outliers in insulin-2:15:
# min oulier: -0.3078 max outlier: 46.311
# 113        8.0583
# 135        8.0500
# 138        4.0500
# 301        2.5500
# 439        0.6167
#            ...
# 177007     0.2750
# 177008     0.2500
# 177009     0.2250
# 177019     0.2500
# 177022    13.0750
# Name: insulin-2:15, Length: 17644, dtype: float64
# Outliers in insulin-2:10:
# min oulier: -0.3078 max outlier: 46.311
# 15         6.5417
# 20         2.6583
# 68         1.0333
# 77         0.2167
# 95         1.7083
#            ...
# 177006     0.2750
# 177007     0.2500
# 177008     0.2250
# 177018     0.2500
# 177021    13.0750
# Name: insulin-2:10, Length: 17620, dtype: float64
# Outliers in insulin-2:05:
# min oulier: -0.3078 max outlier: 46.311
# 20         1.0583
# 38         3.1500
# 53         1.8292
# 58         5.8292
# 75         0.6333
#            ...
# 177005     0.2750
# 177006     0.2500
# 177007     0.2250
# 177017     0.2500
# 177020    13.0750
# Name: insulin-2:05, Length: 17631, dtype: float64
# Outliers in insulin-2:00:
# min oulier: -0.3078 max outlier: 46.311
# 112        8.0583
# 134        8.0500
# 300        2.5500
# 328        6.0333
# 438        0.6167
#            ...
# 177004     0.2750
# 177005     0.2500
# 177006     0.2250
# 177016     0.2500
# 177019    13.0750
# Name: insulin-2:00, Length: 17647, dtype: float64
# Outliers in insulin-1:55:
# min oulier: -0.3078 max outlier: 46.311
# 14         6.5417
# 19         2.6583
# 67         1.0333
# 76         0.2167
# 94         1.7083
#            ...
# 177003     0.2750
# 177004     0.2500
# 177005     0.2250
# 177015     0.2500
# 177018    13.0750
# Name: insulin-1:55, Length: 17625, dtype: float64
# Outliers in insulin-1:50:
# min oulier: -0.3078 max outlier: 46.311
# 19         1.0583
# 37         3.1500
# 52         1.8292
# 57         5.8292
# 74         0.6333
#            ...
# 177002     0.2750
# 177003     0.2500
# 177004     0.2250
# 177014     0.2500
# 177017    13.0750
# Name: insulin-1:50, Length: 17606, dtype: float64
# Outliers in insulin-1:45:
# min oulier: -0.3078 max outlier: 46.311
# 111        8.0583
# 133        8.0500
# 299        2.5500
# 327        6.0333
# 437        0.6167
#            ...
# 177001     0.2750
# 177002     0.2500
# 177003     0.2250
# 177013     0.2500
# 177016    13.0750
# Name: insulin-1:45, Length: 17637, dtype: float64
# Outliers in insulin-1:40:
# min oulier: -0.3078 max outlier: 46.311
# 13         6.5417
# 18         2.6583
# 66         1.0333
# 75         0.2167
# 93         1.7083
#            ...
# 177000     0.2750
# 177001     0.2500
# 177002     0.2250
# 177012     0.2500
# 177015    13.0750
# Name: insulin-1:40, Length: 17613, dtype: float64
# Outliers in insulin-1:35:
# min oulier: -0.3078 max outlier: 46.311
# 18         1.0583
# 36         3.1500
# 51         1.8292
# 56         5.8292
# 73         0.6333
#            ...
# 176999     0.2750
# 177000     0.2500
# 177001     0.2250
# 177011     0.2500
# 177014    13.0750
# Name: insulin-1:35, Length: 17618, dtype: float64
# Outliers in insulin-1:30:
# min oulier: -0.3078 max outlier: 46.311
# 110        8.0583
# 132        8.0500
# 298        2.5500
# 326        6.0333
# 436        0.6167
#            ...
# 176998     0.2750
# 176999     0.2500
# 177000     0.2250
# 177010     0.2500
# 177013    13.0750
# Name: insulin-1:30, Length: 17635, dtype: float64
# Outliers in insulin-1:25:
# min oulier: -0.3078 max outlier: 46.311
# 12         6.5417
# 17         2.6583
# 65         1.0333
# 74         0.2167
# 92         1.7083
#            ...
# 176997     0.2750
# 176998     0.2500
# 176999     0.2250
# 177009     0.2500
# 177012    13.0750
# Name: insulin-1:25, Length: 17611, dtype: float64
# Outliers in insulin-1:20:
# min oulier: -0.3078 max outlier: 46.311
# 17         1.0583
# 35         3.1500
# 50         1.8292
# 55         5.8292
# 72         0.6333
#            ...
# 176996     0.2750
# 176997     0.2500
# 176998     0.2250
# 177008     0.2500
# 177011    13.0750
# Name: insulin-1:20, Length: 17612, dtype: float64
# Outliers in insulin-1:15:
# min oulier: -0.3078 max outlier: 46.311
# 109        8.0583
# 131        8.0500
# 297        2.5500
# 325        6.0333
# 466        1.3417
#            ...
# 176995     0.2750
# 176996     0.2500
# 176997     0.2250
# 177007     0.2500
# 177010    13.0750
# Name: insulin-1:15, Length: 17633, dtype: float64
# Outliers in insulin-1:10:
# min oulier: -0.3078 max outlier: 46.311
# 11         6.5417
# 16         2.6583
# 64         1.0333
# 73         0.2167
# 91         1.7083
#            ...
# 176995     0.2500
# 176996     0.2250
# 177006     0.2500
# 177009    13.0750
# 177023     0.2500
# Name: insulin-1:10, Length: 17611, dtype: float64
# Outliers in insulin-1:05:
# min oulier: -0.3078 max outlier: 46.311
# 16         1.0583
# 49         1.8292
# 54         5.8292
# 71         0.6333
# 72         0.9167
#            ...
# 176995     0.2250
# 177005     0.2500
# 177008    13.0750
# 177022     0.2500
# 177023     0.2750
# Name: insulin-1:05, Length: 17596, dtype: float64
# Outliers in insulin-1:00:
# min oulier: -0.3078 max outlier: 46.311
# 34         3.1500
# 108        8.0583
# 130        8.0500
# 296        2.5500
# 324        6.0333
#            ...
# 177004     0.2500
# 177007    13.0750
# 177021     0.2500
# 177022     0.2750
# 177023     0.2500
# Name: insulin-1:00, Length: 17623, dtype: float64
# Outliers in insulin-0:55:
# min oulier: -0.3078 max outlier: 46.311
# 10         6.5417
# 15         2.6583
# 72         0.2167
# 90         1.7083
# 103        0.2417
#            ...
# 177006    13.0750
# 177020     0.2500
# 177021     0.2750
# 177022     0.2500
# 177023     0.2750
# Name: insulin-0:55, Length: 17597, dtype: float64
# Outliers in insulin-0:50:
# min oulier: -0.3078 max outlier: 46.311
# 15        1.0583
# 33        3.1500
# 48        1.8292
# 53        5.8292
# 63        1.0333
#            ...
# 177019    0.2500
# 177020    0.2750
# 177021    0.2500
# 177022    0.2750
# 177023    0.2500
# Name: insulin-0:50, Length: 17589, dtype: float64
# Outliers in insulin-0:45:
# min oulier: -0.3078 max outlier: 46.311
# 107       8.0583
# 129       8.0500
# 295       2.5500
# 323       6.0333
# 397       4.0500
#            ...
# 177019    0.2750
# 177020    0.2500
# 177021    0.2750
# 177022    0.2500
# 177023    0.2750
# Name: insulin-0:45, Length: 17633, dtype: float64
# Outliers in insulin-0:40:
# min oulier: -0.3078 max outlier: 46.311
# 9         6.5417
# 14        2.6583
# 71        0.2167
# 89        1.7083
# 102       0.2417
#            ...
# 177019    0.2500
# 177020    0.2750
# 177021    0.2500
# 177022    0.2750
# 177023    0.2750
# Name: insulin-0:40, Length: 17609, dtype: float64
# Outliers in insulin-0:35:
# min oulier: -0.3078 max outlier: 46.311
# 14        1.0583
# 32        3.1500
# 47        1.8292
# 52        5.8292
# 62        1.0333
#            ...
# 177019    0.2750
# 177020    0.2500
# 177021    0.2750
# 177022    0.2750
# 177023    0.2500
# Name: insulin-0:35, Length: 17599, dtype: float64
# Outliers in insulin-0:30:
# min oulier: -0.3078 max outlier: 46.311
# 106       8.0583
# 128       8.0500
# 294       2.5500
# 322       6.0333
# 396       4.0500
#            ...
# 177019    0.2500
# 177020    0.2750
# 177021    0.2750
# 177022    0.2500
# 177023    0.2750
# Name: insulin-0:30, Length: 17626, dtype: float64
# Outliers in insulin-0:25:
# min oulier: -0.3078 max outlier: 46.311
# 8         6.5417
# 13        2.6583
# 70        0.2167
# 88        1.7083
# 101       0.2417
#            ...
# 177019    0.2750
# 177020    0.2750
# 177021    0.2500
# 177022    0.2750
# 177023    0.9600
# Name: insulin-0:25, Length: 17585, dtype: float64
# Outliers in insulin-0:20:
# min oulier: -0.3078 max outlier: 46.311
# 13        1.0583
# 31        3.1500
# 46        1.8292
# 51        5.8292
# 61        1.0333
#            ...
# 177019    0.2750
# 177020    0.2500
# 177021    0.2750
# 177022    0.9600
# 177023    0.2750
# Name: insulin-0:20, Length: 17591, dtype: float64
# Outliers in insulin-0:15:
# min oulier: -0.3078 max outlier: 46.311
# 105       8.0583
# 127       8.0500
# 293       2.5500
# 321       6.0333
# 395       4.0500
#            ...
# 177019    0.2500
# 177020    0.2750
# 177021    0.9600
# 177022    0.2750
# 177023    1.0600
# Name: insulin-0:15, Length: 17616, dtype: float64
# Outliers in insulin-0:10:
# min oulier: -0.3078 max outlier: 46.311
# 7         6.5417
# 12        2.6583
# 69        0.2167
# 87        1.7083
# 100       0.2417
#            ...
# 177019    0.2750
# 177020    0.9600
# 177021    0.2750
# 177022    1.0600
# 177023    0.5600
# Name: insulin-0:10, Length: 17593, dtype: float64
# Outliers in insulin-0:05:
# min oulier: -0.3078 max outlier: 46.311
# 12        1.0583
# 30        3.1500
# 45        1.8292
# 50        5.8292
# 60        1.0333
#            ...
# 177018    0.2750
# 177019    0.9600
# 177020    0.2750
# 177021    1.0600
# 177022    0.5600
# Name: insulin-0:05, Length: 17601, dtype: float64
# Outliers in insulin-0:00:
# min oulier: -0.3078 max outlier: 46.311
# 104       8.0583
# 126       8.0500
# 292       2.5500
# 320       6.0333
# 394       4.0500
#            ...
# 177017    0.2750
# 177018    0.9600
# 177019    0.2750
# 177020    1.0600
# 177021    0.5600
# Name: insulin-0:00, Length: 17619, dtype: float64
